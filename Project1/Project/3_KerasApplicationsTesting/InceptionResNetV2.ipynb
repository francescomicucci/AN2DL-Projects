# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Progetto AN2DL/3_KerasApplicationsTesting
# Out:
# Mounted at /gdrive
# /gdrive/.shortcut-targets-by-id/1ygSQdg0_3KzCXK0mWufNykWjfoYjWqKH/Progetto AN2DL/FeatureExtractorTesting

# %% [markdown]
# ### Import libraries

# %%
# Hide warnings
seed  = 42
import os

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold

# %% [markdown]
# ### Load and process the dataset

# %%
# Load data
data = np.load('../clean_data.npz', allow_pickle=True)

# Save labels in a new list (image pixel values are float in [0, 1])
images = data['data']

# Save labels in a new list
labels = data['labels']

# Print data shape
print(images.shape, labels.shape)
# Out:
# (5004, 96, 96, 3) (5004,)

# %%
# Number of images to display
num_img = 100

# Create subplots for displaying images
fig, axes = plt.subplots(10, num_img//10, figsize=(20, 20))
for i in range(num_img):
    ax = axes[i%10, i%num_img//10]
    ax.imshow(np.clip(images[i], 0, 255))  # Display clipped item images
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Convert labels from string to integer
num_labels = []
for label in labels:
  if label == "healthy":
    num_labels.append(0)
  else:
    num_labels.append(1)

# Convert labels in the one-hot encoding format
num_labels = np.array(num_labels)
labels = tfk.utils.to_categorical(num_labels, 2)

# Split data into train and val sets
X_train, X_val, y_train, y_val = train_test_split(
    images,
    labels,
    test_size=0.1,
    stratify=labels
)

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (4503, 96, 96, 3), y_train shape: (4503, 2)
# X_val shape: (501, 96, 96, 3), y_val shape: (501, 2)

# %% [markdown]
# ### InceptionResNetV2

# %%
# Import Feature Extractor with specified settings
feature_extractor = tfk.applications.InceptionResNetV2(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    pooling='avg',
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 [==============================] - 1s 0us/step

# %% [markdown]
# ### Model

# %%
# Define network parameters/callbacks
dropout_rate = 1/10
learning_rate = 1e-3

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.999,
    mode='max',
    min_lr=1e-5
)

early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=20,
    restore_best_weights=True
)

# %%
def build_model(feature_extractor, dropout_rate, learning_rate=0.001):
  # Use the supernet as feature extractor, i.e. freeze all its weigths
  feature_extractor.trainable = False

  # Create an input layer with shape (96, 96, 3)
  inputs = tfk.Input(shape=(96, 96, 3), name='Input')

  # Connect FeatureExtractor to the input
  x = feature_extractor(inputs)

  # Hidden layers
  x = tfkl.Dense(units=64, name='HiddenDense1')(x)
  x = tfkl.Activation('relu', name='HiddenActivation1')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)
  x = tfkl.Dense(units=64, name='HiddenDense2')(dropout)
  x = tfkl.Activation('relu', name='HiddenActivation2')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)

  # Add a Dense layer with 2 unit and softmax activation as the classifier
  outputs = tfkl.Dense(2, activation='softmax')(dropout)

  # Create a Model connecting input and output
  model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

  # Compile the model with Categorical Cross-Entropy loss and Adam optimizer
  model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                optimizer=tfk.optimizers.Adam(learning_rate),
                metrics=['accuracy'])

  # Return the model
  return model

# %%
model = build_model(feature_extractor, dropout_rate, learning_rate)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  inception_resnet_v2 (Funct  (None, 1536)              54336736
#  ional)
#
#  HiddenDense1 (Dense)        (None, 64)                98368
#
#  HiddenActivation1 (Activat  (None, 64)                0
#  ion)
#
#  dropout (Dropout)           (None, 64)                0
#
#  HiddenDense2 (Dense)        (None, 64)                4160
#
#  HiddenActivation2 (Activat  (None, 64)                0
#  ion)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 54439394 (207.67 MB)
# Trainable params: 102658 (401.01 KB)
# Non-trainable params: 54336736 (207.28 MB)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = preprocess_input(X_train*255),
    y = y_train,
    batch_size = 16,
    epochs = 200,
    validation_data = (preprocess_input(X_val*255), y_val),
    callbacks = [early_stopping, lr_scheduler]
).history
# Out:
# Epoch 1/200
# 282/282 [==============================] - 45s 60ms/step - loss: 0.6242 - accuracy: 0.6811 - val_loss: 0.5322 - val_accuracy: 0.7365 - lr: 0.0010
# Epoch 2/200
# 282/282 [==============================] - 10s 37ms/step - loss: 0.5147 - accuracy: 0.7482 - val_loss: 0.5101 - val_accuracy: 0.7525 - lr: 0.0010
# Epoch 3/200
# 282/282 [==============================] - 11s 39ms/step - loss: 0.4874 - accuracy: 0.7615 - val_loss: 0.5129 - val_accuracy: 0.7545 - lr: 0.0010
# Epoch 4/200
# 282/282 [==============================] - 12s 41ms/step - loss: 0.4615 - accuracy: 0.7839 - val_loss: 0.4918 - val_accuracy: 0.7665 - lr: 0.0010
# Epoch 5/200
# 282/282 [==============================] - 11s 40ms/step - loss: 0.4369 - accuracy: 0.7981 - val_loss: 0.5025 - val_accuracy: 0.7725 - lr: 0.0010
# Epoch 6/200
# 282/282 [==============================] - 11s 37ms/step - loss: 0.4244 - accuracy: 0.7964 - val_loss: 0.5184 - val_accuracy: 0.7605 - lr: 0.0010
# Epoch 7/200
# 282/282 [==============================] - 10s 35ms/step - loss: 0.3907 - accuracy: 0.8186 - val_loss: 0.5115 - val_accuracy: 0.7605 - lr: 0.0010
# Epoch 8/200
# 282/282 [==============================] - 10s 37ms/step - loss: 0.3605 - accuracy: 0.8366 - val_loss: 0.5921 - val_accuracy: 0.7166 - lr: 0.0010
# Epoch 9/200
# 282/282 [==============================] - 10s 37ms/step - loss: 0.3422 - accuracy: 0.8497 - val_loss: 0.5650 - val_accuracy: 0.7585 - lr: 0.0010
# Epoch 10/200
# 282/282 [==============================] - 11s 39ms/step - loss: 0.3292 - accuracy: 0.8525 - val_loss: 0.5668 - val_accuracy: 0.7545 - lr: 0.0010
# Epoch 11/200
# 282/282 [==============================] - 10s 35ms/step - loss: 0.2930 - accuracy: 0.8681 - val_loss: 0.6071 - val_accuracy: 0.7405 - lr: 9.9900e-04
# Epoch 12/200
# 282/282 [==============================] - 11s 39ms/step - loss: 0.2782 - accuracy: 0.8781 - val_loss: 0.5587 - val_accuracy: 0.7585 - lr: 9.9900e-04
# Epoch 13/200
# 282/282 [==============================] - 11s 38ms/step - loss: 0.2669 - accuracy: 0.8830 - val_loss: 0.6620 - val_accuracy: 0.7565 - lr: 9.9900e-04
# Epoch 14/200
# 282/282 [==============================] - 11s 38ms/step - loss: 0.2524 - accuracy: 0.8861 - val_loss: 0.6164 - val_accuracy: 0.7565 - lr: 9.9900e-04
# Epoch 15/200
# 282/282 [==============================] - 10s 35ms/step - loss: 0.2214 - accuracy: 0.9007 - val_loss: 0.7761 - val_accuracy: 0.7525 - lr: 9.9900e-04
# Epoch 16/200
# 282/282 [==============================] - 10s 35ms/step - loss: 0.2364 - accuracy: 0.8943 - val_loss: 0.6625 - val_accuracy: 0.7565 - lr: 9.9800e-04
# Epoch 17/200
# 282/282 [==============================] - 10s 37ms/step - loss: 0.1978 - accuracy: 0.9176 - val_loss: 0.7536 - val_accuracy: 0.7525 - lr: 9.9800e-04
# Epoch 18/200
# 282/282 [==============================] - 10s 37ms/step - loss: 0.1897 - accuracy: 0.9161 - val_loss: 0.7999 - val_accuracy: 0.7485 - lr: 9.9800e-04
# Epoch 19/200
# 282/282 [==============================] - 10s 35ms/step - loss: 0.1809 - accuracy: 0.9232 - val_loss: 0.7747 - val_accuracy: 0.7445 - lr: 9.9800e-04
# Epoch 20/200
# 282/282 [==============================] - 10s 37ms/step - loss: 0.1832 - accuracy: 0.9247 - val_loss: 0.8407 - val_accuracy: 0.7425 - lr: 9.9800e-04
# Epoch 21/200
# 282/282 [==============================] - 10s 37ms/step - loss: 0.1563 - accuracy: 0.9334 - val_loss: 0.9709 - val_accuracy: 0.7385 - lr: 9.9700e-04
# Epoch 22/200
# 282/282 [==============================] - 11s 38ms/step - loss: 0.1365 - accuracy: 0.9400 - val_loss: 0.9369 - val_accuracy: 0.7405 - lr: 9.9700e-04
# Epoch 23/200
# 282/282 [==============================] - 10s 37ms/step - loss: 0.1572 - accuracy: 0.9265 - val_loss: 1.0038 - val_accuracy: 0.7425 - lr: 9.9700e-04
# Epoch 24/200
# 282/282 [==============================] - 10s 36ms/step - loss: 0.1539 - accuracy: 0.9292 - val_loss: 1.1133 - val_accuracy: 0.7305 - lr: 9.9700e-04
# Epoch 25/200
# 282/282 [==============================] - 11s 38ms/step - loss: 0.1405 - accuracy: 0.9392 - val_loss: 1.0791 - val_accuracy: 0.7425 - lr: 9.9700e-04

# %%
# Plot the training histories
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the model
model.save('InceptionResNetV2')
