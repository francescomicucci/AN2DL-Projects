# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Progetto AN2DL/3_KerasApplicationsTesting
# Out:
# Mounted at /gdrive
# /gdrive/.shortcut-targets-by-id/1ygSQdg0_3KzCXK0mWufNykWjfoYjWqKH/Progetto AN2DL/FeatureExtractorTesting

# %% [markdown]
# ### Import libraries

# %%
# Hide warnings
seed  = 42
import os

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold

# %% [markdown]
# ### Load and process the dataset

# %%
# Load data
data = np.load('../clean_data.npz', allow_pickle=True)

# Save labels in a new list (image pixel values are float in [0, 1])
images = data['data']

# Save labels in a new list
labels = data['labels']

# Print data shape
print(images.shape, labels.shape)
# Out:
# (5004, 96, 96, 3) (5004,)

# %%
# Number of images to display
num_img = 100

# Create subplots for displaying images
fig, axes = plt.subplots(10, num_img//10, figsize=(20, 20))
for i in range(num_img):
    ax = axes[i%10, i%num_img//10]
    ax.imshow(np.clip(images[i], 0, 255))  # Display clipped item images
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Convert labels from string to integer
num_labels = []
for label in labels:
  if label == "healthy":
    num_labels.append(0)
  else:
    num_labels.append(1)

# Convert labels in the one-hot encoding format
num_labels = np.array(num_labels)
labels = tfk.utils.to_categorical(num_labels, 2)

# Split data into train and val sets
X_train, X_val, y_train, y_val = train_test_split(
    images,
    labels,
    test_size=0.1,
    stratify=labels
)

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (4503, 96, 96, 3), y_train shape: (4503, 2)
# X_val shape: (501, 96, 96, 3), y_val shape: (501, 2)

# %% [markdown]
# ### ResNet50V2

# %%
# Import Feature Extractor with specified settings
feature_extractor = tfk.applications.ResNet50V2(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    pooling='avg',
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 [==============================] - 0s 0us/step

# %% [markdown]
# ### Model

# %%
# Define network parameters/callbacks
dropout_rate = 1/10
learning_rate = 1e-3

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.999,
    mode='max',
    min_lr=1e-5
)

early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=20,
    restore_best_weights=True
)

# %%
def build_model(feature_extractor, dropout_rate, learning_rate=0.001):
  # Use the supernet as feature extractor, i.e. freeze all its weigths
  feature_extractor.trainable = False

  # Create an input layer with shape (96, 96, 3)
  inputs = tfk.Input(shape=(96, 96, 3), name='Input')

  # Connect FeatureExtractor to the input
  x = feature_extractor(inputs)

  # Hidden layers
  x = tfkl.Dense(units=64, name='HiddenDense1')(x)
  x = tfkl.Activation('relu', name='HiddenActivation1')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)
  x = tfkl.Dense(units=64, name='HiddenDense2')(dropout)
  x = tfkl.Activation('relu', name='HiddenActivation2')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)

  # Add a Dense layer with 2 unit and softmax activation as the classifier
  outputs = tfkl.Dense(2, activation='softmax')(dropout)

  # Create a Model connecting input and output
  model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

  # Compile the model with Categorical Cross-Entropy loss and Adam optimizer
  model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                optimizer=tfk.optimizers.Adam(learning_rate),
                metrics=['accuracy'])

  # Return the model
  return model

# %%
model = build_model(feature_extractor, dropout_rate, learning_rate)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  resnet50v2 (Functional)     (None, 2048)              23564800
#
#  HiddenDense1 (Dense)        (None, 64)                131136
#
#  HiddenActivation1 (Activat  (None, 64)                0
#  ion)
#
#  dropout (Dropout)           (None, 64)                0
#
#  HiddenDense2 (Dense)        (None, 64)                4160
#
#  HiddenActivation2 (Activat  (None, 64)                0
#  ion)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 23700226 (90.41 MB)
# Trainable params: 135426 (529.01 KB)
# Non-trainable params: 23564800 (89.89 MB)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = preprocess_input(X_train*255),
    y = y_train,
    batch_size = 16,
    epochs = 200,
    validation_data = (preprocess_input(X_val*255), y_val),
    callbacks = [early_stopping, lr_scheduler]
).history
# Out:
# Epoch 1/200
# 282/282 [==============================] - 23s 31ms/step - loss: 0.5542 - accuracy: 0.7295 - val_loss: 0.5064 - val_accuracy: 0.7365 - lr: 0.0010
# Epoch 2/200
# 282/282 [==============================] - 5s 19ms/step - loss: 0.4284 - accuracy: 0.7966 - val_loss: 0.5012 - val_accuracy: 0.7705 - lr: 0.0010
# Epoch 3/200
# 282/282 [==============================] - 6s 21ms/step - loss: 0.3696 - accuracy: 0.8310 - val_loss: 0.5343 - val_accuracy: 0.7525 - lr: 0.0010
# Epoch 4/200
# 282/282 [==============================] - 5s 19ms/step - loss: 0.3183 - accuracy: 0.8539 - val_loss: 0.5502 - val_accuracy: 0.7465 - lr: 0.0010
# Epoch 5/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.2668 - accuracy: 0.8832 - val_loss: 0.5320 - val_accuracy: 0.7445 - lr: 0.0010
# Epoch 6/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.2322 - accuracy: 0.9003 - val_loss: 0.6409 - val_accuracy: 0.7705 - lr: 0.0010
# Epoch 7/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.1961 - accuracy: 0.9187 - val_loss: 0.6575 - val_accuracy: 0.7884 - lr: 0.0010
# Epoch 8/200
# 282/282 [==============================] - 6s 22ms/step - loss: 0.1489 - accuracy: 0.9400 - val_loss: 0.7431 - val_accuracy: 0.7425 - lr: 0.0010
# Epoch 9/200
# 282/282 [==============================] - 5s 19ms/step - loss: 0.1261 - accuracy: 0.9507 - val_loss: 0.8827 - val_accuracy: 0.7465 - lr: 0.0010
# Epoch 10/200
# 282/282 [==============================] - 6s 21ms/step - loss: 0.1172 - accuracy: 0.9574 - val_loss: 0.9300 - val_accuracy: 0.7685 - lr: 0.0010
# Epoch 11/200
# 282/282 [==============================] - 5s 19ms/step - loss: 0.0923 - accuracy: 0.9634 - val_loss: 1.0154 - val_accuracy: 0.7545 - lr: 0.0010
# Epoch 12/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.0809 - accuracy: 0.9718 - val_loss: 1.0767 - val_accuracy: 0.7485 - lr: 0.0010
# Epoch 13/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.1004 - accuracy: 0.9634 - val_loss: 1.0883 - val_accuracy: 0.7685 - lr: 9.9900e-04
# Epoch 14/200
# 282/282 [==============================] - 5s 19ms/step - loss: 0.0663 - accuracy: 0.9731 - val_loss: 1.2046 - val_accuracy: 0.7725 - lr: 9.9900e-04
# Epoch 15/200
# 282/282 [==============================] - 6s 21ms/step - loss: 0.0495 - accuracy: 0.9807 - val_loss: 1.4407 - val_accuracy: 0.7645 - lr: 9.9900e-04
# Epoch 16/200
# 282/282 [==============================] - 5s 19ms/step - loss: 0.0531 - accuracy: 0.9807 - val_loss: 1.4009 - val_accuracy: 0.7525 - lr: 9.9900e-04
# Epoch 17/200
# 282/282 [==============================] - 6s 21ms/step - loss: 0.0629 - accuracy: 0.9773 - val_loss: 1.2561 - val_accuracy: 0.7665 - lr: 9.9900e-04
# Epoch 18/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.0561 - accuracy: 0.9822 - val_loss: 1.3018 - val_accuracy: 0.7944 - lr: 9.9800e-04
# Epoch 19/200
# 282/282 [==============================] - 5s 19ms/step - loss: 0.0482 - accuracy: 0.9838 - val_loss: 1.3020 - val_accuracy: 0.7605 - lr: 9.9800e-04
# Epoch 20/200
# 282/282 [==============================] - 6s 21ms/step - loss: 0.0445 - accuracy: 0.9818 - val_loss: 1.2940 - val_accuracy: 0.7645 - lr: 9.9800e-04
# Epoch 21/200
# 282/282 [==============================] - 5s 19ms/step - loss: 0.0386 - accuracy: 0.9876 - val_loss: 1.6803 - val_accuracy: 0.7605 - lr: 9.9800e-04
# Epoch 22/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.0512 - accuracy: 0.9816 - val_loss: 1.3173 - val_accuracy: 0.7645 - lr: 9.9800e-04
# Epoch 23/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.0449 - accuracy: 0.9847 - val_loss: 1.2886 - val_accuracy: 0.7685 - lr: 9.9800e-04
# Epoch 24/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.0381 - accuracy: 0.9873 - val_loss: 1.5624 - val_accuracy: 0.7864 - lr: 9.9700e-04
# Epoch 25/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.0389 - accuracy: 0.9860 - val_loss: 1.6988 - val_accuracy: 0.7625 - lr: 9.9700e-04
# Epoch 26/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.0509 - accuracy: 0.9847 - val_loss: 1.5126 - val_accuracy: 0.7485 - lr: 9.9700e-04
# Epoch 27/200
# 282/282 [==============================] - 6s 21ms/step - loss: 0.0410 - accuracy: 0.9878 - val_loss: 1.3865 - val_accuracy: 0.7625 - lr: 9.9700e-04
# Epoch 28/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.0314 - accuracy: 0.9900 - val_loss: 1.4908 - val_accuracy: 0.7485 - lr: 9.9700e-04
# Epoch 29/200
# 282/282 [==============================] - 6s 21ms/step - loss: 0.0290 - accuracy: 0.9918 - val_loss: 1.7103 - val_accuracy: 0.7605 - lr: 9.9601e-04
# Epoch 30/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.0415 - accuracy: 0.9851 - val_loss: 1.3578 - val_accuracy: 0.7605 - lr: 9.9601e-04
# Epoch 31/200
# 282/282 [==============================] - 5s 19ms/step - loss: 0.0271 - accuracy: 0.9896 - val_loss: 1.5618 - val_accuracy: 0.7565 - lr: 9.9601e-04
# Epoch 32/200
# 282/282 [==============================] - 6s 21ms/step - loss: 0.0358 - accuracy: 0.9869 - val_loss: 1.4169 - val_accuracy: 0.7784 - lr: 9.9601e-04
# Epoch 33/200
# 282/282 [==============================] - 6s 22ms/step - loss: 0.0278 - accuracy: 0.9900 - val_loss: 1.4573 - val_accuracy: 0.7725 - lr: 9.9601e-04
# Epoch 34/200
# 282/282 [==============================] - 7s 25ms/step - loss: 0.0365 - accuracy: 0.9876 - val_loss: 1.4587 - val_accuracy: 0.7625 - lr: 9.9501e-04
# Epoch 35/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.0263 - accuracy: 0.9916 - val_loss: 1.6312 - val_accuracy: 0.7665 - lr: 9.9501e-04
# Epoch 36/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.0282 - accuracy: 0.9913 - val_loss: 1.6878 - val_accuracy: 0.7525 - lr: 9.9501e-04
# Epoch 37/200
# 282/282 [==============================] - 5s 19ms/step - loss: 0.0199 - accuracy: 0.9931 - val_loss: 1.4591 - val_accuracy: 0.7625 - lr: 9.9501e-04
# Epoch 38/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.0227 - accuracy: 0.9927 - val_loss: 1.6110 - val_accuracy: 0.7725 - lr: 9.9501e-04

# %%
# Plot the training histories
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the model
model.save('ResNet50V2')
