# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Progetto AN2DL/3_KerasApplicationsTesting
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/Progetto AN2DL/FeatureExtractorTesting

# %% [markdown]
# ### Import libraries

# %%
# Hide warnings
seed  = 42
import os

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold

# %% [markdown]
# ### Load and process the dataset

# %%
# Load data
data = np.load('../clean_data.npz', allow_pickle=True)

# Save labels in a new list (image pixel values are float in [0, 1])
images = data['data']

# Save labels in a new list
labels = data['labels']

# Print data shape
print(images.shape, labels.shape)
# Out:
# (5004, 96, 96, 3) (5004,)

# %%
# Number of images to display
num_img = 100

# Create subplots for displaying images
fig, axes = plt.subplots(10, num_img//10, figsize=(20, 20))
for i in range(num_img):
    ax = axes[i%10, i%num_img//10]
    ax.imshow(np.clip(images[i], 0, 255))  # Display clipped item images
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Convert labels from string to integer
num_labels = []
for label in labels:
  if label == "healthy":
    num_labels.append(0)
  else:
    num_labels.append(1)

# Convert labels in the one-hot encoding format
num_labels = np.array(num_labels)
labels = tfk.utils.to_categorical(num_labels, 2)

# Split data into train and val sets
X_train, X_val, y_train, y_val = train_test_split(
    images,
    labels,
    test_size=0.1,
    stratify=labels
)

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (4503, 96, 96, 3), y_train shape: (4503, 2)
# X_val shape: (501, 96, 96, 3), y_val shape: (501, 2)

# %% [markdown]
# ### ConvNeXtBase

# %%
# Import Feature Extractor with specified settings
feature_extractor = tfk.applications.ConvNeXtBase(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    pooling='avg',
    include_preprocessing=True,
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_base_notop.h5
# 350926856/350926856 [==============================] - 2s 0us/step

# %% [markdown]
# ### Model

# %%
# Define network parameters/callbacks
dropout_rate = 1/10
learning_rate = 1e-3

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.999,
    mode='max',
    min_lr=1e-5
)

early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=20,
    restore_best_weights=True
)

# %%
def build_model(feature_extractor, dropout_rate, learning_rate=0.001):
  # Use the supernet as feature extractor, i.e. freeze all its weigths
  feature_extractor.trainable = False

  # Create an input layer with shape (96, 96, 3)
  inputs = tfk.Input(shape=(96, 96, 3), name='Input')

  # Connect FeatureExtractor to the input
  x = feature_extractor(inputs)

  # Hidden layers
  x = tfkl.Dense(units=64, name='HiddenDense1')(x)
  x = tfkl.Activation('relu', name='HiddenActivation1')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)
  x = tfkl.Dense(units=64, name='HiddenDense2')(dropout)
  x = tfkl.Activation('relu', name='HiddenActivation2')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)

  # Add a Dense layer with 2 unit and softmax activation as the classifier
  outputs = tfkl.Dense(2, activation='softmax')(dropout)

  # Create a Model connecting input and output
  model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

  # Compile the model with Categorical Cross-Entropy loss and Adam optimizer
  model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                optimizer=tfk.optimizers.Adam(learning_rate),
                metrics=['accuracy'])

  # Return the model
  return model

# %%
model = build_model(feature_extractor, dropout_rate, learning_rate)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  convnext_base (Functional)  (None, 1024)              87566464
#
#  HiddenDense1 (Dense)        (None, 64)                65600
#
#  HiddenActivation1 (Activat  (None, 64)                0
#  ion)
#
#  dropout (Dropout)           (None, 64)                0
#
#  HiddenDense2 (Dense)        (None, 64)                4160
#
#  HiddenActivation2 (Activat  (None, 64)                0
#  ion)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 87636354 (334.31 MB)
# Trainable params: 69890 (273.01 KB)
# Non-trainable params: 87566464 (334.04 MB)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = X_train*255,
    y = y_train,
    batch_size = 16,
    epochs = 200,
    validation_data = (X_val*255, y_val),
    callbacks = [early_stopping, lr_scheduler]
).history
# Out:
# Epoch 1/200
# 282/282 [==============================] - 74s 149ms/step - loss: 0.4685 - accuracy: 0.7786 - val_loss: 0.3916 - val_accuracy: 0.8144 - lr: 0.0010
# Epoch 2/200
# 282/282 [==============================] - 33s 119ms/step - loss: 0.3614 - accuracy: 0.8430 - val_loss: 0.3320 - val_accuracy: 0.8463 - lr: 0.0010
# Epoch 3/200
# 282/282 [==============================] - 27s 95ms/step - loss: 0.3052 - accuracy: 0.8716 - val_loss: 0.3441 - val_accuracy: 0.8623 - lr: 0.0010
# Epoch 4/200
# 282/282 [==============================] - 26s 94ms/step - loss: 0.2815 - accuracy: 0.8787 - val_loss: 0.3377 - val_accuracy: 0.8583 - lr: 0.0010
# Epoch 5/200
# 282/282 [==============================] - 27s 97ms/step - loss: 0.2713 - accuracy: 0.8801 - val_loss: 0.3342 - val_accuracy: 0.8383 - lr: 0.0010
# Epoch 6/200
# 282/282 [==============================] - 27s 95ms/step - loss: 0.2500 - accuracy: 0.8952 - val_loss: 0.3103 - val_accuracy: 0.8683 - lr: 0.0010
# Epoch 7/200
# 282/282 [==============================] - 26s 93ms/step - loss: 0.2298 - accuracy: 0.9125 - val_loss: 0.3384 - val_accuracy: 0.8643 - lr: 0.0010
# Epoch 8/200
# 282/282 [==============================] - 27s 94ms/step - loss: 0.2211 - accuracy: 0.9094 - val_loss: 0.3212 - val_accuracy: 0.8743 - lr: 0.0010
# Epoch 9/200
# 282/282 [==============================] - 26s 92ms/step - loss: 0.2038 - accuracy: 0.9176 - val_loss: 0.5771 - val_accuracy: 0.7784 - lr: 0.0010
# Epoch 10/200
# 282/282 [==============================] - 26s 92ms/step - loss: 0.2023 - accuracy: 0.9169 - val_loss: 0.3669 - val_accuracy: 0.8423 - lr: 0.0010
# Epoch 11/200
# 282/282 [==============================] - 28s 99ms/step - loss: 0.1966 - accuracy: 0.9209 - val_loss: 0.4023 - val_accuracy: 0.8144 - lr: 0.0010
# Epoch 12/200
# 282/282 [==============================] - 26s 93ms/step - loss: 0.1814 - accuracy: 0.9267 - val_loss: 0.3295 - val_accuracy: 0.8723 - lr: 0.0010
# Epoch 13/200
# 282/282 [==============================] - 28s 100ms/step - loss: 0.1701 - accuracy: 0.9314 - val_loss: 0.3602 - val_accuracy: 0.8663 - lr: 0.0010
# Epoch 14/200
# 282/282 [==============================] - 26s 92ms/step - loss: 0.1738 - accuracy: 0.9287 - val_loss: 0.3568 - val_accuracy: 0.8643 - lr: 9.9900e-04
# Epoch 15/200
# 282/282 [==============================] - 26s 91ms/step - loss: 0.1703 - accuracy: 0.9280 - val_loss: 0.4217 - val_accuracy: 0.8643 - lr: 9.9900e-04
# 282/282 [==============================] - 26s 91ms/step - loss: 0.0773 - accuracy: 0.9714 - val_loss: 0.5757 - val_accuracy: 0.8703 - lr: 9.9700e-04
# Epoch 35/200
# 282/282 [==============================] - 26s 91ms/step - loss: 0.0825 - accuracy: 0.9651 - val_loss: 0.6731 - val_accuracy: 0.8543 - lr: 9.9700e-04
# Epoch 36/200
# 282/282 [==============================] - 25s 90ms/step - loss: 0.0856 - accuracy: 0.9667 - val_loss: 0.4545 - val_accuracy: 0.8703 - lr: 9.9601e-04
# Epoch 37/200
# 282/282 [==============================] - 25s 89ms/step - loss: 0.0738 - accuracy: 0.9722 - val_loss: 0.5478 - val_accuracy: 0.8723 - lr: 9.9601e-04
# Epoch 38/200
# 282/282 [==============================] - 25s 90ms/step - loss: 0.0641 - accuracy: 0.9760 - val_loss: 0.5326 - val_accuracy: 0.8762 - lr: 9.9601e-04
# Epoch 39/200
# 282/282 [==============================] - 26s 91ms/step - loss: 0.0733 - accuracy: 0.9687 - val_loss: 0.5736 - val_accuracy: 0.8523 - lr: 9.9601e-04
# Epoch 40/200
# 282/282 [==============================] - 26s 93ms/step - loss: 0.0700 - accuracy: 0.9738 - val_loss: 0.5375 - val_accuracy: 0.8583 - lr: 9.9601e-04
# Epoch 41/200
# 282/282 [==============================] - 26s 91ms/step - loss: 0.0667 - accuracy: 0.9729 - val_loss: 0.7125 - val_accuracy: 0.8543 - lr: 9.9501e-04
# Epoch 42/200
# 282/282 [==============================] - 26s 92ms/step - loss: 0.0623 - accuracy: 0.9791 - val_loss: 0.5848 - val_accuracy: 0.8603 - lr: 9.9501e-04
# Epoch 43/200
# 282/282 [==============================] - 26s 92ms/step - loss: 0.0709 - accuracy: 0.9716 - val_loss: 0.5532 - val_accuracy: 0.8683 - lr: 9.9501e-04
# Epoch 44/200
# 282/282 [==============================] - 26s 91ms/step - loss: 0.0623 - accuracy: 0.9760 - val_loss: 0.5998 - val_accuracy: 0.8703 - lr: 9.9501e-04
# Epoch 45/200
# 282/282 [==============================] - 26s 92ms/step - loss: 0.0685 - accuracy: 0.9734 - val_loss: 0.6967 - val_accuracy: 0.8383 - lr: 9.9501e-04
# Epoch 46/200
# 282/282 [==============================] - 26s 92ms/step - loss: 0.0624 - accuracy: 0.9753 - val_loss: 0.5762 - val_accuracy: 0.8683 - lr: 9.9402e-04
# Epoch 47/200
# 282/282 [==============================] - 26s 91ms/step - loss: 0.0569 - accuracy: 0.9789 - val_loss: 0.6017 - val_accuracy: 0.8643 - lr: 9.9402e-04
# Epoch 48/200
# 282/282 [==============================] - 26s 91ms/step - loss: 0.0593 - accuracy: 0.9787 - val_loss: 0.6093 - val_accuracy: 0.8603 - lr: 9.9402e-04
# Epoch 49/200
# 282/282 [==============================] - 26s 92ms/step - loss: 0.0586 - accuracy: 0.9791 - val_loss: 0.5518 - val_accuracy: 0.8743 - lr: 9.9402e-04
# Epoch 50/200
# 282/282 [==============================] - 26s 93ms/step - loss: 0.0589 - accuracy: 0.9785 - val_loss: 0.6328 - val_accuracy: 0.8583 - lr: 9.9402e-04

# %%
# Plot the training histories
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the model
model.save('ConvNeXtBase')
