# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Progetto AN2DL/3_KerasApplicationsTesting
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/Progetto AN2DL/FeatureExtractorTesting

# %% [markdown]
# ### Import libraries

# %%
# Hide warnings
seed  = 42
import os

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold

# %% [markdown]
# ### Load and process the dataset

# %%
# Load data
data = np.load('../clean_data.npz', allow_pickle=True)

# Save labels in a new list (image pixel values are float in [0, 1])
images = data['data']

# Save labels in a new list
labels = data['labels']

# Print data shape
print(images.shape, labels.shape)
# Out:
# (5004, 96, 96, 3) (5004,)

# %%
# Number of images to display
num_img = 100

# Create subplots for displaying images
fig, axes = plt.subplots(10, num_img//10, figsize=(20, 20))
for i in range(num_img):
    ax = axes[i%10, i%num_img//10]
    ax.imshow(np.clip(images[i], 0, 255))  # Display clipped item images
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Convert labels from string to integer
num_labels = []
for label in labels:
  if label == "healthy":
    num_labels.append(0)
  else:
    num_labels.append(1)

# Convert labels in the one-hot encoding format
num_labels = np.array(num_labels)
labels = tfk.utils.to_categorical(num_labels, 2)

# Split data into train and val sets
X_train, X_val, y_train, y_val = train_test_split(
    images,
    labels,
    test_size=0.1,
    stratify=labels
)

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (4503, 96, 96, 3), y_train shape: (4503, 2)
# X_val shape: (501, 96, 96, 3), y_val shape: (501, 2)

# %% [markdown]
# ### EfficientNetV2B3

# %%
# Import Feature Extractor with specified settings
feature_extractor = tfk.applications.EfficientNetV2B3(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    pooling='avg',
    include_preprocessing=True,
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b3_notop.h5
# 52606240/52606240 [==============================] - 0s 0us/step

# %% [markdown]
# ### Model

# %%
# Define network parameters/callbacks
dropout_rate = 1/10
learning_rate = 1e-3

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.999,
    mode='max',
    min_lr=1e-5
)

early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=20,
    restore_best_weights=True
)

# %%
def build_model(feature_extractor, dropout_rate, learning_rate=0.001):
  # Use the supernet as feature extractor, i.e. freeze all its weigths
  feature_extractor.trainable = False

  # Create an input layer with shape (96, 96, 3)
  inputs = tfk.Input(shape=(96, 96, 3), name='Input')

  # Connect FeatureExtractor to the input
  x = feature_extractor(inputs)

  # Hidden layers
  x = tfkl.Dense(units=64, name='HiddenDense1')(x)
  x = tfkl.Activation('relu', name='HiddenActivation1')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)
  x = tfkl.Dense(units=64, name='HiddenDense2')(dropout)
  x = tfkl.Activation('relu', name='HiddenActivation2')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)

  # Add a Dense layer with 2 unit and softmax activation as the classifier
  outputs = tfkl.Dense(2, activation='softmax')(dropout)

  # Create a Model connecting input and output
  model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

  # Compile the model with Categorical Cross-Entropy loss and Adam optimizer
  model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                optimizer=tfk.optimizers.Adam(learning_rate),
                metrics=['accuracy'])

  # Return the model
  return model

# %%
model = build_model(feature_extractor, dropout_rate, learning_rate)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  efficientnetv2-b3 (Functio  (None, 1536)              12930622
#  nal)
#
#  HiddenDense1 (Dense)        (None, 64)                98368
#
#  HiddenActivation1 (Activat  (None, 64)                0
#  ion)
#
#  dropout (Dropout)           (None, 64)                0
#
#  HiddenDense2 (Dense)        (None, 64)                4160
#
#  HiddenActivation2 (Activat  (None, 64)                0
#  ion)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 13033280 (49.72 MB)
# Trainable params: 102658 (401.01 KB)
# Non-trainable params: 12930622 (49.33 MB)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = X_train*255,
    y = y_train,
    batch_size = 16,
    epochs = 200,
    validation_data = (X_val*255, y_val),
    callbacks = [early_stopping, lr_scheduler]
).history
# Out:
# Epoch 1/200
# 282/282 [==============================] - 33s 37ms/step - loss: 0.5223 - accuracy: 0.7393 - val_loss: 0.4588 - val_accuracy: 0.7864 - lr: 0.0010
# Epoch 2/200
# 282/282 [==============================] - 5s 19ms/step - loss: 0.4396 - accuracy: 0.8035 - val_loss: 0.4327 - val_accuracy: 0.8104 - lr: 0.0010
# Epoch 3/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.3979 - accuracy: 0.8217 - val_loss: 0.4350 - val_accuracy: 0.8104 - lr: 0.0010
# Epoch 4/200
# 282/282 [==============================] - 6s 23ms/step - loss: 0.3821 - accuracy: 0.8334 - val_loss: 0.3903 - val_accuracy: 0.8244 - lr: 0.0010
# Epoch 5/200
# 282/282 [==============================] - 6s 21ms/step - loss: 0.3563 - accuracy: 0.8441 - val_loss: 0.4041 - val_accuracy: 0.8283 - lr: 0.0010
# Epoch 6/200
# 282/282 [==============================] - 7s 24ms/step - loss: 0.3480 - accuracy: 0.8490 - val_loss: 0.3880 - val_accuracy: 0.8383 - lr: 0.0010
# Epoch 7/200
# 282/282 [==============================] - 5s 19ms/step - loss: 0.3388 - accuracy: 0.8448 - val_loss: 0.3861 - val_accuracy: 0.8463 - lr: 0.0010
# Epoch 8/200
# 282/282 [==============================] - 6s 23ms/step - loss: 0.3273 - accuracy: 0.8563 - val_loss: 0.4047 - val_accuracy: 0.8343 - lr: 0.0010
# Epoch 9/200
# 282/282 [==============================] - 5s 18ms/step - loss: 0.2312 - accuracy: 0.9052 - val_loss: 0.4237 - val_accuracy: 0.8443 - lr: 9.9800e-04
# Epoch 25/200
# 282/282 [==============================] - 6s 22ms/step - loss: 0.2184 - accuracy: 0.9078 - val_loss: 0.3527 - val_accuracy: 0.8483 - lr: 9.9800e-04
# Epoch 26/200
# 282/282 [==============================] - 5s 18ms/step - loss: 0.2236 - accuracy: 0.9005 - val_loss: 0.3824 - val_accuracy: 0.8543 - lr: 9.9800e-04
# Epoch 27/200
# 282/282 [==============================] - 6s 22ms/step - loss: 0.2033 - accuracy: 0.9169 - val_loss: 0.4335 - val_accuracy: 0.8463 - lr: 9.9800e-04
# Epoch 28/200
# 282/282 [==============================] - 5s 17ms/step - loss: 0.2237 - accuracy: 0.9061 - val_loss: 0.3941 - val_accuracy: 0.8563 - lr: 9.9700e-04
# Epoch 29/200
# 282/282 [==============================] - 6s 22ms/step - loss: 0.2183 - accuracy: 0.9058 - val_loss: 0.4044 - val_accuracy: 0.8603 - lr: 9.9700e-04
# Epoch 30/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.2116 - accuracy: 0.9138 - val_loss: 0.3935 - val_accuracy: 0.8523 - lr: 9.9700e-04
# Epoch 31/200
# 282/282 [==============================] - 5s 18ms/step - loss: 0.2042 - accuracy: 0.9161 - val_loss: 0.3816 - val_accuracy: 0.8523 - lr: 9.9700e-04
# Epoch 32/200
# 282/282 [==============================] - 6s 22ms/step - loss: 0.2061 - accuracy: 0.9116 - val_loss: 0.3955 - val_accuracy: 0.8443 - lr: 9.9700e-04
# Epoch 33/200
# 282/282 [==============================] - 5s 18ms/step - loss: 0.2070 - accuracy: 0.9141 - val_loss: 0.3837 - val_accuracy: 0.8543 - lr: 9.9601e-04
# Epoch 34/200
# 282/282 [==============================] - 7s 24ms/step - loss: 0.1864 - accuracy: 0.9236 - val_loss: 0.3665 - val_accuracy: 0.8643 - lr: 9.9601e-04
# Epoch 35/200
# 282/282 [==============================] - 5s 17ms/step - loss: 0.1992 - accuracy: 0.9216 - val_loss: 0.4050 - val_accuracy: 0.8443 - lr: 9.9601e-04
# Epoch 36/200
# 282/282 [==============================] - 5s 19ms/step - loss: 0.1911 - accuracy: 0.9258 - val_loss: 0.3817 - val_accuracy: 0.8643 - lr: 9.9601e-04
# Epoch 37/200
# 282/282 [==============================] - 6s 23ms/step - loss: 0.1811 - accuracy: 0.9269 - val_loss: 0.3669 - val_accuracy: 0.8543 - lr: 9.9601e-04

# %%
# Plot the training histories
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the model
model.save('EfficientNetV2B3')
