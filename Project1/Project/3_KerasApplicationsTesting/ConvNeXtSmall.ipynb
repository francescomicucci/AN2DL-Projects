# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Progetto AN2DL/3_KerasApplicationsTesting
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/Progetto AN2DL/FeatureExtractorTesting

# %% [markdown]
# ### Import libraries

# %%
# Hide warnings
seed  = 42
import os

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold

# %% [markdown]
# ### Load and process the dataset

# %%
# Load data
data = np.load('../clean_data.npz', allow_pickle=True)

# Save labels in a new list (image pixel values are float in [0, 1])
images = data['data']

# Save labels in a new list
labels = data['labels']

# Print data shape
print(images.shape, labels.shape)
# Out:
# (5004, 96, 96, 3) (5004,)

# %%
# Number of images to display
num_img = 100

# Create subplots for displaying images
fig, axes = plt.subplots(10, num_img//10, figsize=(20, 20))
for i in range(num_img):
    ax = axes[i%10, i%num_img//10]
    ax.imshow(np.clip(images[i], 0, 255))  # Display clipped item images
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Convert labels from string to integer
num_labels = []
for label in labels:
  if label == "healthy":
    num_labels.append(0)
  else:
    num_labels.append(1)

# Convert labels in the one-hot encoding format
num_labels = np.array(num_labels)
labels = tfk.utils.to_categorical(num_labels, 2)

# Split data into train and val sets
X_train, X_val, y_train, y_val = train_test_split(
    images,
    labels,
    test_size=0.1,
    stratify=labels
)

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (4503, 96, 96, 3), y_train shape: (4503, 2)
# X_val shape: (501, 96, 96, 3), y_val shape: (501, 2)

# %% [markdown]
# ### ConvNeXtSmall

# %%
# Import Feature Extractor with specified settings
feature_extractor = tfk.applications.ConvNeXtSmall(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    pooling='avg',
    include_preprocessing=True,
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_small_notop.h5
# 198551472/198551472 [==============================] - 6s 0us/step

# %% [markdown]
# ### Model

# %%
# Define network parameters/callbacks
dropout_rate = 1/10
learning_rate = 1e-3

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.999,
    mode='max',
    min_lr=1e-5
)

early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=20,
    restore_best_weights=True
)

# %%
def build_model(feature_extractor, dropout_rate, learning_rate=0.001):
  # Use the supernet as feature extractor, i.e. freeze all its weigths
  feature_extractor.trainable = False

  # Create an input layer with shape (96, 96, 3)
  inputs = tfk.Input(shape=(96, 96, 3), name='Input')

  # Connect FeatureExtractor to the input
  x = feature_extractor(inputs)

  # Hidden layers
  x = tfkl.Dense(units=64, name='HiddenDense1')(x)
  x = tfkl.Activation('relu', name='HiddenActivation1')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)
  x = tfkl.Dense(units=64, name='HiddenDense2')(dropout)
  x = tfkl.Activation('relu', name='HiddenActivation2')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)

  # Add a Dense layer with 2 unit and softmax activation as the classifier
  outputs = tfkl.Dense(2, activation='softmax')(dropout)

  # Create a Model connecting input and output
  model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

  # Compile the model with Categorical Cross-Entropy loss and Adam optimizer
  model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                optimizer=tfk.optimizers.Adam(learning_rate),
                metrics=['accuracy'])

  # Return the model
  return model

# %%
model = build_model(feature_extractor, dropout_rate, learning_rate)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  convnext_small (Functional  (None, 768)               49454688
#  )
#
#  HiddenDense1 (Dense)        (None, 64)                49216
#
#  HiddenActivation1 (Activat  (None, 64)                0
#  ion)
#
#  dropout (Dropout)           (None, 64)                0
#
#  HiddenDense2 (Dense)        (None, 64)                4160
#
#  HiddenActivation2 (Activat  (None, 64)                0
#  ion)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 49508194 (188.86 MB)
# Trainable params: 53506 (209.01 KB)
# Non-trainable params: 49454688 (188.65 MB)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = X_train*255,
    y = y_train,
    batch_size = 16,
    epochs = 200,
    validation_data = (X_val*255, y_val),
    callbacks = [early_stopping, lr_scheduler]
).history
# Out:
# Epoch 1/200
# 282/282 [==============================] - 68s 128ms/step - loss: 0.5689 - accuracy: 0.7029 - val_loss: 0.4830 - val_accuracy: 0.7585 - lr: 0.0010
# Epoch 2/200
# 282/282 [==============================] - 22s 77ms/step - loss: 0.4676 - accuracy: 0.7742 - val_loss: 0.4416 - val_accuracy: 0.8024 - lr: 0.0010
# Epoch 3/200
# 282/282 [==============================] - 22s 79ms/step - loss: 0.4182 - accuracy: 0.8095 - val_loss: 0.4326 - val_accuracy: 0.8064 - lr: 0.0010
# Epoch 4/200
# 282/282 [==============================] - 22s 77ms/step - loss: 0.4031 - accuracy: 0.8161 - val_loss: 0.4109 - val_accuracy: 0.8064 - lr: 0.0010
# Epoch 5/200
# 282/282 [==============================] - 23s 81ms/step - loss: 0.3747 - accuracy: 0.8294 - val_loss: 0.4173 - val_accuracy: 0.8124 - lr: 0.0010
# Epoch 6/200
# 282/282 [==============================] - 21s 75ms/step - loss: 0.3610 - accuracy: 0.8399 - val_loss: 0.4091 - val_accuracy: 0.8004 - lr: 0.0010
# Epoch 7/200
# 282/282 [==============================] - 22s 78ms/step - loss: 0.3354 - accuracy: 0.8574 - val_loss: 0.4253 - val_accuracy: 0.8263 - lr: 0.0010
# Epoch 8/200
# 282/282 [==============================] - 22s 79ms/step - loss: 0.3283 - accuracy: 0.8543 - val_loss: 0.3851 - val_accuracy: 0.8383 - lr: 0.0010
# Epoch 9/200
# 282/282 [==============================] - 22s 76ms/step - loss: 0.2038 - accuracy: 0.9149 - val_loss: 0.4652 - val_accuracy: 0.8224 - lr: 9.9800e-04
# Epoch 25/200
# 282/282 [==============================] - 22s 80ms/step - loss: 0.2003 - accuracy: 0.9183 - val_loss: 0.4976 - val_accuracy: 0.8124 - lr: 9.9800e-04
# Epoch 26/200
# 282/282 [==============================] - 22s 79ms/step - loss: 0.1996 - accuracy: 0.9209 - val_loss: 0.5092 - val_accuracy: 0.8224 - lr: 9.9800e-04
# Epoch 27/200
# 282/282 [==============================] - 22s 79ms/step - loss: 0.1936 - accuracy: 0.9189 - val_loss: 0.4717 - val_accuracy: 0.8323 - lr: 9.9800e-04
# Epoch 28/200
# 282/282 [==============================] - 21s 75ms/step - loss: 0.1876 - accuracy: 0.9207 - val_loss: 0.5056 - val_accuracy: 0.8224 - lr: 9.9700e-04
# Epoch 29/200
# 282/282 [==============================] - 23s 80ms/step - loss: 0.1725 - accuracy: 0.9332 - val_loss: 0.4958 - val_accuracy: 0.8343 - lr: 9.9700e-04
# Epoch 30/200
# 282/282 [==============================] - 22s 78ms/step - loss: 0.1886 - accuracy: 0.9201 - val_loss: 0.4377 - val_accuracy: 0.8403 - lr: 9.9700e-04
# Epoch 31/200
# 282/282 [==============================] - 22s 80ms/step - loss: 0.1660 - accuracy: 0.9349 - val_loss: 0.5102 - val_accuracy: 0.8303 - lr: 9.9700e-04
# Epoch 32/200
# 282/282 [==============================] - 23s 83ms/step - loss: 0.1860 - accuracy: 0.9232 - val_loss: 0.5224 - val_accuracy: 0.8383 - lr: 9.9700e-04
# Epoch 33/200
# 282/282 [==============================] - 23s 81ms/step - loss: 0.1763 - accuracy: 0.9272 - val_loss: 0.4462 - val_accuracy: 0.8323 - lr: 9.9601e-04
# Epoch 34/200
# 282/282 [==============================] - 30s 105ms/step - loss: 0.1742 - accuracy: 0.9298 - val_loss: 0.5243 - val_accuracy: 0.8343 - lr: 9.9601e-04
# Epoch 35/200
# 282/282 [==============================] - 22s 78ms/step - loss: 0.1624 - accuracy: 0.9369 - val_loss: 0.5329 - val_accuracy: 0.8283 - lr: 9.9601e-04
# Epoch 36/200
# 282/282 [==============================] - 23s 81ms/step - loss: 0.1733 - accuracy: 0.9280 - val_loss: 0.5491 - val_accuracy: 0.8283 - lr: 9.9601e-04
# Epoch 37/200
# 282/282 [==============================] - 24s 85ms/step - loss: 0.1753 - accuracy: 0.9298 - val_loss: 0.5538 - val_accuracy: 0.8323 - lr: 9.9601e-04

# %%
# Plot the training histories
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the model
model.save('ConvNeXtSmall')
