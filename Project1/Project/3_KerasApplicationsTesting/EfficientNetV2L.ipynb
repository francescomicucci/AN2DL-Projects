# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Progetto AN2DL/3_KerasApplicationsTesting
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/Progetto AN2DL/FeatureExtractorTesting

# %% [markdown]
# ### Import libraries

# %%
# Hide warnings
seed  = 42
import os

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold

# %% [markdown]
# ### Load and process the dataset

# %%
# Load data
data = np.load('../clean_data.npz', allow_pickle=True)

# Save labels in a new list (image pixel values are float in [0, 1])
images = data['data']

# Save labels in a new list
labels = data['labels']

# Print data shape
print(images.shape, labels.shape)
# Out:
# (5004, 96, 96, 3) (5004,)

# %%
# Number of images to display
num_img = 100

# Create subplots for displaying images
fig, axes = plt.subplots(10, num_img//10, figsize=(20, 20))
for i in range(num_img):
    ax = axes[i%10, i%num_img//10]
    ax.imshow(np.clip(images[i], 0, 255))  # Display clipped item images
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Convert labels from string to integer
num_labels = []
for label in labels:
  if label == "healthy":
    num_labels.append(0)
  else:
    num_labels.append(1)

# Convert labels in the one-hot encoding format
num_labels = np.array(num_labels)
labels = tfk.utils.to_categorical(num_labels, 2)

# Split data into train and val sets
X_train, X_val, y_train, y_val = train_test_split(
    images,
    labels,
    test_size=0.1,
    stratify=labels
)

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (4503, 96, 96, 3), y_train shape: (4503, 2)
# X_val shape: (501, 96, 96, 3), y_val shape: (501, 2)

# %% [markdown]
# ### EfficientNetV2L

# %%
# Import Feature Extractor with specified settings
feature_extractor = tfk.applications.EfficientNetV2L(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    pooling='avg',
    include_preprocessing=True,
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-l_notop.h5
# 473176280/473176280 [==============================] - 6s 0us/step

# %% [markdown]
# ### Model

# %%
# Define network parameters/callbacks
dropout_rate = 1/10
learning_rate = 1e-3

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.999,
    mode='max',
    min_lr=1e-5
)

early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=20,
    restore_best_weights=True
)

# %%
def build_model(feature_extractor, dropout_rate, learning_rate=0.001):
  # Use the supernet as feature extractor, i.e. freeze all its weigths
  feature_extractor.trainable = False

  # Create an input layer with shape (96, 96, 3)
  inputs = tfk.Input(shape=(96, 96, 3), name='Input')

  # Connect FeatureExtractor to the input
  x = feature_extractor(inputs)

  # Hidden layers
  x = tfkl.Dense(units=64, name='HiddenDense1')(x)
  x = tfkl.Activation('relu', name='HiddenActivation1')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)
  x = tfkl.Dense(units=64, name='HiddenDense2')(dropout)
  x = tfkl.Activation('relu', name='HiddenActivation2')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)

  # Add a Dense layer with 2 unit and softmax activation as the classifier
  outputs = tfkl.Dense(2, activation='softmax')(dropout)

  # Create a Model connecting input and output
  model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

  # Compile the model with Categorical Cross-Entropy loss and Adam optimizer
  model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                optimizer=tfk.optimizers.Adam(learning_rate),
                metrics=['accuracy'])

  # Return the model
  return model

# %%
model = build_model(feature_extractor, dropout_rate, learning_rate)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  efficientnetv2-l (Function  (None, 1280)              117746848
#  al)
#
#  HiddenDense1 (Dense)        (None, 64)                81984
#
#  HiddenActivation1 (Activat  (None, 64)                0
#  ion)
#
#  dropout (Dropout)           (None, 64)                0
#
#  HiddenDense2 (Dense)        (None, 64)                4160
#
#  HiddenActivation2 (Activat  (None, 64)                0
#  ion)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 117833122 (449.50 MB)
# Trainable params: 86274 (337.01 KB)
# Non-trainable params: 117746848 (449.17 MB)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = X_train*255,
    y = y_train,
    batch_size = 16,
    epochs = 200,
    validation_data = (X_val*255, y_val),
    callbacks = [early_stopping, lr_scheduler]
).history
# Out:
# Epoch 1/200
# 282/282 [==============================] - 73s 109ms/step - loss: 0.5365 - accuracy: 0.7284 - val_loss: 0.4495 - val_accuracy: 0.8064 - lr: 0.0010
# Epoch 2/200
# 282/282 [==============================] - 18s 64ms/step - loss: 0.4335 - accuracy: 0.7966 - val_loss: 0.4304 - val_accuracy: 0.8004 - lr: 0.0010
# Epoch 3/200
# 282/282 [==============================] - 18s 65ms/step - loss: 0.3924 - accuracy: 0.8274 - val_loss: 0.4233 - val_accuracy: 0.7984 - lr: 0.0010
# Epoch 4/200
# 282/282 [==============================] - 20s 71ms/step - loss: 0.3803 - accuracy: 0.8277 - val_loss: 0.3931 - val_accuracy: 0.8303 - lr: 0.0010
# Epoch 5/200
# 282/282 [==============================] - 18s 65ms/step - loss: 0.3682 - accuracy: 0.8414 - val_loss: 0.4022 - val_accuracy: 0.8184 - lr: 0.0010
# Epoch 6/200
# 282/282 [==============================] - 19s 67ms/step - loss: 0.3593 - accuracy: 0.8354 - val_loss: 0.3767 - val_accuracy: 0.8323 - lr: 0.0010
# Epoch 7/200
# 282/282 [==============================] - 18s 65ms/step - loss: 0.3427 - accuracy: 0.8517 - val_loss: 0.3846 - val_accuracy: 0.8204 - lr: 0.0010
# Epoch 8/200
# 282/282 [==============================] - 18s 64ms/step - loss: 0.3334 - accuracy: 0.8594 - val_loss: 0.3760 - val_accuracy: 0.8383 - lr: 0.0010
# Epoch 9/200
# 282/282 [==============================] - 19s 66ms/step - loss: 0.3120 - accuracy: 0.8634 - val_loss: 0.3757 - val_accuracy: 0.8463 - lr: 0.0010
# Epoch 10/200
# 282/282 [==============================] - 18s 64ms/step - loss: 0.3245 - accuracy: 0.8581 - val_loss: 0.3753 - val_accuracy: 0.8383 - lr: 0.0010
# Epoch 11/200
# 282/282 [==============================] - 18s 64ms/step - loss: 0.3078 - accuracy: 0.8719 - val_loss: 0.3617 - val_accuracy: 0.8443 - lr: 0.0010
# Epoch 12/200
# 282/282 [==============================] - 18s 64ms/step - loss: 0.3043 - accuracy: 0.8679 - val_loss: 0.4007 - val_accuracy: 0.8343 - lr: 0.0010
# Epoch 13/200
# 282/282 [==============================] - 19s 66ms/step - loss: 0.2884 - accuracy: 0.8807 - val_loss: 0.3896 - val_accuracy: 0.8303 - lr: 0.0010
# Epoch 14/200
# 282/282 [==============================] - 18s 65ms/step - loss: 0.2774 - accuracy: 0.8814 - val_loss: 0.3813 - val_accuracy: 0.8403 - lr: 0.0010
# Epoch 15/200
# 282/282 [==============================] - 18s 62ms/step - loss: 0.2826 - accuracy: 0.8803 - val_loss: 0.3897 - val_accuracy: 0.8263 - lr: 9.9900e-04
# Epoch 16/200
# Epoch 35/200
# 282/282 [==============================] - 18s 64ms/step - loss: 0.1978 - accuracy: 0.9156 - val_loss: 0.3692 - val_accuracy: 0.8523 - lr: 9.9900e-04
# Epoch 36/200
# 282/282 [==============================] - 18s 64ms/step - loss: 0.2001 - accuracy: 0.9174 - val_loss: 0.3600 - val_accuracy: 0.8623 - lr: 9.9900e-04
# Epoch 37/200
# 282/282 [==============================] - 18s 64ms/step - loss: 0.1838 - accuracy: 0.9274 - val_loss: 0.3689 - val_accuracy: 0.8683 - lr: 9.9800e-04
# Epoch 38/200
# 282/282 [==============================] - 18s 64ms/step - loss: 0.1897 - accuracy: 0.9232 - val_loss: 0.3999 - val_accuracy: 0.8483 - lr: 9.9800e-04
# Epoch 39/200
# 282/282 [==============================] - 18s 64ms/step - loss: 0.1902 - accuracy: 0.9249 - val_loss: 0.3979 - val_accuracy: 0.8503 - lr: 9.9800e-04
# Epoch 40/200
# 282/282 [==============================] - 18s 63ms/step - loss: 0.1865 - accuracy: 0.9214 - val_loss: 0.3536 - val_accuracy: 0.8483 - lr: 9.9800e-04
# Epoch 41/200
# 282/282 [==============================] - 18s 65ms/step - loss: 0.1823 - accuracy: 0.9225 - val_loss: 0.3573 - val_accuracy: 0.8663 - lr: 9.9800e-04
# Epoch 42/200
# 282/282 [==============================] - 18s 64ms/step - loss: 0.1729 - accuracy: 0.9294 - val_loss: 0.4072 - val_accuracy: 0.8323 - lr: 9.9700e-04
# Epoch 43/200
# 282/282 [==============================] - 18s 62ms/step - loss: 0.1720 - accuracy: 0.9283 - val_loss: 0.3979 - val_accuracy: 0.8423 - lr: 9.9700e-04
# Epoch 44/200
# 282/282 [==============================] - 18s 63ms/step - loss: 0.1709 - accuracy: 0.9305 - val_loss: 0.4107 - val_accuracy: 0.8443 - lr: 9.9700e-04
# Epoch 45/200
# 282/282 [==============================] - 18s 62ms/step - loss: 0.1709 - accuracy: 0.9332 - val_loss: 0.4311 - val_accuracy: 0.8483 - lr: 9.9700e-04
# Epoch 46/200
# 282/282 [==============================] - 17s 62ms/step - loss: 0.1663 - accuracy: 0.9343 - val_loss: 0.3940 - val_accuracy: 0.8463 - lr: 9.9700e-04
# Epoch 47/200
# 282/282 [==============================] - 18s 64ms/step - loss: 0.1719 - accuracy: 0.9303 - val_loss: 0.3962 - val_accuracy: 0.8443 - lr: 9.9601e-04
# Epoch 48/200
# 282/282 [==============================] - 18s 64ms/step - loss: 0.1646 - accuracy: 0.9354 - val_loss: 0.4502 - val_accuracy: 0.8503 - lr: 9.9601e-04
# Epoch 49/200
# 282/282 [==============================] - 17s 62ms/step - loss: 0.1667 - accuracy: 0.9332 - val_loss: 0.4457 - val_accuracy: 0.8463 - lr: 9.9601e-04
# Epoch 50/200
# 282/282 [==============================] - 18s 64ms/step - loss: 0.1632 - accuracy: 0.9325 - val_loss: 0.4066 - val_accuracy: 0.8463 - lr: 9.9601e-04
# Epoch 51/200
# 282/282 [==============================] - 19s 66ms/step - loss: 0.1602 - accuracy: 0.9332 - val_loss: 0.4470 - val_accuracy: 0.8603 - lr: 9.9601e-04

# %%
# Plot the training histories
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the model
model.save('EfficientNetV2L')
