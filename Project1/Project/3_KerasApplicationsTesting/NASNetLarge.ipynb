# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Progetto AN2DL/3_KerasApplicationsTesting
# Out:
# Mounted at /gdrive
# /gdrive/.shortcut-targets-by-id/1ygSQdg0_3KzCXK0mWufNykWjfoYjWqKH/Progetto AN2DL/FeatureExtractorTesting

# %% [markdown]
# ### Import libraries

# %%
# Hide warnings
seed  = 42
import os

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold

# %% [markdown]
# ### Load and process the dataset

# %%
# Load data
data = np.load('../clean_data.npz', allow_pickle=True)

# Save labels in a new list (image pixel values are float in [0, 1])
images = data['data']

# Save labels in a new list
labels = data['labels']

# Print data shape
print(images.shape, labels.shape)
# Out:
# (5004, 96, 96, 3) (5004,)

# %%
# Number of images to display
num_img = 100

# Create subplots for displaying images
fig, axes = plt.subplots(10, num_img//10, figsize=(20, 20))
for i in range(num_img):
    ax = axes[i%10, i%num_img//10]
    ax.imshow(np.clip(images[i], 0, 255))  # Display clipped item images
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Convert labels from string to integer
num_labels = []
for label in labels:
  if label == "healthy":
    num_labels.append(0)
  else:
    num_labels.append(1)

# Convert labels in the one-hot encoding format
num_labels = np.array(num_labels)
labels = tfk.utils.to_categorical(num_labels, 2)

# Split data into train and val sets
X_train, X_val, y_train, y_val = train_test_split(
    images,
    labels,
    test_size=0.1,
    stratify=labels
)

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (4503, 96, 96, 3), y_train shape: (4503, 2)
# X_val shape: (501, 96, 96, 3), y_val shape: (501, 2)

# %% [markdown]
# ### NASNetLarge

# %%
# Import Feature Extractor with specified settings
feature_extractor = tfk.applications.NASNetLarge(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    pooling='avg',
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-large-no-top.h5
# 343610240/343610240 [==============================] - 2s 0us/step

# %% [markdown]
# ### Model

# %%
# Define network parameters/callbacks
dropout_rate = 1/10
learning_rate = 1e-3

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.999,
    mode='max',
    min_lr=1e-5
)

early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=20,
    restore_best_weights=True
)

# %%
def build_model(feature_extractor, dropout_rate, learning_rate=0.001):
  # Use the supernet as feature extractor, i.e. freeze all its weigths
  feature_extractor.trainable = False

  # Create an input layer with shape (96, 96, 3)
  inputs = tfk.Input(shape=(96, 96, 3), name='Input')

  # Connect FeatureExtractor to the input
  x = feature_extractor(inputs)

  # Hidden layers
  x = tfkl.Dense(units=64, name='HiddenDense1')(x)
  x = tfkl.Activation('relu', name='HiddenActivation1')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)
  x = tfkl.Dense(units=64, name='HiddenDense2')(dropout)
  x = tfkl.Activation('relu', name='HiddenActivation2')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)

  # Add a Dense layer with 2 unit and softmax activation as the classifier
  outputs = tfkl.Dense(2, activation='softmax')(dropout)

  # Create a Model connecting input and output
  model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

  # Compile the model with Categorical Cross-Entropy loss and Adam optimizer
  model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                optimizer=tfk.optimizers.Adam(learning_rate),
                metrics=['accuracy'])

  # Return the model
  return model

# %%
model = build_model(feature_extractor, dropout_rate, learning_rate)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  NASNet (Functional)         (None, 4032)              84916818
#
#  HiddenDense1 (Dense)        (None, 64)                258112
#
#  HiddenActivation1 (Activat  (None, 64)                0
#  ion)
#
#  dropout (Dropout)           (None, 64)                0
#
#  HiddenDense2 (Dense)        (None, 64)                4160
#
#  HiddenActivation2 (Activat  (None, 64)                0
#  ion)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 85179220 (324.93 MB)
# Trainable params: 262402 (1.00 MB)
# Non-trainable params: 84916818 (323.93 MB)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = preprocess_input(X_train*255),
    y = y_train,
    batch_size = 16,
    epochs = 200,
    validation_data = (preprocess_input(X_val*255), y_val),
    callbacks = [early_stopping, lr_scheduler]
).history
# Out:
# Epoch 1/200
# 282/282 [==============================] - 58s 111ms/step - loss: 0.6023 - accuracy: 0.6973 - val_loss: 0.5560 - val_accuracy: 0.7545 - lr: 0.0010
# Epoch 2/200
# 282/282 [==============================] - 23s 82ms/step - loss: 0.4936 - accuracy: 0.7710 - val_loss: 0.5324 - val_accuracy: 0.7665 - lr: 0.0010
# Epoch 3/200
# 282/282 [==============================] - 23s 80ms/step - loss: 0.4372 - accuracy: 0.8044 - val_loss: 0.5335 - val_accuracy: 0.7645 - lr: 0.0010
# Epoch 4/200
# 282/282 [==============================] - 22s 78ms/step - loss: 0.3835 - accuracy: 0.8341 - val_loss: 0.5690 - val_accuracy: 0.7445 - lr: 0.0010
# Epoch 5/200
# 282/282 [==============================] - 22s 79ms/step - loss: 0.3241 - accuracy: 0.8652 - val_loss: 0.6802 - val_accuracy: 0.7525 - lr: 0.0010
# Epoch 6/200
# 282/282 [==============================] - 22s 77ms/step - loss: 0.2839 - accuracy: 0.8841 - val_loss: 0.6111 - val_accuracy: 0.7665 - lr: 0.0010
# Epoch 7/200
# 282/282 [==============================] - 23s 81ms/step - loss: 0.2246 - accuracy: 0.9076 - val_loss: 0.7971 - val_accuracy: 0.7565 - lr: 0.0010
# Epoch 8/200
# 282/282 [==============================] - 22s 79ms/step - loss: 0.1971 - accuracy: 0.9245 - val_loss: 0.7698 - val_accuracy: 0.7445 - lr: 9.9900e-04
# Epoch 9/200
# 282/282 [==============================] - 22s 77ms/step - loss: 0.1905 - accuracy: 0.9296 - val_loss: 0.8834 - val_accuracy: 0.7625 - lr: 9.9900e-04
# Epoch 10/200
# 282/282 [==============================] - 22s 79ms/step - loss: 0.1567 - accuracy: 0.9438 - val_loss: 0.8046 - val_accuracy: 0.7585 - lr: 9.9900e-04
# Epoch 11/200
# 282/282 [==============================] - 22s 79ms/step - loss: 0.1294 - accuracy: 0.9525 - val_loss: 1.0139 - val_accuracy: 0.7365 - lr: 9.9900e-04
# Epoch 12/200
# 282/282 [==============================] - 23s 80ms/step - loss: 0.1128 - accuracy: 0.9587 - val_loss: 1.1432 - val_accuracy: 0.7545 - lr: 9.9900e-04
# Epoch 13/200
# 282/282 [==============================] - 22s 79ms/step - loss: 0.0489 - accuracy: 0.9840 - val_loss: 1.6046 - val_accuracy: 0.7725 - lr: 9.9700e-04
# Epoch 31/200
# 282/282 [==============================] - 22s 78ms/step - loss: 0.0443 - accuracy: 0.9869 - val_loss: 2.2562 - val_accuracy: 0.7605 - lr: 9.9601e-04
# Epoch 32/200
# 282/282 [==============================] - 22s 79ms/step - loss: 0.0635 - accuracy: 0.9838 - val_loss: 1.5387 - val_accuracy: 0.7764 - lr: 9.9601e-04
# Epoch 33/200
# 282/282 [==============================] - 22s 77ms/step - loss: 0.0494 - accuracy: 0.9829 - val_loss: 1.5187 - val_accuracy: 0.7545 - lr: 9.9601e-04
# Epoch 34/200
# 282/282 [==============================] - 23s 80ms/step - loss: 0.0334 - accuracy: 0.9862 - val_loss: 1.4792 - val_accuracy: 0.7804 - lr: 9.9601e-04
# Epoch 35/200
# 282/282 [==============================] - 22s 79ms/step - loss: 0.0407 - accuracy: 0.9849 - val_loss: 1.6828 - val_accuracy: 0.7565 - lr: 9.9601e-04
# Epoch 36/200
# 282/282 [==============================] - 22s 79ms/step - loss: 0.0420 - accuracy: 0.9853 - val_loss: 1.5565 - val_accuracy: 0.7764 - lr: 9.9501e-04
# Epoch 37/200
# 282/282 [==============================] - 22s 78ms/step - loss: 0.0522 - accuracy: 0.9825 - val_loss: 1.5091 - val_accuracy: 0.7585 - lr: 9.9501e-04
# Epoch 38/200
# 282/282 [==============================] - 23s 80ms/step - loss: 0.0447 - accuracy: 0.9862 - val_loss: 1.4445 - val_accuracy: 0.7585 - lr: 9.9501e-04
# Epoch 39/200
# 282/282 [==============================] - 22s 79ms/step - loss: 0.0373 - accuracy: 0.9873 - val_loss: 1.7085 - val_accuracy: 0.7605 - lr: 9.9501e-04
# Epoch 40/200
# 282/282 [==============================] - 22s 79ms/step - loss: 0.0456 - accuracy: 0.9862 - val_loss: 1.6827 - val_accuracy: 0.7764 - lr: 9.9501e-04
# Epoch 41/200
# 282/282 [==============================] - 22s 79ms/step - loss: 0.0291 - accuracy: 0.9911 - val_loss: 1.8753 - val_accuracy: 0.7645 - lr: 9.9402e-04
# Epoch 42/200
# 282/282 [==============================] - 22s 79ms/step - loss: 0.0235 - accuracy: 0.9909 - val_loss: 1.8837 - val_accuracy: 0.7585 - lr: 9.9402e-04
# Epoch 43/200
# 282/282 [==============================] - 23s 81ms/step - loss: 0.0334 - accuracy: 0.9896 - val_loss: 1.9371 - val_accuracy: 0.7425 - lr: 9.9402e-04
# Epoch 44/200
# 282/282 [==============================] - 23s 81ms/step - loss: 0.0328 - accuracy: 0.9896 - val_loss: 1.9698 - val_accuracy: 0.7325 - lr: 9.9402e-04
# Epoch 45/200
# 282/282 [==============================] - 23s 82ms/step - loss: 0.0399 - accuracy: 0.9880 - val_loss: 1.6522 - val_accuracy: 0.7605 - lr: 9.9402e-04

# %%
# Plot the training histories
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the model
model.save('NASNetLarge')
