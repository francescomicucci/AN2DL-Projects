# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Progetto AN2DL/3_KerasApplicationsTesting
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/Progetto AN2DL/FeatureExtractorTesting

# %% [markdown]
# ### Import libraries

# %%
# Hide warnings
seed  = 42
import os

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold

# %% [markdown]
# ### Load and process the dataset

# %%
# Load data
data = np.load('../clean_data.npz', allow_pickle=True)

# Save labels in a new list (image pixel values are float in [0, 1])
images = data['data']

# Save labels in a new list
labels = data['labels']

# Print data shape
print(images.shape, labels.shape)
# Out:
# (5004, 96, 96, 3) (5004,)

# %%
# Number of images to display
num_img = 100

# Create subplots for displaying images
fig, axes = plt.subplots(10, num_img//10, figsize=(20, 20))
for i in range(num_img):
    ax = axes[i%10, i%num_img//10]
    ax.imshow(np.clip(images[i], 0, 255))  # Display clipped item images
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Convert labels from string to integer
num_labels = []
for label in labels:
  if label == "healthy":
    num_labels.append(0)
  else:
    num_labels.append(1)

# Convert labels in the one-hot encoding format
num_labels = np.array(num_labels)
labels = tfk.utils.to_categorical(num_labels, 2)

# Split data into train and val sets
X_train, X_val, y_train, y_val = train_test_split(
    images,
    labels,
    test_size=0.1,
    stratify=labels
)

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (4503, 96, 96, 3), y_train shape: (4503, 2)
# X_val shape: (501, 96, 96, 3), y_val shape: (501, 2)

# %% [markdown]
# ### DenseNet201

# %%
# Import Feature Extractor with specified settings
feature_extractor = tfk.applications.DenseNet201(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    pooling='avg',
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 [==============================] - 0s 0us/step

# %% [markdown]
# ### Model

# %%
# Define network parameters/callbacks
dropout_rate = 1/10
learning_rate = 1e-3

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.999,
    mode='max',
    min_lr=1e-5
)

early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=20,
    restore_best_weights=True
)

# %%
def build_model(feature_extractor, dropout_rate, learning_rate=0.001):
  # Use the supernet as feature extractor, i.e. freeze all its weigths
  feature_extractor.trainable = False

  # Create an input layer with shape (96, 96, 3)
  inputs = tfk.Input(shape=(96, 96, 3), name='Input')

  # Connect FeatureExtractor to the input
  x = feature_extractor(inputs)

  # Hidden layers
  x = tfkl.Dense(units=64, name='HiddenDense1')(x)
  x = tfkl.Activation('relu', name='HiddenActivation1')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)
  x = tfkl.Dense(units=64, name='HiddenDense2')(dropout)
  x = tfkl.Activation('relu', name='HiddenActivation2')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)

  # Add a Dense layer with 2 unit and softmax activation as the classifier
  outputs = tfkl.Dense(2, activation='softmax')(dropout)

  # Create a Model connecting input and output
  model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

  # Compile the model with Categorical Cross-Entropy loss and Adam optimizer
  model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                optimizer=tfk.optimizers.Adam(learning_rate),
                metrics=['accuracy'])

  # Return the model
  return model

# %%
model = build_model(feature_extractor, dropout_rate, learning_rate)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  densenet201 (Functional)    (None, 1920)              18321984
#
#  HiddenDense1 (Dense)        (None, 64)                122944
#
#  HiddenActivation1 (Activat  (None, 64)                0
#  ion)
#
#  dropout (Dropout)           (None, 64)                0
#
#  HiddenDense2 (Dense)        (None, 64)                4160
#
#  HiddenActivation2 (Activat  (None, 64)                0
#  ion)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 18449218 (70.38 MB)
# Trainable params: 127234 (497.01 KB)
# Non-trainable params: 18321984 (69.89 MB)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = preprocess_input(X_train*255),
    y = y_train,
    batch_size = 16,
    epochs = 200,
    validation_data = (preprocess_input(X_val*255), y_val),
    callbacks = [early_stopping, lr_scheduler]
).history
# Out:
# Epoch 1/200
# 282/282 [==============================] - 41s 64ms/step - loss: 0.5043 - accuracy: 0.7528 - val_loss: 0.3946 - val_accuracy: 0.8184 - lr: 0.0010
# Epoch 2/200
# 282/282 [==============================] - 11s 40ms/step - loss: 0.4116 - accuracy: 0.8072 - val_loss: 0.3626 - val_accuracy: 0.8403 - lr: 0.0010
# Epoch 3/200
# 282/282 [==============================] - 10s 36ms/step - loss: 0.3663 - accuracy: 0.8310 - val_loss: 0.3658 - val_accuracy: 0.8503 - lr: 0.0010
# Epoch 4/200
# 282/282 [==============================] - 10s 34ms/step - loss: 0.3345 - accuracy: 0.8548 - val_loss: 0.3681 - val_accuracy: 0.8403 - lr: 0.0010
# Epoch 5/200
# 282/282 [==============================] - 10s 36ms/step - loss: 0.3009 - accuracy: 0.8659 - val_loss: 0.3896 - val_accuracy: 0.8244 - lr: 0.0010
# Epoch 6/200
# 282/282 [==============================] - 10s 36ms/step - loss: 0.2688 - accuracy: 0.8874 - val_loss: 0.4087 - val_accuracy: 0.8144 - lr: 0.0010
# Epoch 7/200
# 282/282 [==============================] - 10s 35ms/step - loss: 0.2527 - accuracy: 0.8883 - val_loss: 0.3974 - val_accuracy: 0.8423 - lr: 0.0010
# Epoch 8/200
# 282/282 [==============================] - 10s 37ms/step - loss: 0.2197 - accuracy: 0.9065 - val_loss: 0.4063 - val_accuracy: 0.8463 - lr: 0.0010
# Epoch 9/200
# 282/282 [==============================] - 11s 38ms/step - loss: 0.1891 - accuracy: 0.9223 - val_loss: 0.4823 - val_accuracy: 0.8104 - lr: 9.9900e-04
# Epoch 10/200
# 282/282 [==============================] - 10s 37ms/step - loss: 0.1727 - accuracy: 0.9303 - val_loss: 0.4941 - val_accuracy: 0.8124 - lr: 9.9900e-04
# Epoch 11/200
# 282/282 [==============================] - 10s 37ms/step - loss: 0.1627 - accuracy: 0.9332 - val_loss: 0.4450 - val_accuracy: 0.8244 - lr: 9.9900e-04
# Epoch 12/200
# 282/282 [==============================] - 10s 36ms/step - loss: 0.1360 - accuracy: 0.9469 - val_loss: 0.4546 - val_accuracy: 0.8463 - lr: 9.9900e-04
# Epoch 13/200
# 282/282 [==============================] - 10s 37ms/step - loss: 0.1291 - accuracy: 0.9503 - val_loss: 0.5256 - val_accuracy: 0.8343 - lr: 9.9900e-04
# Epoch 14/200
# 282/282 [==============================] - 10s 36ms/step - loss: 0.1219 - accuracy: 0.9523 - val_loss: 0.5450 - val_accuracy: 0.8124 - lr: 9.9800e-04
# Epoch 15/200
# 282/282 [==============================] - 11s 38ms/step - loss: 0.1023 - accuracy: 0.9620 - val_loss: 0.4816 - val_accuracy: 0.8583 - lr: 9.9800e-04
# Epoch 16/200
# 282/282 [==============================] - 10s 35ms/step - loss: 0.0841 - accuracy: 0.9656 - val_loss: 0.5645 - val_accuracy: 0.8084 - lr: 9.9800e-04
# Epoch 17/200
# 282/282 [==============================] - 11s 38ms/step - loss: 0.0770 - accuracy: 0.9709 - val_loss: 0.5856 - val_accuracy: 0.8543 - lr: 9.9800e-04
# Epoch 18/200
# 282/282 [==============================] - 10s 37ms/step - loss: 0.0793 - accuracy: 0.9700 - val_loss: 0.6360 - val_accuracy: 0.8443 - lr: 9.9800e-04
# Epoch 19/200
# 282/282 [==============================] - 11s 38ms/step - loss: 0.0751 - accuracy: 0.9718 - val_loss: 0.6317 - val_accuracy: 0.8064 - lr: 9.9800e-04
# Epoch 20/200
# 282/282 [==============================] - 10s 36ms/step - loss: 0.0634 - accuracy: 0.9782 - val_loss: 0.6515 - val_accuracy: 0.8224 - lr: 9.9800e-04
# Epoch 21/200
# 282/282 [==============================] - 10s 36ms/step - loss: 0.0651 - accuracy: 0.9765 - val_loss: 0.6442 - val_accuracy: 0.8204 - lr: 9.9700e-04
# Epoch 22/200
# 282/282 [==============================] - 10s 37ms/step - loss: 0.0664 - accuracy: 0.9769 - val_loss: 0.5653 - val_accuracy: 0.8323 - lr: 9.9700e-04
# Epoch 23/200
# 282/282 [==============================] - 11s 38ms/step - loss: 0.0730 - accuracy: 0.9729 - val_loss: 0.7113 - val_accuracy: 0.8263 - lr: 9.9700e-04
# Epoch 24/200
# 282/282 [==============================] - 10s 37ms/step - loss: 0.0606 - accuracy: 0.9751 - val_loss: 0.7596 - val_accuracy: 0.8144 - lr: 9.9700e-04
# Epoch 25/200
# 282/282 [==============================] - 10s 35ms/step - loss: 0.0643 - accuracy: 0.9796 - val_loss: 0.7070 - val_accuracy: 0.8263 - lr: 9.9700e-04
# Epoch 26/200
# 282/282 [==============================] - 11s 39ms/step - loss: 0.0729 - accuracy: 0.9758 - val_loss: 0.6448 - val_accuracy: 0.8244 - lr: 9.9601e-04
# Epoch 27/200
# 282/282 [==============================] - 10s 37ms/step - loss: 0.0479 - accuracy: 0.9836 - val_loss: 0.6892 - val_accuracy: 0.8144 - lr: 9.9601e-04
# Epoch 28/200
# 282/282 [==============================] - 10s 37ms/step - loss: 0.0542 - accuracy: 0.9809 - val_loss: 0.7093 - val_accuracy: 0.8323 - lr: 9.9601e-04
# Epoch 29/200
# 282/282 [==============================] - 10s 35ms/step - loss: 0.0374 - accuracy: 0.9862 - val_loss: 0.8212 - val_accuracy: 0.8044 - lr: 9.9601e-04
# Epoch 30/200
# 282/282 [==============================] - 10s 37ms/step - loss: 0.0496 - accuracy: 0.9831 - val_loss: 0.7273 - val_accuracy: 0.8543 - lr: 9.9601e-04
# Epoch 31/200
# 282/282 [==============================] - 10s 37ms/step - loss: 0.0418 - accuracy: 0.9847 - val_loss: 0.7074 - val_accuracy: 0.8463 - lr: 9.9501e-04
# Epoch 32/200
# 282/282 [==============================] - 11s 38ms/step - loss: 0.0381 - accuracy: 0.9867 - val_loss: 0.9084 - val_accuracy: 0.8204 - lr: 9.9501e-04
# Epoch 33/200
# 282/282 [==============================] - 10s 34ms/step - loss: 0.0560 - accuracy: 0.9805 - val_loss: 0.6703 - val_accuracy: 0.8343 - lr: 9.9501e-04
# Epoch 34/200
# 282/282 [==============================] - 11s 38ms/step - loss: 0.0404 - accuracy: 0.9851 - val_loss: 0.7854 - val_accuracy: 0.8184 - lr: 9.9501e-04
# Epoch 35/200
# 282/282 [==============================] - 11s 38ms/step - loss: 0.0405 - accuracy: 0.9847 - val_loss: 0.8202 - val_accuracy: 0.8244 - lr: 9.9501e-04

# %%
# Plot the training histories
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the model
model.save('DenseNet201')
