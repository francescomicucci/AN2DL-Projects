# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Progetto AN2DL/3_KerasApplicationsTesting
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/Progetto AN2DL/FeatureExtractorTesting

# %% [markdown]
# ### Import libraries

# %%
# Hide warnings
seed  = 42
import os

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold

# %% [markdown]
# ### Load and process the dataset

# %%
# Load data
data = np.load('../clean_data.npz', allow_pickle=True)

# Save labels in a new list (image pixel values are float in [0, 1])
images = data['data']

# Save labels in a new list
labels = data['labels']

# Print data shape
print(images.shape, labels.shape)
# Out:
# (5004, 96, 96, 3) (5004,)

# %%
# Number of images to display
num_img = 100

# Create subplots for displaying images
fig, axes = plt.subplots(10, num_img//10, figsize=(20, 20))
for i in range(num_img):
    ax = axes[i%10, i%num_img//10]
    ax.imshow(np.clip(images[i], 0, 255))  # Display clipped item images
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Convert labels from string to integer
num_labels = []
for label in labels:
  if label == "healthy":
    num_labels.append(0)
  else:
    num_labels.append(1)

# Convert labels in the one-hot encoding format
num_labels = np.array(num_labels)
labels = tfk.utils.to_categorical(num_labels, 2)

# Split data into train and val sets
X_train, X_val, y_train, y_val = train_test_split(
    images,
    labels,
    test_size=0.1,
    stratify=labels
)

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (4503, 96, 96, 3), y_train shape: (4503, 2)
# X_val shape: (501, 96, 96, 3), y_val shape: (501, 2)

# %% [markdown]
# ### ResNet101

# %%
# Import Feature Extractor with specified settings
feature_extractor = tfk.applications.ResNet101(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    pooling='avg',
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171446536/171446536 [==============================] - 1s 0us/step

# %% [markdown]
# ### Model

# %%
# Define network parameters/callbacks
dropout_rate = 1/10
learning_rate = 1e-3

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.999,
    mode='max',
    min_lr=1e-5
)

early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=20,
    restore_best_weights=True
)

# %%
def build_model(feature_extractor, dropout_rate, learning_rate=0.001):
  # Use the supernet as feature extractor, i.e. freeze all its weigths
  feature_extractor.trainable = False

  # Create an input layer with shape (96, 96, 3)
  inputs = tfk.Input(shape=(96, 96, 3), name='Input')

  # Connect FeatureExtractor to the input
  x = feature_extractor(inputs)

  # Hidden layers
  x = tfkl.Dense(units=64, name='HiddenDense1')(x)
  x = tfkl.Activation('relu', name='HiddenActivation1')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)
  x = tfkl.Dense(units=64, name='HiddenDense2')(dropout)
  x = tfkl.Activation('relu', name='HiddenActivation2')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)

  # Add a Dense layer with 2 unit and softmax activation as the classifier
  outputs = tfkl.Dense(2, activation='softmax')(dropout)

  # Create a Model connecting input and output
  model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

  # Compile the model with Categorical Cross-Entropy loss and Adam optimizer
  model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                optimizer=tfk.optimizers.Adam(learning_rate),
                metrics=['accuracy'])

  # Return the model
  return model

# %%
model = build_model(feature_extractor, dropout_rate, learning_rate)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  resnet101 (Functional)      (None, 2048)              42658176
#
#  HiddenDense1 (Dense)        (None, 64)                131136
#
#  HiddenActivation1 (Activat  (None, 64)                0
#  ion)
#
#  dropout (Dropout)           (None, 64)                0
#
#  HiddenDense2 (Dense)        (None, 64)                4160
#
#  HiddenActivation2 (Activat  (None, 64)                0
#  ion)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 42793602 (163.24 MB)
# Trainable params: 135426 (529.01 KB)
# Non-trainable params: 42658176 (162.73 MB)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = preprocess_input(X_train*255),
    y = y_train,
    batch_size = 16,
    epochs = 200,
    validation_data = (preprocess_input(X_val*255), y_val),
    callbacks = [early_stopping, lr_scheduler]
).history
# Out:
# Epoch 1/200
# 282/282 [==============================] - 29s 52ms/step - loss: 0.6632 - accuracy: 0.6156 - val_loss: 0.6533 - val_accuracy: 0.6208 - lr: 0.0010
# Epoch 2/200
# 282/282 [==============================] - 10s 35ms/step - loss: 0.6545 - accuracy: 0.6260 - val_loss: 0.6497 - val_accuracy: 0.6427 - lr: 0.0010
# Epoch 3/200
# 282/282 [==============================] - 9s 33ms/step - loss: 0.6443 - accuracy: 0.6274 - val_loss: 0.6383 - val_accuracy: 0.6407 - lr: 0.0010
# Epoch 4/200
# 282/282 [==============================] - 10s 34ms/step - loss: 0.6376 - accuracy: 0.6340 - val_loss: 0.6310 - val_accuracy: 0.6527 - lr: 0.0010
# Epoch 5/200
# 282/282 [==============================] - 11s 38ms/step - loss: 0.6353 - accuracy: 0.6400 - val_loss: 0.6339 - val_accuracy: 0.6607 - lr: 0.0010
# Epoch 6/200
# 282/282 [==============================] - 9s 32ms/step - loss: 0.6343 - accuracy: 0.6445 - val_loss: 0.6368 - val_accuracy: 0.6467 - lr: 0.0010
# Epoch 7/200
# 282/282 [==============================] - 10s 35ms/step - loss: 0.6291 - accuracy: 0.6389 - val_loss: 0.6350 - val_accuracy: 0.6427 - lr: 0.0010
# Epoch 8/200
# 282/282 [==============================] - 10s 34ms/step - loss: 0.6283 - accuracy: 0.6389 - val_loss: 0.6305 - val_accuracy: 0.6587 - lr: 0.0010
# Epoch 9/200
# 282/282 [==============================] - 9s 33ms/step - loss: 0.6196 - accuracy: 0.6516 - val_loss: 0.6258 - val_accuracy: 0.6547 - lr: 0.0010
# Epoch 10/200
# 282/282 [==============================] - 10s 36ms/step - loss: 0.6199 - accuracy: 0.6540 - val_loss: 0.6249 - val_accuracy: 0.6587 - lr: 0.0010
# Epoch 11/200
# 282/282 [==============================] - 10s 35ms/step - loss: 0.6197 - accuracy: 0.6538 - val_loss: 0.6264 - val_accuracy: 0.6527 - lr: 9.9900e-04
# Epoch 12/200
# 282/282 [==============================] - 10s 36ms/step - loss: 0.6079 - accuracy: 0.6651 - val_loss: 0.6359 - val_accuracy: 0.6627 - lr: 9.9900e-04
# Epoch 13/200
# 282/282 [==============================] - 9s 33ms/step - loss: 0.6119 - accuracy: 0.6676 - val_loss: 0.6244 - val_accuracy: 0.6747 - lr: 9.9900e-04
# Epoch 14/200
# 282/282 [==============================] - 10s 35ms/step - loss: 0.6068 - accuracy: 0.6682 - val_loss: 0.6322 - val_accuracy: 0.6607 - lr: 9.9900e-04
# Epoch 15/200
# 282/282 [==============================] - 10s 35ms/step - loss: 0.6037 - accuracy: 0.6742 - val_loss: 0.6395 - val_accuracy: 0.6467 - lr: 9.9900e-04
# Epoch 16/200
# 282/282 [==============================] - 10s 34ms/step - loss: 0.6027 - accuracy: 0.6727 - val_loss: 0.6316 - val_accuracy: 0.6607 - lr: 9.9900e-04
# Epoch 17/200
# 282/282 [==============================] - 10s 34ms/step - loss: 0.5981 - accuracy: 0.6758 - val_loss: 0.6615 - val_accuracy: 0.6327 - lr: 9.9900e-04
# Epoch 18/200
# 282/282 [==============================] - 10s 34ms/step - loss: 0.5927 - accuracy: 0.6778 - val_loss: 0.6218 - val_accuracy: 0.6667 - lr: 9.9900e-04
# Epoch 19/200
# 282/282 [==============================] - 10s 35ms/step - loss: 0.5935 - accuracy: 0.6795 - val_loss: 0.6270 - val_accuracy: 0.6507 - lr: 9.9800e-04
# Epoch 20/200
# 282/282 [==============================] - 9s 32ms/step - loss: 0.5896 - accuracy: 0.6824 - val_loss: 0.6272 - val_accuracy: 0.6567 - lr: 9.9800e-04
# Epoch 21/200
# 282/282 [==============================] - 10s 35ms/step - loss: 0.5895 - accuracy: 0.6778 - val_loss: 0.6372 - val_accuracy: 0.6447 - lr: 9.9800e-04
# Epoch 22/200
# 282/282 [==============================] - 10s 35ms/step - loss: 0.5826 - accuracy: 0.6869 - val_loss: 0.6277 - val_accuracy: 0.6467 - lr: 9.9800e-04
# Epoch 23/200
# 282/282 [==============================] - 10s 35ms/step - loss: 0.5861 - accuracy: 0.6795 - val_loss: 0.6691 - val_accuracy: 0.5968 - lr: 9.9800e-04
# Epoch 24/200
# 282/282 [==============================] - 9s 32ms/step - loss: 0.5795 - accuracy: 0.6849 - val_loss: 0.6575 - val_accuracy: 0.6287 - lr: 9.9700e-04
# Epoch 25/200
# 282/282 [==============================] - 10s 34ms/step - loss: 0.5762 - accuracy: 0.6831 - val_loss: 0.6345 - val_accuracy: 0.6427 - lr: 9.9700e-04
# Epoch 26/200
# 282/282 [==============================] - 10s 35ms/step - loss: 0.5740 - accuracy: 0.6871 - val_loss: 0.6241 - val_accuracy: 0.6547 - lr: 9.9700e-04
# Epoch 27/200
# 282/282 [==============================] - 9s 33ms/step - loss: 0.5672 - accuracy: 0.6958 - val_loss: 0.6589 - val_accuracy: 0.6567 - lr: 9.9700e-04
# Epoch 28/200
# 282/282 [==============================] - 10s 35ms/step - loss: 0.5687 - accuracy: 0.6922 - val_loss: 0.6317 - val_accuracy: 0.6487 - lr: 9.9700e-04
# Epoch 29/200
# 282/282 [==============================] - 10s 34ms/step - loss: 0.5615 - accuracy: 0.7009 - val_loss: 0.6406 - val_accuracy: 0.6447 - lr: 9.9601e-04
# Epoch 30/200
# 282/282 [==============================] - 11s 39ms/step - loss: 0.5652 - accuracy: 0.7044 - val_loss: 0.6312 - val_accuracy: 0.6487 - lr: 9.9601e-04
# Epoch 31/200
# 282/282 [==============================] - 9s 32ms/step - loss: 0.5601 - accuracy: 0.7064 - val_loss: 0.6619 - val_accuracy: 0.6347 - lr: 9.9601e-04
# Epoch 32/200
# 282/282 [==============================] - 10s 34ms/step - loss: 0.5543 - accuracy: 0.7002 - val_loss: 0.6417 - val_accuracy: 0.6287 - lr: 9.9601e-04
# Epoch 33/200
# 282/282 [==============================] - 10s 35ms/step - loss: 0.5634 - accuracy: 0.6953 - val_loss: 0.6566 - val_accuracy: 0.6507 - lr: 9.9601e-04

# %%
# Plot the training histories
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the model
model.save('ResNet101')
