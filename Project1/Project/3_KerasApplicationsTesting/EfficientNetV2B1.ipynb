# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Progetto AN2DL/3_KerasApplicationsTesting
# Out:
# Mounted at /gdrive
# /gdrive/.shortcut-targets-by-id/1ygSQdg0_3KzCXK0mWufNykWjfoYjWqKH/Progetto AN2DL/FeatureExtractorTesting

# %% [markdown]
# ### Import libraries

# %%
# Hide warnings
seed  = 42
import os

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold

# %% [markdown]
# ### Load and process the dataset

# %%
# Load data
data = np.load('../clean_data.npz', allow_pickle=True)

# Save labels in a new list (image pixel values are float in [0, 1])
images = data['data']

# Save labels in a new list
labels = data['labels']

# Print data shape
print(images.shape, labels.shape)
# Out:
# (5004, 96, 96, 3) (5004,)

# %%
# Number of images to display
num_img = 100

# Create subplots for displaying images
fig, axes = plt.subplots(10, num_img//10, figsize=(20, 20))
for i in range(num_img):
    ax = axes[i%10, i%num_img//10]
    ax.imshow(np.clip(images[i], 0, 255))  # Display clipped item images
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Convert labels from string to integer
num_labels = []
for label in labels:
  if label == "healthy":
    num_labels.append(0)
  else:
    num_labels.append(1)

# Convert labels in the one-hot encoding format
num_labels = np.array(num_labels)
labels = tfk.utils.to_categorical(num_labels, 2)

# Split data into train and val sets
X_train, X_val, y_train, y_val = train_test_split(
    images,
    labels,
    test_size=0.1,
    stratify=labels
)

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (4503, 96, 96, 3), y_train shape: (4503, 2)
# X_val shape: (501, 96, 96, 3), y_val shape: (501, 2)

# %% [markdown]
# ### EfficientNetV2B1

# %%
# Import Feature Extractor with specified settings
feature_extractor = tfk.applications.EfficientNetV2B1(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    pooling='avg',
    include_preprocessing=True,
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b1_notop.h5
# 28456008/28456008 [==============================] - 0s 0us/step

# %% [markdown]
# ### Model

# %%
# Define network parameters/callbacks
dropout_rate = 1/10
learning_rate = 1e-3

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.999,
    mode='max',
    min_lr=1e-5
)

early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=20,
    restore_best_weights=True
)

# %%
def build_model(feature_extractor, dropout_rate, learning_rate=0.001):
  # Use the supernet as feature extractor, i.e. freeze all its weigths
  feature_extractor.trainable = False

  # Create an input layer with shape (96, 96, 3)
  inputs = tfk.Input(shape=(96, 96, 3), name='Input')

  # Connect FeatureExtractor to the input
  x = feature_extractor(inputs)

  # Hidden layers
  x = tfkl.Dense(units=64, name='HiddenDense1')(x)
  x = tfkl.Activation('relu', name='HiddenActivation1')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)
  x = tfkl.Dense(units=64, name='HiddenDense2')(dropout)
  x = tfkl.Activation('relu', name='HiddenActivation2')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)

  # Add a Dense layer with 2 unit and softmax activation as the classifier
  outputs = tfkl.Dense(2, activation='softmax')(dropout)

  # Create a Model connecting input and output
  model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

  # Compile the model with Categorical Cross-Entropy loss and Adam optimizer
  model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                optimizer=tfk.optimizers.Adam(learning_rate),
                metrics=['accuracy'])

  # Return the model
  return model

# %%
model = build_model(feature_extractor, dropout_rate, learning_rate)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  efficientnetv2-b1 (Functio  (None, 1280)              6931124
#  nal)
#
#  HiddenDense1 (Dense)        (None, 64)                81984
#
#  HiddenActivation1 (Activat  (None, 64)                0
#  ion)
#
#  dropout (Dropout)           (None, 64)                0
#
#  HiddenDense2 (Dense)        (None, 64)                4160
#
#  HiddenActivation2 (Activat  (None, 64)                0
#  ion)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 7017398 (26.77 MB)
# Trainable params: 86274 (337.01 KB)
# Non-trainable params: 6931124 (26.44 MB)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = X_train*255,
    y = y_train,
    batch_size = 16,
    epochs = 200,
    validation_data = (X_val*255, y_val),
    callbacks = [early_stopping, lr_scheduler]
).history
# Out:
# Epoch 1/200
# 282/282 [==============================] - 30s 35ms/step - loss: 0.5152 - accuracy: 0.7411 - val_loss: 0.4882 - val_accuracy: 0.7565 - lr: 0.0010
# Epoch 2/200
# 282/282 [==============================] - 5s 18ms/step - loss: 0.4290 - accuracy: 0.8012 - val_loss: 0.3895 - val_accuracy: 0.8084 - lr: 0.0010
# Epoch 3/200
# 282/282 [==============================] - 5s 18ms/step - loss: 0.4039 - accuracy: 0.8183 - val_loss: 0.3814 - val_accuracy: 0.8303 - lr: 0.0010
# Epoch 4/200
# 282/282 [==============================] - 4s 15ms/step - loss: 0.3815 - accuracy: 0.8319 - val_loss: 0.3978 - val_accuracy: 0.8164 - lr: 0.0010
# Epoch 5/200
# 282/282 [==============================] - 5s 19ms/step - loss: 0.3637 - accuracy: 0.8354 - val_loss: 0.4386 - val_accuracy: 0.8224 - lr: 0.0010
# Epoch 6/200
# 282/282 [==============================] - 5s 17ms/step - loss: 0.3539 - accuracy: 0.8454 - val_loss: 0.3696 - val_accuracy: 0.8323 - lr: 0.0010
# Epoch 7/200
# 282/282 [==============================] - 5s 16ms/step - loss: 0.3404 - accuracy: 0.8494 - val_loss: 0.3853 - val_accuracy: 0.8343 - lr: 0.0010
# Epoch 8/200
# 282/282 [==============================] - 5s 19ms/step - loss: 0.3179 - accuracy: 0.8614 - val_loss: 0.3555 - val_accuracy: 0.8383 - lr: 0.0010
# Epoch 9/200
# 282/282 [==============================] - 4s 15ms/step - loss: 0.3121 - accuracy: 0.8628 - val_loss: 0.4308 - val_accuracy: 0.8124 - lr: 0.0010
# Epoch 10/200
# 282/282 [==============================] - 5s 16ms/step - loss: 0.2959 - accuracy: 0.8716 - val_loss: 0.3524 - val_accuracy: 0.8383 - lr: 0.0010
# Epoch 11/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.2877 - accuracy: 0.8732 - val_loss: 0.3532 - val_accuracy: 0.8443 - lr: 0.0010
# Epoch 12/200
# 282/282 [==============================] - 4s 15ms/step - loss: 0.2760 - accuracy: 0.8834 - val_loss: 0.3832 - val_accuracy: 0.8283 - lr: 0.0010
# 282/282 [==============================] - 5s 19ms/step - loss: 0.1459 - accuracy: 0.9449 - val_loss: 0.4148 - val_accuracy: 0.8723 - lr: 9.9601e-04
# Epoch 48/200
# 282/282 [==============================] - 4s 15ms/step - loss: 0.1307 - accuracy: 0.9465 - val_loss: 0.4375 - val_accuracy: 0.8623 - lr: 9.9501e-04
# Epoch 49/200
# 282/282 [==============================] - 5s 17ms/step - loss: 0.1358 - accuracy: 0.9460 - val_loss: 0.5082 - val_accuracy: 0.8263 - lr: 9.9501e-04
# Epoch 50/200
# 282/282 [==============================] - 5s 17ms/step - loss: 0.1526 - accuracy: 0.9398 - val_loss: 0.3919 - val_accuracy: 0.8623 - lr: 9.9501e-04
# Epoch 51/200
# 282/282 [==============================] - 4s 16ms/step - loss: 0.1334 - accuracy: 0.9451 - val_loss: 0.4503 - val_accuracy: 0.8343 - lr: 9.9501e-04
# Epoch 52/200
# 282/282 [==============================] - 5s 18ms/step - loss: 0.1375 - accuracy: 0.9467 - val_loss: 0.4191 - val_accuracy: 0.8463 - lr: 9.9501e-04
# Epoch 53/200
# 282/282 [==============================] - 5s 16ms/step - loss: 0.1391 - accuracy: 0.9427 - val_loss: 0.3946 - val_accuracy: 0.8523 - lr: 9.9402e-04
# Epoch 54/200
# 282/282 [==============================] - 4s 15ms/step - loss: 0.1283 - accuracy: 0.9485 - val_loss: 0.4317 - val_accuracy: 0.8543 - lr: 9.9402e-04
# Epoch 55/200
# 282/282 [==============================] - 5s 18ms/step - loss: 0.1378 - accuracy: 0.9498 - val_loss: 0.4034 - val_accuracy: 0.8483 - lr: 9.9402e-04
# Epoch 56/200
# 282/282 [==============================] - 5s 17ms/step - loss: 0.1262 - accuracy: 0.9489 - val_loss: 0.4142 - val_accuracy: 0.8583 - lr: 9.9402e-04
# Epoch 57/200
# 282/282 [==============================] - 4s 16ms/step - loss: 0.1456 - accuracy: 0.9438 - val_loss: 0.4412 - val_accuracy: 0.8603 - lr: 9.9402e-04
# Epoch 58/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.1257 - accuracy: 0.9523 - val_loss: 0.4174 - val_accuracy: 0.8643 - lr: 9.9302e-04
# Epoch 59/200
# 282/282 [==============================] - 4s 16ms/step - loss: 0.1148 - accuracy: 0.9589 - val_loss: 0.4437 - val_accuracy: 0.8503 - lr: 9.9302e-04
# Epoch 60/200
# 282/282 [==============================] - 4s 16ms/step - loss: 0.1314 - accuracy: 0.9445 - val_loss: 0.4699 - val_accuracy: 0.8403 - lr: 9.9302e-04
# Epoch 61/200
# 282/282 [==============================] - 5s 19ms/step - loss: 0.1175 - accuracy: 0.9520 - val_loss: 0.4716 - val_accuracy: 0.8543 - lr: 9.9302e-04
# Epoch 62/200
# 282/282 [==============================] - 5s 17ms/step - loss: 0.1272 - accuracy: 0.9485 - val_loss: 0.4841 - val_accuracy: 0.8443 - lr: 9.9302e-04

# %%
# Plot the training histories
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the model
model.save('EfficientNetV2B1')
