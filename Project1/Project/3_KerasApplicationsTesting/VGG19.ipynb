# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Progetto AN2DL/3_KerasApplicationsTesting
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/Progetto AN2DL/FeatureExtractorTesting

# %% [markdown]
# ### Import libraries

# %%
# Hide warnings
seed  = 42
import os

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold

# %% [markdown]
# ### Load and process the dataset

# %%
# Load data
data = np.load('../clean_data.npz', allow_pickle=True)

# Save labels in a new list (image pixel values are float in [0, 1])
images = data['data']

# Save labels in a new list
labels = data['labels']

# Print data shape
print(images.shape, labels.shape)
# Out:
# (5004, 96, 96, 3) (5004,)

# %%
# Number of images to display
num_img = 100

# Create subplots for displaying images
fig, axes = plt.subplots(10, num_img//10, figsize=(20, 20))
for i in range(num_img):
    ax = axes[i%10, i%num_img//10]
    ax.imshow(np.clip(images[i], 0, 255))  # Display clipped item images
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Convert labels from string to integer
num_labels = []
for label in labels:
  if label == "healthy":
    num_labels.append(0)
  else:
    num_labels.append(1)

# Convert labels in the one-hot encoding format
num_labels = np.array(num_labels)
labels = tfk.utils.to_categorical(num_labels, 2)

# Split data into train and val sets
X_train, X_val, y_train, y_val = train_test_split(
    images,
    labels,
    test_size=0.1,
    stratify=labels
)

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (4503, 96, 96, 3), y_train shape: (4503, 2)
# X_val shape: (501, 96, 96, 3), y_val shape: (501, 2)

# %% [markdown]
# ### VGG19

# %%
# Import Feature Extractor with specified settings
feature_extractor = tfk.applications.VGG19(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    pooling='avg',
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step

# %% [markdown]
# ### Model

# %%
# Define network parameters/callbacks
dropout_rate = 1/10
learning_rate = 1e-3

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.999,
    mode='max',
    min_lr=1e-5
)

early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=20,
    restore_best_weights=True
)

# %%
def build_model(feature_extractor, dropout_rate, learning_rate=0.001):
  # Use the supernet as feature extractor, i.e. freeze all its weigths
  feature_extractor.trainable = False

  # Create an input layer with shape (96, 96, 3)
  inputs = tfk.Input(shape=(96, 96, 3), name='Input')

  # Connect FeatureExtractor to the input
  x = feature_extractor(inputs)

  # Hidden layers
  x = tfkl.Dense(units=64, name='HiddenDense1')(x)
  x = tfkl.Activation('relu', name='HiddenActivation1')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)
  x = tfkl.Dense(units=64, name='HiddenDense2')(dropout)
  x = tfkl.Activation('relu', name='HiddenActivation2')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)

  # Add a Dense layer with 2 unit and softmax activation as the classifier
  outputs = tfkl.Dense(2, activation='softmax')(dropout)

  # Create a Model connecting input and output
  model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

  # Compile the model with Categorical Cross-Entropy loss and Adam optimizer
  model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                optimizer=tfk.optimizers.Adam(learning_rate),
                metrics=['accuracy'])

  # Return the model
  return model

# %%
model = build_model(feature_extractor, dropout_rate, learning_rate)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  vgg19 (Functional)          (None, 512)               20024384
#
#  HiddenDense1 (Dense)        (None, 64)                32832
#
#  HiddenActivation1 (Activat  (None, 64)                0
#  ion)
#
#  dropout (Dropout)           (None, 64)                0
#
#  HiddenDense2 (Dense)        (None, 64)                4160
#
#  HiddenActivation2 (Activat  (None, 64)                0
#  ion)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 20061506 (76.53 MB)
# Trainable params: 37122 (145.01 KB)
# Non-trainable params: 20024384 (76.39 MB)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = preprocess_input(X_train*255),
    y = y_train,
    batch_size = 16,
    epochs = 200,
    validation_data = (preprocess_input(X_val*255), y_val),
    callbacks = [early_stopping, lr_scheduler]
).history
# Out:
# Epoch 1/200
# 282/282 [==============================] - 19s 28ms/step - loss: 0.5707 - accuracy: 0.7060 - val_loss: 0.4950 - val_accuracy: 0.7685 - lr: 0.0010
# Epoch 2/200
# 282/282 [==============================] - 6s 22ms/step - loss: 0.4921 - accuracy: 0.7655 - val_loss: 0.5121 - val_accuracy: 0.7405 - lr: 0.0010
# Epoch 3/200
# 282/282 [==============================] - 7s 24ms/step - loss: 0.4638 - accuracy: 0.7890 - val_loss: 0.4434 - val_accuracy: 0.7864 - lr: 0.0010
# Epoch 4/200
# 282/282 [==============================] - 6s 23ms/step - loss: 0.4420 - accuracy: 0.7959 - val_loss: 0.4460 - val_accuracy: 0.7884 - lr: 0.0010
# Epoch 5/200
# 282/282 [==============================] - 7s 24ms/step - loss: 0.4244 - accuracy: 0.8130 - val_loss: 0.4613 - val_accuracy: 0.7764 - lr: 0.0010
# Epoch 6/200
# 282/282 [==============================] - 7s 23ms/step - loss: 0.4045 - accuracy: 0.8217 - val_loss: 0.4416 - val_accuracy: 0.7984 - lr: 0.0010
# Epoch 7/200
# 282/282 [==============================] - 7s 24ms/step - loss: 0.3955 - accuracy: 0.8190 - val_loss: 0.4416 - val_accuracy: 0.7884 - lr: 0.0010
# Epoch 8/200
# 282/282 [==============================] - 7s 23ms/step - loss: 0.3785 - accuracy: 0.8326 - val_loss: 0.4332 - val_accuracy: 0.7924 - lr: 0.0010
# Epoch 9/200
# 282/282 [==============================] - 7s 24ms/step - loss: 0.3625 - accuracy: 0.8414 - val_loss: 0.4363 - val_accuracy: 0.7904 - lr: 0.0010
# Epoch 10/200
# 282/282 [==============================] - 6s 23ms/step - loss: 0.3560 - accuracy: 0.8457 - val_loss: 0.4268 - val_accuracy: 0.7944 - lr: 0.0010
# Epoch 11/200
# 282/282 [==============================] - 7s 24ms/step - loss: 0.3337 - accuracy: 0.8512 - val_loss: 0.4486 - val_accuracy: 0.7904 - lr: 0.0010
# Epoch 12/200
# 282/282 [==============================] - 7s 23ms/step - loss: 0.3197 - accuracy: 0.8636 - val_loss: 0.5069 - val_accuracy: 0.7844 - lr: 9.9900e-04
# Epoch 13/200
# 282/282 [==============================] - 7s 26ms/step - loss: 0.3161 - accuracy: 0.8616 - val_loss: 0.4487 - val_accuracy: 0.7924 - lr: 9.9900e-04
# Epoch 14/200
# 282/282 [==============================] - 6s 23ms/step - loss: 0.2961 - accuracy: 0.8676 - val_loss: 0.4356 - val_accuracy: 0.8204 - lr: 9.9900e-04
# Epoch 15/200
# 282/282 [==============================] - 7s 26ms/step - loss: 0.2809 - accuracy: 0.8807 - val_loss: 0.4718 - val_accuracy: 0.7924 - lr: 9.9900e-04
# Epoch 16/200
# 282/282 [==============================] - 6s 23ms/step - loss: 0.2673 - accuracy: 0.8896 - val_loss: 0.5290 - val_accuracy: 0.7864 - lr: 9.9900e-04
# Epoch 17/200
# 282/282 [==============================] - 7s 24ms/step - loss: 0.2650 - accuracy: 0.8879 - val_loss: 0.4937 - val_accuracy: 0.7904 - lr: 9.9900e-04
# Epoch 18/200
# 282/282 [==============================] - 6s 23ms/step - loss: 0.2529 - accuracy: 0.8941 - val_loss: 0.4995 - val_accuracy: 0.7984 - lr: 9.9900e-04
# Epoch 19/200
# 282/282 [==============================] - 7s 24ms/step - loss: 0.2468 - accuracy: 0.8978 - val_loss: 0.4874 - val_accuracy: 0.7824 - lr: 9.9900e-04
# Epoch 20/200
# 282/282 [==============================] - 6s 23ms/step - loss: 0.2366 - accuracy: 0.8994 - val_loss: 0.5319 - val_accuracy: 0.7884 - lr: 9.9800e-04
# Epoch 21/200
# 282/282 [==============================] - 7s 23ms/step - loss: 0.2229 - accuracy: 0.9094 - val_loss: 0.5312 - val_accuracy: 0.7824 - lr: 9.9800e-04
# Epoch 22/200
# 282/282 [==============================] - 6s 23ms/step - loss: 0.2140 - accuracy: 0.9081 - val_loss: 0.5595 - val_accuracy: 0.7944 - lr: 9.9800e-04
# Epoch 23/200
# 282/282 [==============================] - 7s 25ms/step - loss: 0.2221 - accuracy: 0.9065 - val_loss: 0.6363 - val_accuracy: 0.7685 - lr: 9.9800e-04
# Epoch 24/200
# 282/282 [==============================] - 7s 25ms/step - loss: 0.1900 - accuracy: 0.9221 - val_loss: 0.5503 - val_accuracy: 0.7924 - lr: 9.9800e-04
# Epoch 25/200
# 282/282 [==============================] - 7s 26ms/step - loss: 0.1919 - accuracy: 0.9238 - val_loss: 0.6069 - val_accuracy: 0.7884 - lr: 9.9700e-04
# Epoch 26/200
# 282/282 [==============================] - 6s 23ms/step - loss: 0.1906 - accuracy: 0.9243 - val_loss: 0.6171 - val_accuracy: 0.7904 - lr: 9.9700e-04
# Epoch 27/200
# 282/282 [==============================] - 7s 26ms/step - loss: 0.1778 - accuracy: 0.9280 - val_loss: 0.5761 - val_accuracy: 0.7685 - lr: 9.9700e-04
# Epoch 28/200
# 282/282 [==============================] - 6s 23ms/step - loss: 0.1905 - accuracy: 0.9207 - val_loss: 0.6992 - val_accuracy: 0.8064 - lr: 9.9700e-04
# Epoch 29/200
# 282/282 [==============================] - 7s 26ms/step - loss: 0.1781 - accuracy: 0.9283 - val_loss: 0.6111 - val_accuracy: 0.7884 - lr: 9.9700e-04
# Epoch 30/200
# 282/282 [==============================] - 6s 23ms/step - loss: 0.1559 - accuracy: 0.9396 - val_loss: 0.6384 - val_accuracy: 0.7705 - lr: 9.9601e-04
# Epoch 31/200
# 282/282 [==============================] - 7s 26ms/step - loss: 0.1582 - accuracy: 0.9354 - val_loss: 0.6832 - val_accuracy: 0.7984 - lr: 9.9601e-04
# Epoch 32/200
# 282/282 [==============================] - 7s 23ms/step - loss: 0.1491 - accuracy: 0.9398 - val_loss: 0.6238 - val_accuracy: 0.7944 - lr: 9.9601e-04
# Epoch 33/200
# 282/282 [==============================] - 7s 24ms/step - loss: 0.1517 - accuracy: 0.9372 - val_loss: 0.6919 - val_accuracy: 0.7804 - lr: 9.9601e-04
# Epoch 34/200
# 282/282 [==============================] - 7s 24ms/step - loss: 0.1427 - accuracy: 0.9425 - val_loss: 0.6716 - val_accuracy: 0.8004 - lr: 9.9601e-04

# %%
# Plot the training histories
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the model
model.save('VGG19')
