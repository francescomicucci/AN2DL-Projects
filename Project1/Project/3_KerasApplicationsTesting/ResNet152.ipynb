# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Progetto AN2DL/3_KerasApplicationsTesting
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/Progetto AN2DL/FeatureExtractorTesting

# %% [markdown]
# ### Import libraries

# %%
# Hide warnings
seed  = 42
import os

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold

# %% [markdown]
# ### Load and process the dataset

# %%
# Load data
data = np.load('../clean_data.npz', allow_pickle=True)

# Save labels in a new list (image pixel values are float in [0, 1])
images = data['data']

# Save labels in a new list
labels = data['labels']

# Print data shape
print(images.shape, labels.shape)
# Out:
# (5004, 96, 96, 3) (5004,)

# %%
# Number of images to display
num_img = 100

# Create subplots for displaying images
fig, axes = plt.subplots(10, num_img//10, figsize=(20, 20))
for i in range(num_img):
    ax = axes[i%10, i%num_img//10]
    ax.imshow(np.clip(images[i], 0, 255))  # Display clipped item images
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Convert labels from string to integer
num_labels = []
for label in labels:
  if label == "healthy":
    num_labels.append(0)
  else:
    num_labels.append(1)

# Convert labels in the one-hot encoding format
num_labels = np.array(num_labels)
labels = tfk.utils.to_categorical(num_labels, 2)

# Split data into train and val sets
X_train, X_val, y_train, y_val = train_test_split(
    images,
    labels,
    test_size=0.1,
    stratify=labels
)

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (4503, 96, 96, 3), y_train shape: (4503, 2)
# X_val shape: (501, 96, 96, 3), y_val shape: (501, 2)

# %% [markdown]
# ### ResNet152

# %%
# Import Feature Extractor with specified settings
feature_extractor = tfk.applications.ResNet152(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    pooling='avg',
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234698864/234698864 [==============================] - 2s 0us/step

# %% [markdown]
# ### Model

# %%
# Define network parameters/callbacks
dropout_rate = 1/10
learning_rate = 1e-3

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.999,
    mode='max',
    min_lr=1e-5
)

early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=20,
    restore_best_weights=True
)

# %%
def build_model(feature_extractor, dropout_rate, learning_rate=0.001):
  # Use the supernet as feature extractor, i.e. freeze all its weigths
  feature_extractor.trainable = False

  # Create an input layer with shape (96, 96, 3)
  inputs = tfk.Input(shape=(96, 96, 3), name='Input')

  # Connect FeatureExtractor to the input
  x = feature_extractor(inputs)

  # Hidden layers
  x = tfkl.Dense(units=64, name='HiddenDense1')(x)
  x = tfkl.Activation('relu', name='HiddenActivation1')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)
  x = tfkl.Dense(units=64, name='HiddenDense2')(dropout)
  x = tfkl.Activation('relu', name='HiddenActivation2')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)

  # Add a Dense layer with 2 unit and softmax activation as the classifier
  outputs = tfkl.Dense(2, activation='softmax')(dropout)

  # Create a Model connecting input and output
  model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

  # Compile the model with Categorical Cross-Entropy loss and Adam optimizer
  model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                optimizer=tfk.optimizers.Adam(learning_rate),
                metrics=['accuracy'])

  # Return the model
  return model

# %%
model = build_model(feature_extractor, dropout_rate, learning_rate)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  resnet152 (Functional)      (None, 2048)              58370944
#
#  HiddenDense1 (Dense)        (None, 64)                131136
#
#  HiddenActivation1 (Activat  (None, 64)                0
#  ion)
#
#  dropout (Dropout)           (None, 64)                0
#
#  HiddenDense2 (Dense)        (None, 64)                4160
#
#  HiddenActivation2 (Activat  (None, 64)                0
#  ion)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 58506370 (223.18 MB)
# Trainable params: 135426 (529.01 KB)
# Non-trainable params: 58370944 (222.67 MB)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = preprocess_input(X_train*255),
    y = y_train,
    batch_size = 16,
    epochs = 200,
    validation_data = (preprocess_input(X_val*255), y_val),
    callbacks = [early_stopping, lr_scheduler]
).history
# Out:
# Epoch 1/200
# 282/282 [==============================] - 39s 73ms/step - loss: 0.6739 - accuracy: 0.6109 - val_loss: 0.6591 - val_accuracy: 0.6188 - lr: 0.0010
# Epoch 2/200
# 282/282 [==============================] - 13s 48ms/step - loss: 0.6587 - accuracy: 0.6205 - val_loss: 0.6642 - val_accuracy: 0.6347 - lr: 0.0010
# Epoch 3/200
# 282/282 [==============================] - 13s 47ms/step - loss: 0.6568 - accuracy: 0.6194 - val_loss: 0.6663 - val_accuracy: 0.6188 - lr: 0.0010
# Epoch 4/200
# 282/282 [==============================] - 14s 51ms/step - loss: 0.6529 - accuracy: 0.6238 - val_loss: 0.6511 - val_accuracy: 0.6267 - lr: 0.0010
# Epoch 5/200
# 282/282 [==============================] - 13s 47ms/step - loss: 0.6511 - accuracy: 0.6194 - val_loss: 0.6539 - val_accuracy: 0.6287 - lr: 0.0010
# Epoch 6/200
# 282/282 [==============================] - 13s 47ms/step - loss: 0.6480 - accuracy: 0.6169 - val_loss: 0.6520 - val_accuracy: 0.6267 - lr: 0.0010
# Epoch 7/200
# 282/282 [==============================] - 13s 47ms/step - loss: 0.6434 - accuracy: 0.6380 - val_loss: 0.6610 - val_accuracy: 0.6267 - lr: 0.0010
# Epoch 8/200
# 282/282 [==============================] - 13s 47ms/step - loss: 0.6411 - accuracy: 0.6331 - val_loss: 0.6524 - val_accuracy: 0.6248 - lr: 9.9900e-04
# Epoch 9/200
# 282/282 [==============================] - 14s 49ms/step - loss: 0.5320 - accuracy: 0.7191 - val_loss: 0.7226 - val_accuracy: 0.6367 - lr: 9.9601e-04
# Epoch 40/200
# 282/282 [==============================] - 13s 47ms/step - loss: 0.5342 - accuracy: 0.7144 - val_loss: 0.7311 - val_accuracy: 0.6168 - lr: 9.9601e-04
# Epoch 41/200
# 282/282 [==============================] - 13s 47ms/step - loss: 0.5337 - accuracy: 0.7180 - val_loss: 0.7035 - val_accuracy: 0.6287 - lr: 9.9601e-04
# Epoch 42/200
# 282/282 [==============================] - 13s 48ms/step - loss: 0.5275 - accuracy: 0.7217 - val_loss: 0.7836 - val_accuracy: 0.6427 - lr: 9.9601e-04
# Epoch 43/200
# 282/282 [==============================] - 14s 48ms/step - loss: 0.5274 - accuracy: 0.7215 - val_loss: 0.7314 - val_accuracy: 0.6148 - lr: 9.9501e-04
# Epoch 44/200
# 282/282 [==============================] - 13s 48ms/step - loss: 0.5271 - accuracy: 0.7224 - val_loss: 0.7222 - val_accuracy: 0.6347 - lr: 9.9501e-04
# Epoch 45/200
# 282/282 [==============================] - 13s 48ms/step - loss: 0.5252 - accuracy: 0.7186 - val_loss: 0.8200 - val_accuracy: 0.6467 - lr: 9.9501e-04
# Epoch 46/200
# 282/282 [==============================] - 13s 48ms/step - loss: 0.5187 - accuracy: 0.7315 - val_loss: 0.7294 - val_accuracy: 0.6387 - lr: 9.9501e-04
# Epoch 47/200
# 282/282 [==============================] - 13s 47ms/step - loss: 0.5011 - accuracy: 0.7391 - val_loss: 0.7306 - val_accuracy: 0.6587 - lr: 9.9501e-04
# Epoch 48/200
# 282/282 [==============================] - 15s 52ms/step - loss: 0.5018 - accuracy: 0.7382 - val_loss: 0.7871 - val_accuracy: 0.6387 - lr: 9.9402e-04
# Epoch 49/200
# 282/282 [==============================] - 14s 48ms/step - loss: 0.5027 - accuracy: 0.7391 - val_loss: 0.7602 - val_accuracy: 0.6248 - lr: 9.9402e-04
# Epoch 50/200
# 282/282 [==============================] - 13s 48ms/step - loss: 0.5042 - accuracy: 0.7362 - val_loss: 0.7880 - val_accuracy: 0.6168 - lr: 9.9402e-04
# Epoch 51/200
# 282/282 [==============================] - 13s 48ms/step - loss: 0.4989 - accuracy: 0.7348 - val_loss: 0.7750 - val_accuracy: 0.6287 - lr: 9.9402e-04
# Epoch 52/200
# 282/282 [==============================] - 14s 49ms/step - loss: 0.4992 - accuracy: 0.7326 - val_loss: 0.7930 - val_accuracy: 0.6307 - lr: 9.9402e-04

# %%
# Plot the training histories
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the model
model.save('ResNet152')
