# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Progetto AN2DL/3_KerasApplicationsTesting
# Out:
# Mounted at /gdrive
# /gdrive/.shortcut-targets-by-id/1ygSQdg0_3KzCXK0mWufNykWjfoYjWqKH/Progetto AN2DL/FeatureExtractorTesting

# %% [markdown]
# ### Import libraries

# %%
# Hide warnings
seed  = 42
import os

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold

# %% [markdown]
# ### Load and process the dataset

# %%
# Load data
data = np.load('../clean_data.npz', allow_pickle=True)

# Save labels in a new list (image pixel values are float in [0, 1])
images = data['data']

# Save labels in a new list
labels = data['labels']

# Print data shape
print(images.shape, labels.shape)
# Out:
# (5004, 96, 96, 3) (5004,)

# %%
# Number of images to display
num_img = 100

# Create subplots for displaying images
fig, axes = plt.subplots(10, num_img//10, figsize=(20, 20))
for i in range(num_img):
    ax = axes[i%10, i%num_img//10]
    ax.imshow(np.clip(images[i], 0, 255))  # Display clipped item images
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Convert labels from string to integer
num_labels = []
for label in labels:
  if label == "healthy":
    num_labels.append(0)
  else:
    num_labels.append(1)

# Convert labels in the one-hot encoding format
num_labels = np.array(num_labels)
labels = tfk.utils.to_categorical(num_labels, 2)

# Split data into train and val sets
X_train, X_val, y_train, y_val = train_test_split(
    images,
    labels,
    test_size=0.1,
    stratify=labels
)

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (4503, 96, 96, 3), y_train shape: (4503, 2)
# X_val shape: (501, 96, 96, 3), y_val shape: (501, 2)

# %% [markdown]
# ### DenseNet121

# %%
# Import Feature Extractor with specified settings
feature_extractor = tfk.applications.DenseNet121(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    pooling='avg',
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 2s 0us/step

# %% [markdown]
# ### Model

# %%
# Define network parameters/callbacks
dropout_rate = 1/10
learning_rate = 1e-3

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.999,
    mode='max',
    min_lr=1e-5
)

early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=20,
    restore_best_weights=True
)

# %%
def build_model(feature_extractor, dropout_rate, learning_rate=0.001):
  # Use the supernet as feature extractor, i.e. freeze all its weigths
  feature_extractor.trainable = False

  # Create an input layer with shape (96, 96, 3)
  inputs = tfk.Input(shape=(96, 96, 3), name='Input')

  # Connect FeatureExtractor to the input
  x = feature_extractor(inputs)

  # Hidden layers
  x = tfkl.Dense(units=64, name='HiddenDense1')(x)
  x = tfkl.Activation('relu', name='HiddenActivation1')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)
  x = tfkl.Dense(units=64, name='HiddenDense2')(dropout)
  x = tfkl.Activation('relu', name='HiddenActivation2')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)

  # Add a Dense layer with 2 unit and softmax activation as the classifier
  outputs = tfkl.Dense(2, activation='softmax')(dropout)

  # Create a Model connecting input and output
  model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

  # Compile the model with Categorical Cross-Entropy loss and Adam optimizer
  model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                optimizer=tfk.optimizers.Adam(learning_rate),
                metrics=['accuracy'])

  # Return the model
  return model

# %%
model = build_model(feature_extractor, dropout_rate, learning_rate)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  densenet121 (Functional)    (None, 1024)              7037504
#
#  HiddenDense1 (Dense)        (None, 64)                65600
#
#  HiddenActivation1 (Activat  (None, 64)                0
#  ion)
#
#  dropout (Dropout)           (None, 64)                0
#
#  HiddenDense2 (Dense)        (None, 64)                4160
#
#  HiddenActivation2 (Activat  (None, 64)                0
#  ion)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 7107394 (27.11 MB)
# Trainable params: 69890 (273.01 KB)
# Non-trainable params: 7037504 (26.85 MB)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = preprocess_input(X_train*255),
    y = y_train,
    batch_size = 16,
    epochs = 200,
    validation_data = (preprocess_input(X_val*255), y_val),
    callbacks = [early_stopping, lr_scheduler]
).history
# Out:
# Epoch 1/200
# 282/282 [==============================] - 29s 46ms/step - loss: 0.5134 - accuracy: 0.7502 - val_loss: 0.4606 - val_accuracy: 0.7924 - lr: 0.0010
# Epoch 2/200
# 282/282 [==============================] - 7s 25ms/step - loss: 0.4178 - accuracy: 0.8072 - val_loss: 0.4397 - val_accuracy: 0.8064 - lr: 0.0010
# Epoch 3/200
# 282/282 [==============================] - 6s 22ms/step - loss: 0.3779 - accuracy: 0.8303 - val_loss: 0.3949 - val_accuracy: 0.8184 - lr: 0.0010
# Epoch 4/200
# 282/282 [==============================] - 7s 24ms/step - loss: 0.3450 - accuracy: 0.8472 - val_loss: 0.4675 - val_accuracy: 0.7924 - lr: 0.0010
# Epoch 5/200
# 282/282 [==============================] - 6s 21ms/step - loss: 0.3210 - accuracy: 0.8605 - val_loss: 0.3755 - val_accuracy: 0.8124 - lr: 0.0010
# Epoch 6/200
# 282/282 [==============================] - 6s 22ms/step - loss: 0.3024 - accuracy: 0.8674 - val_loss: 0.3733 - val_accuracy: 0.8244 - lr: 0.0010
# Epoch 7/200
# 282/282 [==============================] - 8s 29ms/step - loss: 0.2777 - accuracy: 0.8796 - val_loss: 0.3986 - val_accuracy: 0.8443 - lr: 0.0010
# Epoch 8/200
# 282/282 [==============================] - 6s 22ms/step - loss: 0.2541 - accuracy: 0.8918 - val_loss: 0.4042 - val_accuracy: 0.8363 - lr: 0.0010
# Epoch 9/200
# 282/282 [==============================] - 7s 23ms/step - loss: 0.2410 - accuracy: 0.8941 - val_loss: 0.3875 - val_accuracy: 0.8343 - lr: 0.0010
# Epoch 10/200
# 282/282 [==============================] - 6s 21ms/step - loss: 0.2137 - accuracy: 0.9096 - val_loss: 0.4122 - val_accuracy: 0.8443 - lr: 0.0010
# Epoch 11/200
# 282/282 [==============================] - 7s 25ms/step - loss: 0.1951 - accuracy: 0.9154 - val_loss: 0.4259 - val_accuracy: 0.8503 - lr: 0.0010
# Epoch 12/200
# 282/282 [==============================] - 6s 21ms/step - loss: 0.1880 - accuracy: 0.9232 - val_loss: 0.4279 - val_accuracy: 0.8343 - lr: 0.0010
# Epoch 13/200
# 282/282 [==============================] - 7s 25ms/step - loss: 0.1838 - accuracy: 0.9269 - val_loss: 0.3891 - val_accuracy: 0.8583 - lr: 0.0010
# Epoch 14/200
# 282/282 [==============================] - 6s 21ms/step - loss: 0.1686 - accuracy: 0.9309 - val_loss: 0.4158 - val_accuracy: 0.8503 - lr: 0.0010
# Epoch 15/200
# 282/282 [==============================] - 7s 24ms/step - loss: 0.1526 - accuracy: 0.9367 - val_loss: 0.4712 - val_accuracy: 0.8443 - lr: 0.0010
# Epoch 16/200
# 282/282 [==============================] - 6s 21ms/step - loss: 0.1445 - accuracy: 0.9387 - val_loss: 0.4725 - val_accuracy: 0.8403 - lr: 0.0010
# Epoch 17/200
# 282/282 [==============================] - 7s 24ms/step - loss: 0.1182 - accuracy: 0.9547 - val_loss: 0.4901 - val_accuracy: 0.8463 - lr: 0.0010
# Epoch 18/200
# 282/282 [==============================] - 6s 21ms/step - loss: 0.1350 - accuracy: 0.9463 - val_loss: 0.4689 - val_accuracy: 0.8523 - lr: 0.0010
# Epoch 19/200
# 282/282 [==============================] - 6s 22ms/step - loss: 0.1073 - accuracy: 0.9598 - val_loss: 0.5273 - val_accuracy: 0.8204 - lr: 9.9900e-04
# Epoch 20/200
# 282/282 [==============================] - 6s 23ms/step - loss: 0.1117 - accuracy: 0.9580 - val_loss: 0.5482 - val_accuracy: 0.8343 - lr: 9.9900e-04
# Epoch 21/200
# 282/282 [==============================] - 6s 21ms/step - loss: 0.0996 - accuracy: 0.9600 - val_loss: 0.5948 - val_accuracy: 0.8463 - lr: 9.9900e-04
# Epoch 22/200
# 282/282 [==============================] - 7s 24ms/step - loss: 0.1041 - accuracy: 0.9576 - val_loss: 0.5245 - val_accuracy: 0.8543 - lr: 9.9900e-04
# Epoch 23/200
# 282/282 [==============================] - 6s 21ms/step - loss: 0.0895 - accuracy: 0.9674 - val_loss: 0.4953 - val_accuracy: 0.8463 - lr: 9.9900e-04
# Epoch 24/200
# 282/282 [==============================] - 7s 25ms/step - loss: 0.0725 - accuracy: 0.9738 - val_loss: 0.6751 - val_accuracy: 0.8244 - lr: 9.9800e-04
# Epoch 25/200
# 282/282 [==============================] - 6s 21ms/step - loss: 0.0893 - accuracy: 0.9638 - val_loss: 0.6523 - val_accuracy: 0.8503 - lr: 9.9800e-04
# Epoch 26/200
# 282/282 [==============================] - 7s 24ms/step - loss: 0.0945 - accuracy: 0.9640 - val_loss: 0.6255 - val_accuracy: 0.8263 - lr: 9.9800e-04
# Epoch 27/200
# 282/282 [==============================] - 6s 21ms/step - loss: 0.0794 - accuracy: 0.9711 - val_loss: 0.6967 - val_accuracy: 0.8443 - lr: 9.9800e-04
# Epoch 28/200
# 282/282 [==============================] - 7s 25ms/step - loss: 0.0790 - accuracy: 0.9698 - val_loss: 0.6538 - val_accuracy: 0.8303 - lr: 9.9800e-04
# Epoch 29/200
# 282/282 [==============================] - 6s 22ms/step - loss: 0.0627 - accuracy: 0.9760 - val_loss: 0.6248 - val_accuracy: 0.8383 - lr: 9.9700e-04
# Epoch 30/200
# 282/282 [==============================] - 7s 23ms/step - loss: 0.0897 - accuracy: 0.9665 - val_loss: 0.6599 - val_accuracy: 0.8303 - lr: 9.9700e-04
# Epoch 31/200
# 282/282 [==============================] - 6s 22ms/step - loss: 0.0560 - accuracy: 0.9796 - val_loss: 0.7567 - val_accuracy: 0.8403 - lr: 9.9700e-04
# Epoch 32/200
# 282/282 [==============================] - 6s 22ms/step - loss: 0.0811 - accuracy: 0.9691 - val_loss: 0.6305 - val_accuracy: 0.8383 - lr: 9.9700e-04
# Epoch 33/200
# 282/282 [==============================] - 7s 24ms/step - loss: 0.0797 - accuracy: 0.9709 - val_loss: 0.6986 - val_accuracy: 0.8323 - lr: 9.9700e-04

# %%
# Plot the training histories
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the model
model.save('DenseNet121')
