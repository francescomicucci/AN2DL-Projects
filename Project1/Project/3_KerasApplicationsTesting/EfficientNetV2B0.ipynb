# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Progetto AN2DL/3_KerasApplicationsTesting
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/My Drive/Progetto AN2DL/FeatureExtractorTesting

# %% [markdown]
# ### Import libraries

# %%
# Hide warnings
seed  = 42
import os

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold

# %% [markdown]
# ### Load and process the dataset

# %%
# Load data
data = np.load('../clean_data.npz', allow_pickle=True)

# Save labels in a new list (image pixel values are float in [0, 1])
images = data['data']

# Save labels in a new list
labels = data['labels']

# Print data shape
print(images.shape, labels.shape)
# Out:
# (5004, 96, 96, 3) (5004,)

# %%
# Number of images to display
num_img = 100

# Create subplots for displaying images
fig, axes = plt.subplots(10, num_img//10, figsize=(20, 20))
for i in range(num_img):
    ax = axes[i%10, i%num_img//10]
    ax.imshow(np.clip(images[i], 0, 255))  # Display clipped item images
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Convert labels from string to integer
num_labels = []
for label in labels:
  if label == "healthy":
    num_labels.append(0)
  else:
    num_labels.append(1)

# Convert labels in the one-hot encoding format
num_labels = np.array(num_labels)
labels = tfk.utils.to_categorical(num_labels, 2)

# Split data into train and val sets
X_train, X_val, y_train, y_val = train_test_split(
    images,
    labels,
    test_size=0.1,
    stratify=labels
)

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (4503, 96, 96, 3), y_train shape: (4503, 2)
# X_val shape: (501, 96, 96, 3), y_val shape: (501, 2)

# %% [markdown]
# ### EfficientNetV2B0

# %%
# Import Feature Extractor with specified settings
feature_extractor = tfk.applications.EfficientNetV2B0(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    pooling='avg',
    include_preprocessing=True,
)

# %% [markdown]
# ### Model

# %%
# Define network parameters/callbacks
dropout_rate = 1/10
learning_rate = 1e-3

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.999,
    mode='max',
    min_lr=1e-5
)

early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=20,
    restore_best_weights=True
)

# %%
def build_model(feature_extractor, dropout_rate, learning_rate=0.001):
  # Use the supernet as feature extractor, i.e. freeze all its weigths
  feature_extractor.trainable = False

  # Create an input layer with shape (96, 96, 3)
  inputs = tfk.Input(shape=(96, 96, 3), name='Input')

  # Connect FeatureExtractor to the input
  x = feature_extractor(inputs)

  # Hidden layers
  x = tfkl.Dense(units=64, name='HiddenDense1')(x)
  x = tfkl.Activation('relu', name='HiddenActivation1')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)
  x = tfkl.Dense(units=64, name='HiddenDense2')(dropout)
  x = tfkl.Activation('relu', name='HiddenActivation2')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)

  # Add a Dense layer with 2 unit and softmax activation as the classifier
  outputs = tfkl.Dense(2, activation='softmax')(dropout)

  # Create a Model connecting input and output
  model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

  # Compile the model with Categorical Cross-Entropy loss and Adam optimizer
  model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                optimizer=tfk.optimizers.Adam(learning_rate),
                metrics=['accuracy'])

  # Return the model
  return model

# %%
model = build_model(feature_extractor, dropout_rate, learning_rate)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  efficientnetv2-b0 (Functio  (None, 1280)              5919312
#  nal)
#
#  HiddenDense1 (Dense)        (None, 64)                81984
#
#  HiddenActivation1 (Activat  (None, 64)                0
#  ion)
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  HiddenDense2 (Dense)        (None, 64)                4160
#
#  HiddenActivation2 (Activat  (None, 64)                0
#  ion)
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 6005586 (22.91 MB)
# Trainable params: 86274 (337.01 KB)
# Non-trainable params: 5919312 (22.58 MB)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = X_train*255,
    y = y_train,
    batch_size = 16,
    epochs = 200,
    validation_data = (X_val*255, y_val),
    callbacks = [early_stopping, lr_scheduler]
).history
# Out:
# Epoch 1/200
# 282/282 [==============================] - 18s 35ms/step - loss: 0.4950 - accuracy: 0.7573 - val_loss: 0.4057 - val_accuracy: 0.8164 - lr: 0.0010
# Epoch 2/200
# 282/282 [==============================] - 4s 14ms/step - loss: 0.4065 - accuracy: 0.8137 - val_loss: 0.4235 - val_accuracy: 0.7984 - lr: 0.0010
# Epoch 3/200
# 282/282 [==============================] - 4s 14ms/step - loss: 0.3797 - accuracy: 0.8290 - val_loss: 0.3630 - val_accuracy: 0.8483 - lr: 0.0010
# Epoch 4/200
# 282/282 [==============================] - 5s 16ms/step - loss: 0.3587 - accuracy: 0.8403 - val_loss: 0.3543 - val_accuracy: 0.8403 - lr: 0.0010
# Epoch 5/200
# 282/282 [==============================] - 4s 14ms/step - loss: 0.3318 - accuracy: 0.8557 - val_loss: 0.3730 - val_accuracy: 0.8483 - lr: 0.0010
# Epoch 6/200
# 282/282 [==============================] - 4s 13ms/step - loss: 0.3186 - accuracy: 0.8616 - val_loss: 0.3446 - val_accuracy: 0.8583 - lr: 0.0010
# Epoch 7/200
# 282/282 [==============================] - 4s 13ms/step - loss: 0.2885 - accuracy: 0.8741 - val_loss: 0.3699 - val_accuracy: 0.8463 - lr: 0.0010
# Epoch 8/200
# 282/282 [==============================] - 5s 17ms/step - loss: 0.2899 - accuracy: 0.8756 - val_loss: 0.3603 - val_accuracy: 0.8363 - lr: 0.0010
# Epoch 9/200
# 282/282 [==============================] - 4s 16ms/step - loss: 0.2786 - accuracy: 0.8867 - val_loss: 0.3689 - val_accuracy: 0.8244 - lr: 0.0010
# Epoch 10/200
# 282/282 [==============================] - 4s 13ms/step - loss: 0.2529 - accuracy: 0.8956 - val_loss: 0.3523 - val_accuracy: 0.8683 - lr: 0.0010
# Epoch 11/200
# 282/282 [==============================] - 5s 18ms/step - loss: 0.2398 - accuracy: 0.8961 - val_loss: 0.3513 - val_accuracy: 0.8623 - lr: 0.0010
# Epoch 12/200
# 282/282 [==============================] - 6s 22ms/step - loss: 0.2334 - accuracy: 0.9021 - val_loss: 0.3658 - val_accuracy: 0.8563 - lr: 0.0010
# Epoch 13/200
# 282/282 [==============================] - 4s 15ms/step - loss: 0.2364 - accuracy: 0.8994 - val_loss: 0.3666 - val_accuracy: 0.8443 - lr: 0.0010
# Epoch 14/200
# 282/282 [==============================] - 5s 17ms/step - loss: 0.2138 - accuracy: 0.9109 - val_loss: 0.4249 - val_accuracy: 0.8543 - lr: 0.0010
# Epoch 15/200
# 282/282 [==============================] - 4s 14ms/step - loss: 0.2105 - accuracy: 0.9129 - val_loss: 0.3891 - val_accuracy: 0.8743 - lr: 0.0010
# Epoch 16/200
# 282/282 [==============================] - 4s 13ms/step - loss: 0.1904 - accuracy: 0.9203 - val_loss: 0.3783 - val_accuracy: 0.8603 - lr: 0.0010
# Epoch 17/200
# 282/282 [==============================] - 5s 17ms/step - loss: 0.1872 - accuracy: 0.9260 - val_loss: 0.4476 - val_accuracy: 0.8523 - lr: 0.0010
# Epoch 18/200
# 282/282 [==============================] - 3s 12ms/step - loss: 0.1904 - accuracy: 0.9209 - val_loss: 0.4282 - val_accuracy: 0.8523 - lr: 0.0010
# Epoch 19/200
# 282/282 [==============================] - 4s 13ms/step - loss: 0.1807 - accuracy: 0.9225 - val_loss: 0.4263 - val_accuracy: 0.8583 - lr: 0.0010
# Epoch 20/200
# 282/282 [==============================] - 5s 16ms/step - loss: 0.1728 - accuracy: 0.9243 - val_loss: 0.4018 - val_accuracy: 0.8483 - lr: 0.0010
# Epoch 21/200
# 282/282 [==============================] - 4s 14ms/step - loss: 0.1651 - accuracy: 0.9347 - val_loss: 0.3956 - val_accuracy: 0.8663 - lr: 9.9900e-04
# Epoch 22/200
# 282/282 [==============================] - 4s 13ms/step - loss: 0.1556 - accuracy: 0.9387 - val_loss: 0.4288 - val_accuracy: 0.8503 - lr: 9.9900e-04
# Epoch 23/200
# 282/282 [==============================] - 4s 14ms/step - loss: 0.1529 - accuracy: 0.9383 - val_loss: 0.4694 - val_accuracy: 0.8443 - lr: 9.9900e-04
# Epoch 24/200
# 282/282 [==============================] - 5s 16ms/step - loss: 0.1412 - accuracy: 0.9431 - val_loss: 0.4678 - val_accuracy: 0.8463 - lr: 9.9900e-04
# Epoch 25/200
# 282/282 [==============================] - 4s 14ms/step - loss: 0.1563 - accuracy: 0.9398 - val_loss: 0.4467 - val_accuracy: 0.8343 - lr: 9.9900e-04
# Epoch 26/200
# 282/282 [==============================] - 4s 13ms/step - loss: 0.1424 - accuracy: 0.9423 - val_loss: 0.4378 - val_accuracy: 0.8463 - lr: 9.9800e-04
# Epoch 27/200
# 282/282 [==============================] - 5s 18ms/step - loss: 0.1405 - accuracy: 0.9425 - val_loss: 0.5230 - val_accuracy: 0.8503 - lr: 9.9800e-04
# Epoch 28/200
# 282/282 [==============================] - 4s 12ms/step - loss: 0.1337 - accuracy: 0.9478 - val_loss: 0.5120 - val_accuracy: 0.8403 - lr: 9.9800e-04
# Epoch 29/200
# 282/282 [==============================] - 4s 12ms/step - loss: 0.1363 - accuracy: 0.9494 - val_loss: 0.4939 - val_accuracy: 0.8463 - lr: 9.9800e-04
# Epoch 30/200
# 282/282 [==============================] - 4s 15ms/step - loss: 0.1243 - accuracy: 0.9525 - val_loss: 0.4749 - val_accuracy: 0.8483 - lr: 9.9800e-04
# Epoch 31/200
# 282/282 [==============================] - 4s 15ms/step - loss: 0.1225 - accuracy: 0.9505 - val_loss: 0.5078 - val_accuracy: 0.8483 - lr: 9.9700e-04
# Epoch 32/200
# 282/282 [==============================] - 4s 13ms/step - loss: 0.1221 - accuracy: 0.9480 - val_loss: 0.4481 - val_accuracy: 0.8503 - lr: 9.9700e-04
# Epoch 33/200
# 282/282 [==============================] - 4s 14ms/step - loss: 0.1246 - accuracy: 0.9491 - val_loss: 0.4775 - val_accuracy: 0.8543 - lr: 9.9700e-04
# Epoch 34/200
# 282/282 [==============================] - 5s 17ms/step - loss: 0.1259 - accuracy: 0.9478 - val_loss: 0.5155 - val_accuracy: 0.8363 - lr: 9.9700e-04
# Epoch 35/200
# 282/282 [==============================] - 4s 14ms/step - loss: 0.1213 - accuracy: 0.9538 - val_loss: 0.4804 - val_accuracy: 0.8623 - lr: 9.9700e-04

# %%
# Plot the training histories
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the model
model.save('EfficientNetV2B0')
