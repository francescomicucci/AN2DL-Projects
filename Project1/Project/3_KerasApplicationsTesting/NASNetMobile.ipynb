# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Progetto AN2DL/3_KerasApplicationsTesting
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/Progetto AN2DL/FeatureExtractorTesting

# %% [markdown]
# ### Import libraries

# %%
# Hide warnings
seed  = 42
import os

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold

# %% [markdown]
# ### Load and process the dataset

# %%
# Load data
data = np.load('../clean_data.npz', allow_pickle=True)

# Save labels in a new list (image pixel values are float in [0, 1])
images = data['data']

# Save labels in a new list
labels = data['labels']

# Print data shape
print(images.shape, labels.shape)
# Out:
# (5004, 96, 96, 3) (5004,)

# %%
# Number of images to display
num_img = 100

# Create subplots for displaying images
fig, axes = plt.subplots(10, num_img//10, figsize=(20, 20))
for i in range(num_img):
    ax = axes[i%10, i%num_img//10]
    ax.imshow(np.clip(images[i], 0, 255))  # Display clipped item images
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Convert labels from string to integer
num_labels = []
for label in labels:
  if label == "healthy":
    num_labels.append(0)
  else:
    num_labels.append(1)

# Convert labels in the one-hot encoding format
num_labels = np.array(num_labels)
labels = tfk.utils.to_categorical(num_labels, 2)

# Split data into train and val sets
X_train, X_val, y_train, y_val = train_test_split(
    images,
    labels,
    test_size=0.1,
    stratify=labels
)

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (4503, 96, 96, 3), y_train shape: (4503, 2)
# X_val shape: (501, 96, 96, 3), y_val shape: (501, 2)

# %% [markdown]
# ### NASNetMobile

# %%
# Import Feature Extractor with specified settings
feature_extractor = tfk.applications.NASNetMobile(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    pooling='avg',
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-mobile-no-top.h5
# 19993432/19993432 [==============================] - 0s 0us/step

# %% [markdown]
# ### Model

# %%
# Define network parameters/callbacks
dropout_rate = 1/10
learning_rate = 1e-3

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.999,
    mode='max',
    min_lr=1e-5
)

early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=20,
    restore_best_weights=True
)

# %%
def build_model(feature_extractor, dropout_rate, learning_rate=0.001):
  # Use the supernet as feature extractor, i.e. freeze all its weigths
  feature_extractor.trainable = False

  # Create an input layer with shape (96, 96, 3)
  inputs = tfk.Input(shape=(96, 96, 3), name='Input')

  # Connect FeatureExtractor to the input
  x = feature_extractor(inputs)

  # Hidden layers
  x = tfkl.Dense(units=64, name='HiddenDense1')(x)
  x = tfkl.Activation('relu', name='HiddenActivation1')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)
  x = tfkl.Dense(units=64, name='HiddenDense2')(dropout)
  x = tfkl.Activation('relu', name='HiddenActivation2')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)

  # Add a Dense layer with 2 unit and softmax activation as the classifier
  outputs = tfkl.Dense(2, activation='softmax')(dropout)

  # Create a Model connecting input and output
  model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

  # Compile the model with Categorical Cross-Entropy loss and Adam optimizer
  model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                optimizer=tfk.optimizers.Adam(learning_rate),
                metrics=['accuracy'])

  # Return the model
  return model

# %%
model = build_model(feature_extractor, dropout_rate, learning_rate)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  NASNet (Functional)         (None, 1056)              4269716
#
#  HiddenDense1 (Dense)        (None, 64)                67648
#
#  HiddenActivation1 (Activat  (None, 64)                0
#  ion)
#
#  dropout (Dropout)           (None, 64)                0
#
#  HiddenDense2 (Dense)        (None, 64)                4160
#
#  HiddenActivation2 (Activat  (None, 64)                0
#  ion)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 4341654 (16.56 MB)
# Trainable params: 71938 (281.01 KB)
# Non-trainable params: 4269716 (16.29 MB)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = preprocess_input(X_train*255),
    y = y_train,
    batch_size = 16,
    epochs = 200,
    validation_data = (preprocess_input(X_val*255), y_val),
    callbacks = [early_stopping, lr_scheduler]
).history
# Out:
# Epoch 1/200
# 282/282 [==============================] - 37s 51ms/step - loss: 0.5463 - accuracy: 0.7297 - val_loss: 0.5043 - val_accuracy: 0.7764 - lr: 0.0010
# Epoch 2/200
# 282/282 [==============================] - 10s 35ms/step - loss: 0.4372 - accuracy: 0.8106 - val_loss: 0.4557 - val_accuracy: 0.7964 - lr: 0.0010
# Epoch 3/200
# 282/282 [==============================] - 8s 29ms/step - loss: 0.3937 - accuracy: 0.8252 - val_loss: 0.4615 - val_accuracy: 0.7864 - lr: 0.0010
# Epoch 4/200
# 282/282 [==============================] - 8s 30ms/step - loss: 0.3511 - accuracy: 0.8432 - val_loss: 0.4564 - val_accuracy: 0.7944 - lr: 0.0010
# Epoch 5/200
# 282/282 [==============================] - 9s 34ms/step - loss: 0.3344 - accuracy: 0.8523 - val_loss: 0.4817 - val_accuracy: 0.7864 - lr: 0.0010
# Epoch 6/200
# 282/282 [==============================] - 10s 35ms/step - loss: 0.3036 - accuracy: 0.8643 - val_loss: 0.4923 - val_accuracy: 0.7864 - lr: 0.0010
# Epoch 7/200
# 282/282 [==============================] - 9s 32ms/step - loss: 0.2763 - accuracy: 0.8830 - val_loss: 0.5021 - val_accuracy: 0.8084 - lr: 0.0010
# Epoch 8/200
# 282/282 [==============================] - 9s 34ms/step - loss: 0.2548 - accuracy: 0.8910 - val_loss: 0.5118 - val_accuracy: 0.7984 - lr: 0.0010
# Epoch 9/200
# 282/282 [==============================] - 8s 30ms/step - loss: 0.2121 - accuracy: 0.9107 - val_loss: 0.5586 - val_accuracy: 0.7824 - lr: 0.0010
# Epoch 10/200
# 282/282 [==============================] - 9s 31ms/step - loss: 0.1878 - accuracy: 0.9249 - val_loss: 0.5977 - val_accuracy: 0.8044 - lr: 0.0010
# Epoch 11/200
# 282/282 [==============================] - 9s 32ms/step - loss: 0.1761 - accuracy: 0.9234 - val_loss: 0.6401 - val_accuracy: 0.7844 - lr: 0.0010
# Epoch 12/200
# 282/282 [==============================] - 8s 29ms/step - loss: 0.1512 - accuracy: 0.9376 - val_loss: 0.7192 - val_accuracy: 0.8064 - lr: 0.0010
# Epoch 13/200
# 282/282 [==============================] - 9s 33ms/step - loss: 0.1277 - accuracy: 0.9491 - val_loss: 0.8184 - val_accuracy: 0.8084 - lr: 9.9900e-04
# Epoch 14/200
# 282/282 [==============================] - 10s 34ms/step - loss: 0.1132 - accuracy: 0.9567 - val_loss: 0.8901 - val_accuracy: 0.8064 - lr: 9.9900e-04
# Epoch 15/200
# 282/282 [==============================] - 8s 28ms/step - loss: 0.1178 - accuracy: 0.9558 - val_loss: 0.8994 - val_accuracy: 0.7764 - lr: 9.9900e-04
# Epoch 16/200
# 282/282 [==============================] - 9s 31ms/step - loss: 0.1033 - accuracy: 0.9591 - val_loss: 0.7638 - val_accuracy: 0.7964 - lr: 9.9900e-04
# Epoch 17/200
# 282/282 [==============================] - 9s 32ms/step - loss: 0.0907 - accuracy: 0.9665 - val_loss: 0.7768 - val_accuracy: 0.7784 - lr: 9.9900e-04
# Epoch 18/200
# 282/282 [==============================] - 8s 29ms/step - loss: 0.0958 - accuracy: 0.9647 - val_loss: 0.8120 - val_accuracy: 0.7944 - lr: 9.9800e-04
# Epoch 19/200
# 282/282 [==============================] - 9s 32ms/step - loss: 0.0672 - accuracy: 0.9756 - val_loss: 1.1261 - val_accuracy: 0.7984 - lr: 9.9800e-04
# Epoch 20/200
# 282/282 [==============================] - 9s 33ms/step - loss: 0.0683 - accuracy: 0.9740 - val_loss: 1.0530 - val_accuracy: 0.8044 - lr: 9.9800e-04
# Epoch 21/200
# 282/282 [==============================] - 8s 27ms/step - loss: 0.0703 - accuracy: 0.9745 - val_loss: 1.0467 - val_accuracy: 0.7924 - lr: 9.9800e-04
# Epoch 22/200
# 282/282 [==============================] - 9s 32ms/step - loss: 0.0650 - accuracy: 0.9769 - val_loss: 1.1167 - val_accuracy: 0.7864 - lr: 9.9800e-04
# Epoch 23/200
# 282/282 [==============================] - 9s 30ms/step - loss: 0.0792 - accuracy: 0.9694 - val_loss: 0.9493 - val_accuracy: 0.7844 - lr: 9.9700e-04
# Epoch 24/200
# 282/282 [==============================] - 8s 28ms/step - loss: 0.0453 - accuracy: 0.9836 - val_loss: 1.1191 - val_accuracy: 0.7984 - lr: 9.9700e-04
# Epoch 25/200
# 282/282 [==============================] - 10s 34ms/step - loss: 0.0551 - accuracy: 0.9800 - val_loss: 1.0776 - val_accuracy: 0.8004 - lr: 9.9700e-04
# Epoch 26/200
# 282/282 [==============================] - 8s 30ms/step - loss: 0.0508 - accuracy: 0.9829 - val_loss: 1.1168 - val_accuracy: 0.8084 - lr: 9.9700e-04
# Epoch 27/200
# 282/282 [==============================] - 9s 32ms/step - loss: 0.0559 - accuracy: 0.9807 - val_loss: 1.1395 - val_accuracy: 0.7864 - lr: 9.9700e-04

# %%
# Plot the training histories
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the model
model.save('NASNetMobile')
