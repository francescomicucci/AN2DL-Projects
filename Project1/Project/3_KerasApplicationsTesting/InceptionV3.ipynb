# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Progetto AN2DL/3_KerasApplicationsTesting
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/Progetto AN2DL/FeatureExtractorTesting

# %% [markdown]
# ### Import libraries

# %%
# Hide warnings
seed  = 42
import os

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold

# %% [markdown]
# ### Load and process the dataset

# %%
# Load data
data = np.load('../clean_data.npz', allow_pickle=True)

# Save labels in a new list (image pixel values are float in [0, 1])
images = data['data']

# Save labels in a new list
labels = data['labels']

# Print data shape
print(images.shape, labels.shape)
# Out:
# (5004, 96, 96, 3) (5004,)

# %%
# Number of images to display
num_img = 100

# Create subplots for displaying images
fig, axes = plt.subplots(10, num_img//10, figsize=(20, 20))
for i in range(num_img):
    ax = axes[i%10, i%num_img//10]
    ax.imshow(np.clip(images[i], 0, 255))  # Display clipped item images
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Convert labels from string to integer
num_labels = []
for label in labels:
  if label == "healthy":
    num_labels.append(0)
  else:
    num_labels.append(1)

# Convert labels in the one-hot encoding format
num_labels = np.array(num_labels)
labels = tfk.utils.to_categorical(num_labels, 2)

# Split data into train and val sets
X_train, X_val, y_train, y_val = train_test_split(
    images,
    labels,
    test_size=0.1,
    stratify=labels
)

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (4503, 96, 96, 3), y_train shape: (4503, 2)
# X_val shape: (501, 96, 96, 3), y_val shape: (501, 2)

# %% [markdown]
# ### InceptionV3

# %%
# Import Feature Extractor with specified settings
feature_extractor = tfk.applications.InceptionV3(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    pooling='avg',
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 3s 0us/step

# %% [markdown]
# ### Model

# %%
# Define network parameters/callbacks
dropout_rate = 1/10
learning_rate = 1e-3

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.999,
    mode='max',
    min_lr=1e-5
)

early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=20,
    restore_best_weights=True
)

# %%
def build_model(feature_extractor, dropout_rate, learning_rate=0.001):
  # Use the supernet as feature extractor, i.e. freeze all its weigths
  feature_extractor.trainable = False

  # Create an input layer with shape (96, 96, 3)
  inputs = tfk.Input(shape=(96, 96, 3), name='Input')

  # Connect FeatureExtractor to the input
  x = feature_extractor(inputs)

  # Hidden layers
  x = tfkl.Dense(units=64, name='HiddenDense1')(x)
  x = tfkl.Activation('relu', name='HiddenActivation1')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)
  x = tfkl.Dense(units=64, name='HiddenDense2')(dropout)
  x = tfkl.Activation('relu', name='HiddenActivation2')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)

  # Add a Dense layer with 2 unit and softmax activation as the classifier
  outputs = tfkl.Dense(2, activation='softmax')(dropout)

  # Create a Model connecting input and output
  model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

  # Compile the model with Categorical Cross-Entropy loss and Adam optimizer
  model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                optimizer=tfk.optimizers.Adam(learning_rate),
                metrics=['accuracy'])

  # Return the model
  return model

# %%
model = build_model(feature_extractor, dropout_rate, learning_rate)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  inception_v3 (Functional)   (None, 2048)              21802784
#
#  HiddenDense1 (Dense)        (None, 64)                131136
#
#  HiddenActivation1 (Activat  (None, 64)                0
#  ion)
#
#  dropout (Dropout)           (None, 64)                0
#
#  HiddenDense2 (Dense)        (None, 64)                4160
#
#  HiddenActivation2 (Activat  (None, 64)                0
#  ion)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 21938210 (83.69 MB)
# Trainable params: 135426 (529.01 KB)
# Non-trainable params: 21802784 (83.17 MB)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = preprocess_input(X_train*255),
    y = y_train,
    batch_size = 16,
    epochs = 200,
    validation_data = (preprocess_input(X_val*255), y_val),
    callbacks = [early_stopping, lr_scheduler]
).history
# Out:
# Epoch 1/200
# 282/282 [==============================] - 24s 31ms/step - loss: 0.5889 - accuracy: 0.6891 - val_loss: 0.5194 - val_accuracy: 0.7445 - lr: 0.0010
# Epoch 2/200
# 282/282 [==============================] - 7s 26ms/step - loss: 0.5086 - accuracy: 0.7513 - val_loss: 0.5374 - val_accuracy: 0.7385 - lr: 0.0010
# Epoch 3/200
# 282/282 [==============================] - 5s 19ms/step - loss: 0.4826 - accuracy: 0.7666 - val_loss: 0.5539 - val_accuracy: 0.7325 - lr: 0.0010
# Epoch 4/200
# 282/282 [==============================] - 5s 18ms/step - loss: 0.4533 - accuracy: 0.7835 - val_loss: 0.5387 - val_accuracy: 0.7445 - lr: 0.0010
# Epoch 5/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.4300 - accuracy: 0.7984 - val_loss: 0.5246 - val_accuracy: 0.7305 - lr: 0.0010
# Epoch 6/200
# 282/282 [==============================] - 5s 18ms/step - loss: 0.3934 - accuracy: 0.8215 - val_loss: 0.5205 - val_accuracy: 0.7525 - lr: 0.0010
# Epoch 7/200
# 282/282 [==============================] - 5s 19ms/step - loss: 0.3746 - accuracy: 0.8330 - val_loss: 0.5729 - val_accuracy: 0.7385 - lr: 0.0010
# Epoch 8/200
# 282/282 [==============================] - 6s 19ms/step - loss: 0.3403 - accuracy: 0.8461 - val_loss: 0.5951 - val_accuracy: 0.7685 - lr: 0.0010
# Epoch 9/200
# 282/282 [==============================] - 5s 18ms/step - loss: 0.3143 - accuracy: 0.8574 - val_loss: 0.6738 - val_accuracy: 0.7445 - lr: 0.0010
# Epoch 10/200
# 282/282 [==============================] - 6s 21ms/step - loss: 0.2880 - accuracy: 0.8781 - val_loss: 0.6714 - val_accuracy: 0.7605 - lr: 0.0010
# Epoch 11/200
# 282/282 [==============================] - 5s 18ms/step - loss: 0.2356 - accuracy: 0.8936 - val_loss: 0.7034 - val_accuracy: 0.7545 - lr: 0.0010
# Epoch 12/200
# 282/282 [==============================] - 5s 18ms/step - loss: 0.2399 - accuracy: 0.8965 - val_loss: 0.7610 - val_accuracy: 0.7465 - lr: 0.0010
# Epoch 13/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.2015 - accuracy: 0.9101 - val_loss: 0.7185 - val_accuracy: 0.7585 - lr: 0.0010
# Epoch 14/200
# 282/282 [==============================] - 5s 18ms/step - loss: 0.2024 - accuracy: 0.9094 - val_loss: 1.0631 - val_accuracy: 0.7485 - lr: 9.9900e-04
# Epoch 15/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.1856 - accuracy: 0.9254 - val_loss: 0.8406 - val_accuracy: 0.7345 - lr: 9.9900e-04
# Epoch 16/200
# 282/282 [==============================] - 5s 18ms/step - loss: 0.1438 - accuracy: 0.9409 - val_loss: 0.9908 - val_accuracy: 0.7345 - lr: 9.9900e-04
# Epoch 17/200
# 282/282 [==============================] - 5s 17ms/step - loss: 0.1381 - accuracy: 0.9447 - val_loss: 1.0219 - val_accuracy: 0.7525 - lr: 9.9900e-04
# Epoch 18/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.1221 - accuracy: 0.9514 - val_loss: 1.1315 - val_accuracy: 0.7505 - lr: 9.9900e-04
# Epoch 19/200
# 282/282 [==============================] - 5s 17ms/step - loss: 0.1278 - accuracy: 0.9509 - val_loss: 0.9715 - val_accuracy: 0.7246 - lr: 9.9800e-04
# Epoch 20/200
# 282/282 [==============================] - 5s 18ms/step - loss: 0.1107 - accuracy: 0.9551 - val_loss: 1.1747 - val_accuracy: 0.7405 - lr: 9.9800e-04
# Epoch 21/200
# 282/282 [==============================] - 5s 19ms/step - loss: 0.1098 - accuracy: 0.9578 - val_loss: 0.9968 - val_accuracy: 0.7525 - lr: 9.9800e-04
# Epoch 22/200
# 282/282 [==============================] - 5s 17ms/step - loss: 0.1096 - accuracy: 0.9538 - val_loss: 1.0639 - val_accuracy: 0.7505 - lr: 9.9800e-04
# Epoch 23/200
# 282/282 [==============================] - 5s 19ms/step - loss: 0.1009 - accuracy: 0.9598 - val_loss: 1.4062 - val_accuracy: 0.7425 - lr: 9.9800e-04
# Epoch 24/200
# 282/282 [==============================] - 5s 17ms/step - loss: 0.1046 - accuracy: 0.9609 - val_loss: 1.0478 - val_accuracy: 0.7485 - lr: 9.9700e-04
# Epoch 25/200
# 282/282 [==============================] - 5s 18ms/step - loss: 0.0936 - accuracy: 0.9629 - val_loss: 1.0681 - val_accuracy: 0.7585 - lr: 9.9700e-04
# Epoch 26/200
# 282/282 [==============================] - 6s 21ms/step - loss: 0.0785 - accuracy: 0.9702 - val_loss: 1.3817 - val_accuracy: 0.7525 - lr: 9.9700e-04
# Epoch 27/200
# 282/282 [==============================] - 5s 17ms/step - loss: 0.1031 - accuracy: 0.9609 - val_loss: 1.2388 - val_accuracy: 0.7385 - lr: 9.9700e-04
# Epoch 28/200
# 282/282 [==============================] - 5s 18ms/step - loss: 0.0967 - accuracy: 0.9607 - val_loss: 1.3110 - val_accuracy: 0.7565 - lr: 9.9700e-04

# %%
# Plot the training histories
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the model
model.save('InceptionV3')
