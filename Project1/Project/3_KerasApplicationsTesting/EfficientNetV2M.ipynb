# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Progetto AN2DL/3_KerasApplicationsTesting
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/Progetto AN2DL/FeatureExtractorTesting

# %% [markdown]
# ### Import libraries

# %%
# Hide warnings
seed  = 42
import os

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold

# %% [markdown]
# ### Load and process the dataset

# %%
# Load data
data = np.load('../clean_data.npz', allow_pickle=True)

# Save labels in a new list (image pixel values are float in [0, 1])
images = data['data']

# Save labels in a new list
labels = data['labels']

# Print data shape
print(images.shape, labels.shape)
# Out:
# (5004, 96, 96, 3) (5004,)

# %%
# Number of images to display
num_img = 100

# Create subplots for displaying images
fig, axes = plt.subplots(10, num_img//10, figsize=(20, 20))
for i in range(num_img):
    ax = axes[i%10, i%num_img//10]
    ax.imshow(np.clip(images[i], 0, 255))  # Display clipped item images
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Convert labels from string to integer
num_labels = []
for label in labels:
  if label == "healthy":
    num_labels.append(0)
  else:
    num_labels.append(1)

# Convert labels in the one-hot encoding format
num_labels = np.array(num_labels)
labels = tfk.utils.to_categorical(num_labels, 2)

# Split data into train and val sets
X_train, X_val, y_train, y_val = train_test_split(
    images,
    labels,
    test_size=0.1,
    stratify=labels
)

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (4503, 96, 96, 3), y_train shape: (4503, 2)
# X_val shape: (501, 96, 96, 3), y_val shape: (501, 2)

# %% [markdown]
# ### EfficientNetV2M

# %%
# Import Feature Extractor with specified settings
feature_extractor = tfk.applications.EfficientNetV2M(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    pooling='avg',
    include_preprocessing=True,
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-m_notop.h5
# 214201816/214201816 [==============================] - 6s 0us/step

# %% [markdown]
# ### Model

# %%
# Define network parameters/callbacks
dropout_rate = 1/10
learning_rate = 1e-3

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.999,
    mode='max',
    min_lr=1e-5
)

early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=20,
    restore_best_weights=True
)

# %%
def build_model(feature_extractor, dropout_rate, learning_rate=0.001):
  # Use the supernet as feature extractor, i.e. freeze all its weigths
  feature_extractor.trainable = False

  # Create an input layer with shape (96, 96, 3)
  inputs = tfk.Input(shape=(96, 96, 3), name='Input')

  # Connect FeatureExtractor to the input
  x = feature_extractor(inputs)

  # Hidden layers
  x = tfkl.Dense(units=64, name='HiddenDense1')(x)
  x = tfkl.Activation('relu', name='HiddenActivation1')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)
  x = tfkl.Dense(units=64, name='HiddenDense2')(dropout)
  x = tfkl.Activation('relu', name='HiddenActivation2')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)

  # Add a Dense layer with 2 unit and softmax activation as the classifier
  outputs = tfkl.Dense(2, activation='softmax')(dropout)

  # Create a Model connecting input and output
  model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

  # Compile the model with Categorical Cross-Entropy loss and Adam optimizer
  model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                optimizer=tfk.optimizers.Adam(learning_rate),
                metrics=['accuracy'])

  # Return the model
  return model

# %%
model = build_model(feature_extractor, dropout_rate, learning_rate)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  efficientnetv2-m (Function  (None, 1280)              53150388
#  al)
#
#  HiddenDense1 (Dense)        (None, 64)                81984
#
#  HiddenActivation1 (Activat  (None, 64)                0
#  ion)
#
#  dropout (Dropout)           (None, 64)                0
#
#  HiddenDense2 (Dense)        (None, 64)                4160
#
#  HiddenActivation2 (Activat  (None, 64)                0
#  ion)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 53236662 (203.08 MB)
# Trainable params: 86274 (337.01 KB)
# Non-trainable params: 53150388 (202.75 MB)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = X_train*255,
    y = y_train,
    batch_size = 16,
    epochs = 200,
    validation_data = (X_val*255, y_val),
    callbacks = [early_stopping, lr_scheduler]
).history
# Out:
# Epoch 1/200
# 282/282 [==============================] - 49s 66ms/step - loss: 0.5325 - accuracy: 0.7308 - val_loss: 0.4495 - val_accuracy: 0.8084 - lr: 0.0010
# Epoch 2/200
# 282/282 [==============================] - 12s 43ms/step - loss: 0.4585 - accuracy: 0.7853 - val_loss: 0.4237 - val_accuracy: 0.8104 - lr: 0.0010
# Epoch 3/200
# 282/282 [==============================] - 11s 41ms/step - loss: 0.4298 - accuracy: 0.8030 - val_loss: 0.4256 - val_accuracy: 0.8024 - lr: 0.0010
# Epoch 4/200
# 282/282 [==============================] - 12s 42ms/step - loss: 0.4019 - accuracy: 0.8159 - val_loss: 0.3966 - val_accuracy: 0.8343 - lr: 0.0010
# Epoch 5/200
# 282/282 [==============================] - 12s 42ms/step - loss: 0.3922 - accuracy: 0.8223 - val_loss: 0.3824 - val_accuracy: 0.8363 - lr: 0.0010
# Epoch 6/200
# 282/282 [==============================] - 12s 43ms/step - loss: 0.3860 - accuracy: 0.8228 - val_loss: 0.4011 - val_accuracy: 0.8224 - lr: 0.0010
# Epoch 7/200
# 282/282 [==============================] - 11s 38ms/step - loss: 0.3646 - accuracy: 0.8403 - val_loss: 0.3884 - val_accuracy: 0.8283 - lr: 0.0010
# Epoch 8/200
# 282/282 [==============================] - 11s 40ms/step - loss: 0.3573 - accuracy: 0.8399 - val_loss: 0.4476 - val_accuracy: 0.7904 - lr: 0.0010
# Epoch 9/200
# 282/282 [==============================] - 12s 41ms/step - loss: 0.3461 - accuracy: 0.8474 - val_loss: 0.3714 - val_accuracy: 0.8363 - lr: 0.0010
# Epoch 10/200
# 282/282 [==============================] - 12s 41ms/step - loss: 0.3391 - accuracy: 0.8554 - val_loss: 0.3886 - val_accuracy: 0.8303 - lr: 0.0010
# Epoch 42/200
# 282/282 [==============================] - 11s 38ms/step - loss: 0.2030 - accuracy: 0.9125 - val_loss: 0.4034 - val_accuracy: 0.8403 - lr: 9.9501e-04
# Epoch 43/200
# 282/282 [==============================] - 11s 40ms/step - loss: 0.2081 - accuracy: 0.9114 - val_loss: 0.3851 - val_accuracy: 0.8523 - lr: 9.9501e-04
# Epoch 44/200
# 282/282 [==============================] - 12s 41ms/step - loss: 0.2182 - accuracy: 0.9094 - val_loss: 0.4341 - val_accuracy: 0.8423 - lr: 9.9501e-04
# Epoch 45/200
# 282/282 [==============================] - 11s 41ms/step - loss: 0.2055 - accuracy: 0.9136 - val_loss: 0.3858 - val_accuracy: 0.8643 - lr: 9.9501e-04
# Epoch 46/200
# 282/282 [==============================] - 12s 42ms/step - loss: 0.2022 - accuracy: 0.9141 - val_loss: 0.3869 - val_accuracy: 0.8543 - lr: 9.9402e-04
# Epoch 47/200
# 282/282 [==============================] - 13s 45ms/step - loss: 0.1949 - accuracy: 0.9214 - val_loss: 0.3726 - val_accuracy: 0.8563 - lr: 9.9402e-04
# Epoch 48/200
# 282/282 [==============================] - 11s 39ms/step - loss: 0.2000 - accuracy: 0.9165 - val_loss: 0.3760 - val_accuracy: 0.8603 - lr: 9.9402e-04
# Epoch 49/200
# 282/282 [==============================] - 11s 40ms/step - loss: 0.1919 - accuracy: 0.9192 - val_loss: 0.4186 - val_accuracy: 0.8383 - lr: 9.9402e-04
# Epoch 50/200
# 282/282 [==============================] - 12s 41ms/step - loss: 0.2040 - accuracy: 0.9145 - val_loss: 0.4069 - val_accuracy: 0.8463 - lr: 9.9402e-04
# Epoch 51/200
# 282/282 [==============================] - 12s 42ms/step - loss: 0.1933 - accuracy: 0.9214 - val_loss: 0.3914 - val_accuracy: 0.8543 - lr: 9.9302e-04
# Epoch 52/200
# 282/282 [==============================] - 12s 41ms/step - loss: 0.1976 - accuracy: 0.9196 - val_loss: 0.3848 - val_accuracy: 0.8563 - lr: 9.9302e-04
# Epoch 53/200
# 282/282 [==============================] - 12s 41ms/step - loss: 0.1844 - accuracy: 0.9258 - val_loss: 0.3986 - val_accuracy: 0.8463 - lr: 9.9302e-04
# Epoch 54/200
# 282/282 [==============================] - 11s 40ms/step - loss: 0.1922 - accuracy: 0.9223 - val_loss: 0.3657 - val_accuracy: 0.8463 - lr: 9.9302e-04
# Epoch 55/200
# 282/282 [==============================] - 11s 40ms/step - loss: 0.1899 - accuracy: 0.9225 - val_loss: 0.4031 - val_accuracy: 0.8563 - lr: 9.9302e-04

# %%
# Plot the training histories
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the model
model.save('EfficientNetV2M')
