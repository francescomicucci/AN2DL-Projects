# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Progetto AN2DL/3_KerasApplicationsTesting
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/Progetto AN2DL/FeatureExtractorTesting

# %% [markdown]
# ### Import libraries

# %%
# Hide warnings
seed  = 42
import os

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold

# %% [markdown]
# ### Load and process the dataset

# %%
# Load data
data = np.load('../clean_data.npz', allow_pickle=True)

# Save labels in a new list (image pixel values are float in [0, 1])
images = data['data']

# Save labels in a new list
labels = data['labels']

# Print data shape
print(images.shape, labels.shape)
# Out:
# (5004, 96, 96, 3) (5004,)

# %%
# Number of images to display
num_img = 100

# Create subplots for displaying images
fig, axes = plt.subplots(10, num_img//10, figsize=(20, 20))
for i in range(num_img):
    ax = axes[i%10, i%num_img//10]
    ax.imshow(np.clip(images[i], 0, 255))  # Display clipped item images
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Convert labels from string to integer
num_labels = []
for label in labels:
  if label == "healthy":
    num_labels.append(0)
  else:
    num_labels.append(1)

# Convert labels in the one-hot encoding format
num_labels = np.array(num_labels)
labels = tfk.utils.to_categorical(num_labels, 2)

# Split data into train and val sets
X_train, X_val, y_train, y_val = train_test_split(
    images,
    labels,
    test_size=0.1,
    stratify=labels
)

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (4503, 96, 96, 3), y_train shape: (4503, 2)
# X_val shape: (501, 96, 96, 3), y_val shape: (501, 2)

# %% [markdown]
# ### Xception

# %%
# Import Feature Extractor with specified settings
feature_extractor = tfk.applications.Xception(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    pooling='avg',
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 0s 0us/step

# %% [markdown]
# ### Model

# %%
# Define network parameters/callbacks
dropout_rate = 1/10
learning_rate = 1e-3

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.999,
    mode='max',
    min_lr=1e-5
)

early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=20,
    restore_best_weights=True
)

# %%
def build_model(feature_extractor, dropout_rate, learning_rate=0.001):
  # Use the supernet as feature extractor, i.e. freeze all its weigths
  feature_extractor.trainable = False

  # Create an input layer with shape (96, 96, 3)
  inputs = tfk.Input(shape=(96, 96, 3), name='Input')

  # Connect FeatureExtractor to the input
  x = feature_extractor(inputs)

  # Hidden layers
  x = tfkl.Dense(units=64, name='HiddenDense1')(x)
  x = tfkl.Activation('relu', name='HiddenActivation1')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)
  x = tfkl.Dense(units=64, name='HiddenDense2')(dropout)
  x = tfkl.Activation('relu', name='HiddenActivation2')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)

  # Add a Dense layer with 2 unit and softmax activation as the classifier
  outputs = tfkl.Dense(2, activation='softmax')(dropout)

  # Create a Model connecting input and output
  model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

  # Compile the model with Categorical Cross-Entropy loss and Adam optimizer
  model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                optimizer=tfk.optimizers.Adam(learning_rate),
                metrics=['accuracy'])

  # Return the model
  return model

# %%
model = build_model(feature_extractor, dropout_rate, learning_rate)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  xception (Functional)       (None, 2048)              20861480
#
#  HiddenDense1 (Dense)        (None, 64)                131136
#
#  HiddenActivation1 (Activat  (None, 64)                0
#  ion)
#
#  dropout (Dropout)           (None, 64)                0
#
#  HiddenDense2 (Dense)        (None, 64)                4160
#
#  HiddenActivation2 (Activat  (None, 64)                0
#  ion)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 20996906 (80.10 MB)
# Trainable params: 135426 (529.01 KB)
# Non-trainable params: 20861480 (79.58 MB)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = preprocess_input(X_train*255),
    y = y_train,
    batch_size = 16,
    epochs = 200,
    validation_data = (preprocess_input(X_val*255), y_val),
    callbacks = [early_stopping, lr_scheduler]
).history
# Out:
# Epoch 1/200
# 282/282 [==============================] - 20s 28ms/step - loss: 0.5617 - accuracy: 0.7135 - val_loss: 0.5244 - val_accuracy: 0.7585 - lr: 0.0010
# Epoch 2/200
# 282/282 [==============================] - 5s 19ms/step - loss: 0.4780 - accuracy: 0.7722 - val_loss: 0.4800 - val_accuracy: 0.7745 - lr: 0.0010
# Epoch 3/200
# 282/282 [==============================] - 6s 21ms/step - loss: 0.4434 - accuracy: 0.7848 - val_loss: 0.4719 - val_accuracy: 0.7764 - lr: 0.0010
# Epoch 4/200
# 282/282 [==============================] - 6s 21ms/step - loss: 0.4151 - accuracy: 0.8101 - val_loss: 0.5270 - val_accuracy: 0.7485 - lr: 0.0010
# Epoch 5/200
# 282/282 [==============================] - 8s 27ms/step - loss: 0.3946 - accuracy: 0.8215 - val_loss: 0.4481 - val_accuracy: 0.7904 - lr: 0.0010
# Epoch 6/200
# 282/282 [==============================] - 6s 22ms/step - loss: 0.3661 - accuracy: 0.8388 - val_loss: 0.4629 - val_accuracy: 0.7904 - lr: 0.0010
# Epoch 7/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.3356 - accuracy: 0.8510 - val_loss: 0.4678 - val_accuracy: 0.7924 - lr: 0.0010
# Epoch 8/200
# 282/282 [==============================] - 6s 23ms/step - loss: 0.3160 - accuracy: 0.8672 - val_loss: 0.4818 - val_accuracy: 0.8004 - lr: 0.0010
# Epoch 9/200
# Epoch 25/200
# 282/282 [==============================] - 6s 21ms/step - loss: 0.1067 - accuracy: 0.9583 - val_loss: 0.8140 - val_accuracy: 0.8044 - lr: 9.9800e-04
# Epoch 26/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.1104 - accuracy: 0.9534 - val_loss: 0.9301 - val_accuracy: 0.7844 - lr: 9.9800e-04
# Epoch 27/200
# 282/282 [==============================] - 6s 22ms/step - loss: 0.0980 - accuracy: 0.9607 - val_loss: 0.9691 - val_accuracy: 0.8024 - lr: 9.9800e-04
# Epoch 28/200
# 282/282 [==============================] - 5s 19ms/step - loss: 0.1117 - accuracy: 0.9591 - val_loss: 0.9300 - val_accuracy: 0.7944 - lr: 9.9700e-04
# Epoch 29/200
# 282/282 [==============================] - 6s 21ms/step - loss: 0.0879 - accuracy: 0.9631 - val_loss: 1.0569 - val_accuracy: 0.7844 - lr: 9.9700e-04
# Epoch 30/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.0882 - accuracy: 0.9642 - val_loss: 0.9829 - val_accuracy: 0.7764 - lr: 9.9700e-04
# Epoch 31/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.0956 - accuracy: 0.9642 - val_loss: 0.9239 - val_accuracy: 0.8104 - lr: 9.9700e-04
# Epoch 32/200
# 282/282 [==============================] - 6s 21ms/step - loss: 0.0886 - accuracy: 0.9642 - val_loss: 0.8312 - val_accuracy: 0.7964 - lr: 9.9700e-04
# Epoch 33/200
# 282/282 [==============================] - 6s 20ms/step - loss: 0.0955 - accuracy: 0.9636 - val_loss: 1.0118 - val_accuracy: 0.8024 - lr: 9.9601e-04
# Epoch 34/200
# 282/282 [==============================] - 6s 22ms/step - loss: 0.0863 - accuracy: 0.9638 - val_loss: 0.9846 - val_accuracy: 0.7824 - lr: 9.9601e-04
# Epoch 35/200
# 282/282 [==============================] - 5s 19ms/step - loss: 0.0928 - accuracy: 0.9596 - val_loss: 0.9717 - val_accuracy: 0.7944 - lr: 9.9601e-04
# Epoch 36/200
# 282/282 [==============================] - 6s 21ms/step - loss: 0.0686 - accuracy: 0.9707 - val_loss: 0.9917 - val_accuracy: 0.8084 - lr: 9.9601e-04
# Epoch 37/200
# 282/282 [==============================] - 6s 21ms/step - loss: 0.0811 - accuracy: 0.9716 - val_loss: 0.8787 - val_accuracy: 0.7804 - lr: 9.9601e-04

# %%
# Plot the training histories
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the model
model.save('Xception')
