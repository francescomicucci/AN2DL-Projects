# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Progetto AN2DL/3_KerasApplicationsTesting
# Out:
# Mounted at /gdrive
# /gdrive/.shortcut-targets-by-id/1ygSQdg0_3KzCXK0mWufNykWjfoYjWqKH/Progetto AN2DL/FeatureExtractorTesting

# %% [markdown]
# ### Import libraries

# %%
# Hide warnings
seed  = 42
import os

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold

# %% [markdown]
# ### Load and process the dataset

# %%
# Load data
data = np.load('../clean_data.npz', allow_pickle=True)

# Save labels in a new list (image pixel values are float in [0, 1])
images = data['data']

# Save labels in a new list
labels = data['labels']

# Print data shape
print(images.shape, labels.shape)
# Out:
# (5004, 96, 96, 3) (5004,)

# %%
# Number of images to display
num_img = 100

# Create subplots for displaying images
fig, axes = plt.subplots(10, num_img//10, figsize=(20, 20))
for i in range(num_img):
    ax = axes[i%10, i%num_img//10]
    ax.imshow(np.clip(images[i], 0, 255))  # Display clipped item images
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Convert labels from string to integer
num_labels = []
for label in labels:
  if label == "healthy":
    num_labels.append(0)
  else:
    num_labels.append(1)

# Convert labels in the one-hot encoding format
num_labels = np.array(num_labels)
labels = tfk.utils.to_categorical(num_labels, 2)

# Split data into train and val sets
X_train, X_val, y_train, y_val = train_test_split(
    images,
    labels,
    test_size=0.1,
    stratify=labels
)

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (4503, 96, 96, 3), y_train shape: (4503, 2)
# X_val shape: (501, 96, 96, 3), y_val shape: (501, 2)

# %% [markdown]
# ### ConvNeXtTiny

# %%
# Import Feature Extractor with specified settings
feature_extractor = tfk.applications.ConvNeXtTiny(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    pooling='avg',
    include_preprocessing=True,
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_tiny_notop.h5
# 111650432/111650432 [==============================] - 0s 0us/step

# %% [markdown]
# ### Model

# %%
# Define network parameters/callbacks
dropout_rate = 1/10
learning_rate = 1e-3

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.999,
    mode='max',
    min_lr=1e-5
)

early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=20,
    restore_best_weights=True
)

# %%
def build_model(feature_extractor, dropout_rate, learning_rate=0.001):
  # Use the supernet as feature extractor, i.e. freeze all its weigths
  feature_extractor.trainable = False

  # Create an input layer with shape (96, 96, 3)
  inputs = tfk.Input(shape=(96, 96, 3), name='Input')

  # Connect FeatureExtractor to the input
  x = feature_extractor(inputs)

  # Hidden layers
  x = tfkl.Dense(units=64, name='HiddenDense1')(x)
  x = tfkl.Activation('relu', name='HiddenActivation1')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)
  x = tfkl.Dense(units=64, name='HiddenDense2')(dropout)
  x = tfkl.Activation('relu', name='HiddenActivation2')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)

  # Add a Dense layer with 2 unit and softmax activation as the classifier
  outputs = tfkl.Dense(2, activation='softmax')(dropout)

  # Create a Model connecting input and output
  model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

  # Compile the model with Categorical Cross-Entropy loss and Adam optimizer
  model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                optimizer=tfk.optimizers.Adam(learning_rate),
                metrics=['accuracy'])

  # Return the model
  return model

# %%
model = build_model(feature_extractor, dropout_rate, learning_rate)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  convnext_tiny (Functional)  (None, 768)               27820128
#
#  HiddenDense1 (Dense)        (None, 64)                49216
#
#  HiddenActivation1 (Activat  (None, 64)                0
#  ion)
#
#  dropout (Dropout)           (None, 64)                0
#
#  HiddenDense2 (Dense)        (None, 64)                4160
#
#  HiddenActivation2 (Activat  (None, 64)                0
#  ion)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 27873634 (106.33 MB)
# Trainable params: 53506 (209.01 KB)
# Non-trainable params: 27820128 (106.13 MB)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = X_train*255,
    y = y_train,
    batch_size = 16,
    epochs = 200,
    validation_data = (X_val*255, y_val),
    callbacks = [early_stopping, lr_scheduler]
).history
# Out:
# Epoch 1/200
# 282/282 [==============================] - 44s 72ms/step - loss: 0.5522 - accuracy: 0.7160 - val_loss: 0.4628 - val_accuracy: 0.7884 - lr: 0.0010
# Epoch 2/200
# 282/282 [==============================] - 13s 48ms/step - loss: 0.4579 - accuracy: 0.7826 - val_loss: 0.4668 - val_accuracy: 0.7824 - lr: 0.0010
# Epoch 3/200
# 282/282 [==============================] - 12s 43ms/step - loss: 0.4215 - accuracy: 0.8012 - val_loss: 0.4337 - val_accuracy: 0.7884 - lr: 0.0010
# Epoch 4/200
# 282/282 [==============================] - 12s 43ms/step - loss: 0.3838 - accuracy: 0.8261 - val_loss: 0.4366 - val_accuracy: 0.7864 - lr: 0.0010
# Epoch 5/200
# 282/282 [==============================] - 15s 52ms/step - loss: 0.3661 - accuracy: 0.8303 - val_loss: 0.4417 - val_accuracy: 0.7804 - lr: 0.0010
# Epoch 6/200
# 282/282 [==============================] - 13s 45ms/step - loss: 0.3493 - accuracy: 0.8408 - val_loss: 0.4119 - val_accuracy: 0.8184 - lr: 0.0010
# Epoch 7/200
# 282/282 [==============================] - 12s 43ms/step - loss: 0.3237 - accuracy: 0.8585 - val_loss: 0.4075 - val_accuracy: 0.7984 - lr: 0.0010
# Epoch 8/200
# 282/282 [==============================] - 12s 43ms/step - loss: 0.3221 - accuracy: 0.8517 - val_loss: 0.4981 - val_accuracy: 0.7645 - lr: 0.0010
# Epoch 9/200
# 282/282 [==============================] - 12s 43ms/step - loss: 0.3033 - accuracy: 0.8725 - val_loss: 0.4212 - val_accuracy: 0.8224 - lr: 0.0010
# Epoch 10/200
# 282/282 [==============================] - 13s 46ms/step - loss: 0.3016 - accuracy: 0.8728 - val_loss: 0.4345 - val_accuracy: 0.8064 - lr: 0.0010
# Epoch 11/200
# 282/282 [==============================] - 13s 45ms/step - loss: 0.2884 - accuracy: 0.8774 - val_loss: 0.4149 - val_accuracy: 0.8224 - lr: 0.0010
# Epoch 12/200
# 282/282 [==============================] - 13s 45ms/step - loss: 0.2722 - accuracy: 0.8845 - val_loss: 0.4174 - val_accuracy: 0.8244 - lr: 0.0010
# Epoch 13/200
# 282/282 [==============================] - 13s 45ms/step - loss: 0.2601 - accuracy: 0.8914 - val_loss: 0.4265 - val_accuracy: 0.8244 - lr: 0.0010
# Epoch 14/200
# 282/282 [==============================] - 13s 45ms/step - loss: 0.2583 - accuracy: 0.8899 - val_loss: 0.4407 - val_accuracy: 0.8323 - lr: 0.0010
# Epoch 15/200
