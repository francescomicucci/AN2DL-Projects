# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Progetto AN2DL/3_KerasApplicationsTesting
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/Progetto AN2DL/FeatureExtractorTesting

# %% [markdown]
# ### Import libraries

# %%
# Hide warnings
seed  = 42
import os

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold

# %% [markdown]
# ### Load and process the dataset

# %%
# Load data
data = np.load('../clean_data.npz', allow_pickle=True)

# Save labels in a new list (image pixel values are float in [0, 1])
images = data['data']

# Save labels in a new list
labels = data['labels']

# Print data shape
print(images.shape, labels.shape)
# Out:
# (5004, 96, 96, 3) (5004,)

# %%
# Number of images to display
num_img = 100

# Create subplots for displaying images
fig, axes = plt.subplots(10, num_img//10, figsize=(20, 20))
for i in range(num_img):
    ax = axes[i%10, i%num_img//10]
    ax.imshow(np.clip(images[i], 0, 255))  # Display clipped item images
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Convert labels from string to integer
num_labels = []
for label in labels:
  if label == "healthy":
    num_labels.append(0)
  else:
    num_labels.append(1)

# Convert labels in the one-hot encoding format
num_labels = np.array(num_labels)
labels = tfk.utils.to_categorical(num_labels, 2)

# Split data into train and val sets
X_train, X_val, y_train, y_val = train_test_split(
    images,
    labels,
    test_size=0.1,
    stratify=labels
)

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (4503, 96, 96, 3), y_train shape: (4503, 2)
# X_val shape: (501, 96, 96, 3), y_val shape: (501, 2)

# %% [markdown]
# ### ConvNeXtXLarge

# %%
# Import Feature Extractor with specified settings
feature_extractor = tfk.applications.ConvNeXtXLarge(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    pooling='avg',
    include_preprocessing=True,
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_xlarge_notop.h5
# 1393257616/1393257616 [==============================] - 6s 0us/step

# %% [markdown]
# ### Model

# %%
# Define network parameters/callbacks
dropout_rate = 1/10
learning_rate = 1e-3

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.999,
    mode='max',
    min_lr=1e-5
)

early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=20,
    restore_best_weights=True
)

# %%
def build_model(feature_extractor, dropout_rate, learning_rate=0.001):
  # Use the supernet as feature extractor, i.e. freeze all its weigths
  feature_extractor.trainable = False

  # Create an input layer with shape (96, 96, 3)
  inputs = tfk.Input(shape=(96, 96, 3), name='Input')

  # Connect FeatureExtractor to the input
  x = feature_extractor(inputs)

  # Hidden layers
  x = tfkl.Dense(units=64, name='HiddenDense1')(x)
  x = tfkl.Activation('relu', name='HiddenActivation1')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)
  x = tfkl.Dense(units=64, name='HiddenDense2')(dropout)
  x = tfkl.Activation('relu', name='HiddenActivation2')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)

  # Add a Dense layer with 2 unit and softmax activation as the classifier
  outputs = tfkl.Dense(2, activation='softmax')(dropout)

  # Create a Model connecting input and output
  model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

  # Compile the model with Categorical Cross-Entropy loss and Adam optimizer
  model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                optimizer=tfk.optimizers.Adam(learning_rate),
                metrics=['accuracy'])

  # Return the model
  return model

# %%
model = build_model(feature_extractor, dropout_rate, learning_rate)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  convnext_xlarge (Functiona  (None, 2048)              348147968
#  l)
#
#  HiddenDense1 (Dense)        (None, 64)                131136
#
#  HiddenActivation1 (Activat  (None, 64)                0
#  ion)
#
#  dropout (Dropout)           (None, 64)                0
#
#  HiddenDense2 (Dense)        (None, 64)                4160
#
#  HiddenActivation2 (Activat  (None, 64)                0
#  ion)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 348283394 (1.30 GB)
# Trainable params: 135426 (529.01 KB)
# Non-trainable params: 348147968 (1.30 GB)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = X_train*255,
    y = y_train,
    batch_size = 16,
    epochs = 200,
    validation_data = (X_val*255, y_val),
    callbacks = [early_stopping, lr_scheduler]
).history
# Out:
# Epoch 1/200
# 282/282 [==============================] - 100s 248ms/step - loss: 0.4742 - accuracy: 0.7797 - val_loss: 0.3657 - val_accuracy: 0.8443 - lr: 0.0010
# Epoch 2/200
# 282/282 [==============================] - 54s 192ms/step - loss: 0.3475 - accuracy: 0.8425 - val_loss: 0.3521 - val_accuracy: 0.8403 - lr: 0.0010
# Epoch 3/200
# 282/282 [==============================] - 60s 213ms/step - loss: 0.2897 - accuracy: 0.8728 - val_loss: 0.3573 - val_accuracy: 0.8563 - lr: 0.0010
# Epoch 4/200
# 282/282 [==============================] - 54s 191ms/step - loss: 0.2688 - accuracy: 0.8856 - val_loss: 0.3272 - val_accuracy: 0.8563 - lr: 0.0010
# Epoch 5/200
# 282/282 [==============================] - 55s 194ms/step - loss: 0.2453 - accuracy: 0.8963 - val_loss: 0.3185 - val_accuracy: 0.8743 - lr: 0.0010
# Epoch 6/200
# 282/282 [==============================] - 59s 208ms/step - loss: 0.2288 - accuracy: 0.9061 - val_loss: 0.3562 - val_accuracy: 0.8623 - lr: 0.0010
# Epoch 7/200
# 282/282 [==============================] - 59s 209ms/step - loss: 0.2193 - accuracy: 0.9087 - val_loss: 0.3228 - val_accuracy: 0.8703 - lr: 0.0010
# Epoch 8/200
# 282/282 [==============================] - 59s 208ms/step - loss: 0.1881 - accuracy: 0.9212 - val_loss: 0.3584 - val_accuracy: 0.8743 - lr: 0.0010
# Epoch 9/200
# 282/282 [==============================] - 59s 207ms/step - loss: 0.1915 - accuracy: 0.9189 - val_loss: 0.3375 - val_accuracy: 0.8703 - lr: 0.0010
# Epoch 10/200
# 282/282 [==============================] - 60s 213ms/step - loss: 0.1629 - accuracy: 0.9347 - val_loss: 0.3451 - val_accuracy: 0.8762 - lr: 0.0010
# Epoch 11/200
# 282/282 [==============================] - 59s 208ms/step - loss: 0.1477 - accuracy: 0.9378 - val_loss: 0.3908 - val_accuracy: 0.8743 - lr: 0.0010
# Epoch 12/200
# 282/282 [==============================] - 59s 208ms/step - loss: 0.1596 - accuracy: 0.9345 - val_loss: 0.3210 - val_accuracy: 0.8762 - lr: 0.0010
# Epoch 13/200
# 282/282 [==============================] - 60s 213ms/step - loss: 0.1436 - accuracy: 0.9394 - val_loss: 0.3815 - val_accuracy: 0.8882 - lr: 0.0010
# Epoch 14/200
# 282/282 [==============================] - 54s 190ms/step - loss: 0.1436 - accuracy: 0.9420 - val_loss: 0.4011 - val_accuracy: 0.8623 - lr: 0.0010
# Epoch 15/200
# 282/282 [==============================] - 59s 208ms/step - loss: 0.0724 - accuracy: 0.9709 - val_loss: 0.4693 - val_accuracy: 0.8743 - lr: 9.9800e-04
# Epoch 34/200
# 282/282 [==============================] - 54s 190ms/step - loss: 0.0694 - accuracy: 0.9707 - val_loss: 0.5751 - val_accuracy: 0.8962 - lr: 9.9800e-04
# Epoch 35/200
# 282/282 [==============================] - 53s 189ms/step - loss: 0.0641 - accuracy: 0.9731 - val_loss: 0.5144 - val_accuracy: 0.8683 - lr: 9.9700e-04
# Epoch 36/200
# 282/282 [==============================] - 59s 208ms/step - loss: 0.0718 - accuracy: 0.9716 - val_loss: 0.5488 - val_accuracy: 0.8762 - lr: 9.9700e-04
# Epoch 37/200
# 282/282 [==============================] - 59s 208ms/step - loss: 0.0810 - accuracy: 0.9651 - val_loss: 0.4727 - val_accuracy: 0.8962 - lr: 9.9700e-04
# Epoch 38/200
# 282/282 [==============================] - 59s 209ms/step - loss: 0.0586 - accuracy: 0.9749 - val_loss: 0.4410 - val_accuracy: 0.8962 - lr: 9.9700e-04
# Epoch 39/200
# 282/282 [==============================] - 59s 208ms/step - loss: 0.0724 - accuracy: 0.9678 - val_loss: 0.4215 - val_accuracy: 0.8982 - lr: 9.9700e-04
# Epoch 40/200
# 282/282 [==============================] - 59s 208ms/step - loss: 0.0569 - accuracy: 0.9765 - val_loss: 0.5655 - val_accuracy: 0.8902 - lr: 9.9601e-04
# Epoch 41/200
# 282/282 [==============================] - 59s 208ms/step - loss: 0.0594 - accuracy: 0.9769 - val_loss: 0.7242 - val_accuracy: 0.8463 - lr: 9.9601e-04
# Epoch 42/200
# 282/282 [==============================] - 59s 207ms/step - loss: 0.0689 - accuracy: 0.9727 - val_loss: 0.4573 - val_accuracy: 0.8762 - lr: 9.9601e-04
# Epoch 43/200
# 282/282 [==============================] - 59s 208ms/step - loss: 0.0595 - accuracy: 0.9751 - val_loss: 0.5454 - val_accuracy: 0.8982 - lr: 9.9601e-04
# Epoch 44/200
# 282/282 [==============================] - 54s 192ms/step - loss: 0.0612 - accuracy: 0.9731 - val_loss: 0.5882 - val_accuracy: 0.8743 - lr: 9.9601e-04
# Epoch 45/200
# 282/282 [==============================] - 59s 209ms/step - loss: 0.0641 - accuracy: 0.9751 - val_loss: 0.5886 - val_accuracy: 0.8822 - lr: 9.9501e-04
# Epoch 46/200
# 282/282 [==============================] - 54s 192ms/step - loss: 0.0588 - accuracy: 0.9776 - val_loss: 0.5201 - val_accuracy: 0.8782 - lr: 9.9501e-04
# Epoch 47/200
# 282/282 [==============================] - 59s 209ms/step - loss: 0.0547 - accuracy: 0.9787 - val_loss: 0.5487 - val_accuracy: 0.8942 - lr: 9.9501e-04
# Epoch 48/200
# 282/282 [==============================] - 59s 210ms/step - loss: 0.0490 - accuracy: 0.9776 - val_loss: 0.6828 - val_accuracy: 0.8723 - lr: 9.9501e-04
# Epoch 49/200
# 282/282 [==============================] - 60s 213ms/step - loss: 0.0522 - accuracy: 0.9785 - val_loss: 0.6012 - val_accuracy: 0.8723 - lr: 9.9501e-04

# %%
# Plot the training histories
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the model
model.save('ConvNeXtXLarge')
