# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Progetto AN2DL/3_KerasApplicationsTesting
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/Progetto AN2DL/FeatureExtractorTesting

# %% [markdown]
# ### Import libraries

# %%
# Hide warnings
seed  = 42
import os

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold

# %% [markdown]
# ### Load and process the dataset

# %%
# Load data
data = np.load('../clean_data.npz', allow_pickle=True)

# Save labels in a new list (image pixel values are float in [0, 1])
images = data['data']

# Save labels in a new list
labels = data['labels']

# Print data shape
print(images.shape, labels.shape)
# Out:
# (5004, 96, 96, 3) (5004,)

# %%
# Number of images to display
num_img = 100

# Create subplots for displaying images
fig, axes = plt.subplots(10, num_img//10, figsize=(20, 20))
for i in range(num_img):
    ax = axes[i%10, i%num_img//10]
    ax.imshow(np.clip(images[i], 0, 255))  # Display clipped item images
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Convert labels from string to integer
num_labels = []
for label in labels:
  if label == "healthy":
    num_labels.append(0)
  else:
    num_labels.append(1)

# Convert labels in the one-hot encoding format
num_labels = np.array(num_labels)
labels = tfk.utils.to_categorical(num_labels, 2)

# Split data into train and val sets
X_train, X_val, y_train, y_val = train_test_split(
    images,
    labels,
    test_size=0.1,
    stratify=labels
)

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (4503, 96, 96, 3), y_train shape: (4503, 2)
# X_val shape: (501, 96, 96, 3), y_val shape: (501, 2)

# %% [markdown]
# ### EfficientNetV2S

# %%
# Import Feature Extractor with specified settings
feature_extractor = tfk.applications.EfficientNetV2S(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    pooling='avg',
    include_preprocessing=True,
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-s_notop.h5
# 82420632/82420632 [==============================] - 5s 0us/step

# %% [markdown]
# ### Model

# %%
# Define network parameters/callbacks
dropout_rate = 1/10
learning_rate = 1e-3

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.999,
    mode='max',
    min_lr=1e-5
)

early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=20,
    restore_best_weights=True
)

# %%
def build_model(feature_extractor, dropout_rate, learning_rate=0.001):
  # Use the supernet as feature extractor, i.e. freeze all its weigths
  feature_extractor.trainable = False

  # Create an input layer with shape (96, 96, 3)
  inputs = tfk.Input(shape=(96, 96, 3), name='Input')

  # Connect FeatureExtractor to the input
  x = feature_extractor(inputs)

  # Hidden layers
  x = tfkl.Dense(units=64, name='HiddenDense1')(x)
  x = tfkl.Activation('relu', name='HiddenActivation1')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)
  x = tfkl.Dense(units=64, name='HiddenDense2')(dropout)
  x = tfkl.Activation('relu', name='HiddenActivation2')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)

  # Add a Dense layer with 2 unit and softmax activation as the classifier
  outputs = tfkl.Dense(2, activation='softmax')(dropout)

  # Create a Model connecting input and output
  model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

  # Compile the model with Categorical Cross-Entropy loss and Adam optimizer
  model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                optimizer=tfk.optimizers.Adam(learning_rate),
                metrics=['accuracy'])

  # Return the model
  return model

# %%
model = build_model(feature_extractor, dropout_rate, learning_rate)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  efficientnetv2-s (Function  (None, 1280)              20331360
#  al)
#
#  HiddenDense1 (Dense)        (None, 64)                81984
#
#  HiddenActivation1 (Activat  (None, 64)                0
#  ion)
#
#  dropout (Dropout)           (None, 64)                0
#
#  HiddenDense2 (Dense)        (None, 64)                4160
#
#  HiddenActivation2 (Activat  (None, 64)                0
#  ion)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 20417634 (77.89 MB)
# Trainable params: 86274 (337.01 KB)
# Non-trainable params: 20331360 (77.56 MB)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = X_train*255,
    y = y_train,
    batch_size = 16,
    epochs = 200,
    validation_data = (X_val*255, y_val),
    callbacks = [early_stopping, lr_scheduler]
).history
# Out:
# Epoch 1/200
# 282/282 [==============================] - 39s 45ms/step - loss: 0.4996 - accuracy: 0.7468 - val_loss: 0.4102 - val_accuracy: 0.8224 - lr: 0.0010
# Epoch 2/200
# 282/282 [==============================] - 8s 29ms/step - loss: 0.4245 - accuracy: 0.8059 - val_loss: 0.4304 - val_accuracy: 0.8164 - lr: 0.0010
# Epoch 3/200
# 282/282 [==============================] - 7s 24ms/step - loss: 0.3869 - accuracy: 0.8250 - val_loss: 0.3765 - val_accuracy: 0.8224 - lr: 0.0010
# Epoch 4/200
# 282/282 [==============================] - 9s 31ms/step - loss: 0.3686 - accuracy: 0.8334 - val_loss: 0.3770 - val_accuracy: 0.8244 - lr: 0.0010
# Epoch 5/200
# 282/282 [==============================] - 8s 29ms/step - loss: 0.3562 - accuracy: 0.8425 - val_loss: 0.3643 - val_accuracy: 0.8343 - lr: 0.0010
# Epoch 6/200
# 282/282 [==============================] - 8s 27ms/step - loss: 0.3431 - accuracy: 0.8539 - val_loss: 0.3672 - val_accuracy: 0.8443 - lr: 0.0010
# Epoch 7/200
# 282/282 [==============================] - 9s 32ms/step - loss: 0.3252 - accuracy: 0.8581 - val_loss: 0.3421 - val_accuracy: 0.8483 - lr: 0.0010
# Epoch 8/200
# 282/282 [==============================] - 7s 26ms/step - loss: 0.3143 - accuracy: 0.8645 - val_loss: 0.3496 - val_accuracy: 0.8423 - lr: 0.0010
# Epoch 9/200
# 282/282 [==============================] - 9s 31ms/step - loss: 0.2991 - accuracy: 0.8721 - val_loss: 0.3842 - val_accuracy: 0.8263 - lr: 0.0010
# 282/282 [==============================] - 8s 29ms/step - loss: 0.1813 - accuracy: 0.9265 - val_loss: 0.3709 - val_accuracy: 0.8623 - lr: 9.9900e-04
# Epoch 26/200
# 282/282 [==============================] - 7s 26ms/step - loss: 0.1801 - accuracy: 0.9278 - val_loss: 0.4230 - val_accuracy: 0.8643 - lr: 9.9900e-04
# Epoch 27/200
# 282/282 [==============================] - 8s 29ms/step - loss: 0.1845 - accuracy: 0.9285 - val_loss: 0.3912 - val_accuracy: 0.8403 - lr: 9.9900e-04
# Epoch 28/200
# 282/282 [==============================] - 7s 24ms/step - loss: 0.1746 - accuracy: 0.9316 - val_loss: 0.3906 - val_accuracy: 0.8623 - lr: 9.9900e-04
# Epoch 29/200
# 282/282 [==============================] - 9s 32ms/step - loss: 0.1737 - accuracy: 0.9265 - val_loss: 0.4196 - val_accuracy: 0.8623 - lr: 9.9800e-04
# Epoch 30/200
# 282/282 [==============================] - 8s 28ms/step - loss: 0.1661 - accuracy: 0.9345 - val_loss: 0.3760 - val_accuracy: 0.8543 - lr: 9.9800e-04
# Epoch 31/200
# 282/282 [==============================] - 8s 27ms/step - loss: 0.1698 - accuracy: 0.9300 - val_loss: 0.3870 - val_accuracy: 0.8583 - lr: 9.9800e-04
# Epoch 32/200
# 282/282 [==============================] - 9s 32ms/step - loss: 0.1602 - accuracy: 0.9345 - val_loss: 0.3862 - val_accuracy: 0.8543 - lr: 9.9800e-04
# Epoch 33/200
# 282/282 [==============================] - 7s 24ms/step - loss: 0.1604 - accuracy: 0.9367 - val_loss: 0.3770 - val_accuracy: 0.8523 - lr: 9.9800e-04
# Epoch 34/200
# 282/282 [==============================] - 8s 30ms/step - loss: 0.1443 - accuracy: 0.9458 - val_loss: 0.4064 - val_accuracy: 0.8623 - lr: 9.9700e-04
# Epoch 35/200
# 282/282 [==============================] - 7s 26ms/step - loss: 0.1463 - accuracy: 0.9429 - val_loss: 0.4311 - val_accuracy: 0.8503 - lr: 9.9700e-04
# Epoch 36/200
# 282/282 [==============================] - 8s 29ms/step - loss: 0.1463 - accuracy: 0.9423 - val_loss: 0.4166 - val_accuracy: 0.8683 - lr: 9.9700e-04
# Epoch 37/200
# 282/282 [==============================] - 7s 26ms/step - loss: 0.1451 - accuracy: 0.9456 - val_loss: 0.3858 - val_accuracy: 0.8503 - lr: 9.9700e-04
# Epoch 38/200
# 282/282 [==============================] - 9s 31ms/step - loss: 0.1435 - accuracy: 0.9436 - val_loss: 0.3892 - val_accuracy: 0.8743 - lr: 9.9700e-04

# %%
# Plot the training histories
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the model
model.save('EfficientNetV2S')
