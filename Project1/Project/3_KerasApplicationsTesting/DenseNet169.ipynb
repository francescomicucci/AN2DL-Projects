# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Progetto AN2DL/3_KerasApplicationsTesting
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/Progetto AN2DL/FeatureExtractorTesting

# %% [markdown]
# ### Import libraries

# %%
# Hide warnings
seed  = 42
import os

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold

# %% [markdown]
# ### Load and process the dataset

# %%
# Load data
data = np.load('../clean_data.npz', allow_pickle=True)

# Save labels in a new list (image pixel values are float in [0, 1])
images = data['data']

# Save labels in a new list
labels = data['labels']

# Print data shape
print(images.shape, labels.shape)
# Out:
# (5004, 96, 96, 3) (5004,)

# %%
# Number of images to display
num_img = 100

# Create subplots for displaying images
fig, axes = plt.subplots(10, num_img//10, figsize=(20, 20))
for i in range(num_img):
    ax = axes[i%10, i%num_img//10]
    ax.imshow(np.clip(images[i], 0, 255))  # Display clipped item images
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Convert labels from string to integer
num_labels = []
for label in labels:
  if label == "healthy":
    num_labels.append(0)
  else:
    num_labels.append(1)

# Convert labels in the one-hot encoding format
num_labels = np.array(num_labels)
labels = tfk.utils.to_categorical(num_labels, 2)

# Split data into train and val sets
X_train, X_val, y_train, y_val = train_test_split(
    images,
    labels,
    test_size=0.1,
    stratify=labels
)

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (4503, 96, 96, 3), y_train shape: (4503, 2)
# X_val shape: (501, 96, 96, 3), y_val shape: (501, 2)

# %% [markdown]
# ### DenseNet169

# %%
# Import Feature Extractor with specified settings
feature_extractor = tfk.applications.DenseNet169(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    pooling='avg',
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51877672/51877672 [==============================] - 0s 0us/step

# %% [markdown]
# ### Model

# %%
# Define network parameters/callbacks
dropout_rate = 1/10
learning_rate = 1e-3

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.999,
    mode='max',
    min_lr=1e-5
)

early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=20,
    restore_best_weights=True
)

# %%
def build_model(feature_extractor, dropout_rate, learning_rate=0.001):
  # Use the supernet as feature extractor, i.e. freeze all its weigths
  feature_extractor.trainable = False

  # Create an input layer with shape (96, 96, 3)
  inputs = tfk.Input(shape=(96, 96, 3), name='Input')

  # Connect FeatureExtractor to the input
  x = feature_extractor(inputs)

  # Hidden layers
  x = tfkl.Dense(units=64, name='HiddenDense1')(x)
  x = tfkl.Activation('relu', name='HiddenActivation1')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)
  x = tfkl.Dense(units=64, name='HiddenDense2')(dropout)
  x = tfkl.Activation('relu', name='HiddenActivation2')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)

  # Add a Dense layer with 2 unit and softmax activation as the classifier
  outputs = tfkl.Dense(2, activation='softmax')(dropout)

  # Create a Model connecting input and output
  model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

  # Compile the model with Categorical Cross-Entropy loss and Adam optimizer
  model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                optimizer=tfk.optimizers.Adam(learning_rate),
                metrics=['accuracy'])

  # Return the model
  return model

# %%
model = build_model(feature_extractor, dropout_rate, learning_rate)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  densenet169 (Functional)    (None, 1664)              12642880
#
#  HiddenDense1 (Dense)        (None, 64)                106560
#
#  HiddenActivation1 (Activat  (None, 64)                0
#  ion)
#
#  dropout (Dropout)           (None, 64)                0
#
#  HiddenDense2 (Dense)        (None, 64)                4160
#
#  HiddenActivation2 (Activat  (None, 64)                0
#  ion)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 12753730 (48.65 MB)
# Trainable params: 110850 (433.01 KB)
# Non-trainable params: 12642880 (48.23 MB)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = preprocess_input(X_train*255),
    y = y_train,
    batch_size = 16,
    epochs = 200,
    validation_data = (preprocess_input(X_val*255), y_val),
    callbacks = [early_stopping, lr_scheduler]
).history
# Out:
# Epoch 1/200
# 282/282 [==============================] - 37s 55ms/step - loss: 0.4878 - accuracy: 0.7602 - val_loss: 0.4391 - val_accuracy: 0.8044 - lr: 0.0010
# Epoch 2/200
# 282/282 [==============================] - 10s 34ms/step - loss: 0.3969 - accuracy: 0.8210 - val_loss: 0.4506 - val_accuracy: 0.7705 - lr: 0.0010
# Epoch 3/200
# 282/282 [==============================] - 9s 31ms/step - loss: 0.3627 - accuracy: 0.8434 - val_loss: 0.4091 - val_accuracy: 0.8224 - lr: 0.0010
# Epoch 4/200
# 282/282 [==============================] - 9s 33ms/step - loss: 0.3337 - accuracy: 0.8525 - val_loss: 0.3983 - val_accuracy: 0.8244 - lr: 0.0010
# Epoch 5/200
# 282/282 [==============================] - 10s 34ms/step - loss: 0.3022 - accuracy: 0.8679 - val_loss: 0.4561 - val_accuracy: 0.8024 - lr: 0.0010
# Epoch 6/200
# 282/282 [==============================] - 8s 29ms/step - loss: 0.2750 - accuracy: 0.8832 - val_loss: 0.4292 - val_accuracy: 0.8224 - lr: 0.0010
# Epoch 7/200
# 282/282 [==============================] - 10s 34ms/step - loss: 0.2471 - accuracy: 0.8938 - val_loss: 0.5174 - val_accuracy: 0.8044 - lr: 0.0010
# Epoch 8/200
# 282/282 [==============================] - 9s 31ms/step - loss: 0.2271 - accuracy: 0.9021 - val_loss: 0.4537 - val_accuracy: 0.8303 - lr: 0.0010
# Epoch 9/200
# 282/282 [==============================] - 8s 29ms/step - loss: 0.2091 - accuracy: 0.9114 - val_loss: 0.5297 - val_accuracy: 0.8303 - lr: 0.0010
# Epoch 10/200
# 282/282 [==============================] - 9s 32ms/step - loss: 0.1927 - accuracy: 0.9258 - val_loss: 0.5873 - val_accuracy: 0.8184 - lr: 0.0010
# Epoch 11/200
# 282/282 [==============================] - 8s 29ms/step - loss: 0.1748 - accuracy: 0.9287 - val_loss: 0.5669 - val_accuracy: 0.8224 - lr: 0.0010
# 282/282 [==============================] - 8s 28ms/step - loss: 0.0671 - accuracy: 0.9714 - val_loss: 0.8224 - val_accuracy: 0.8363 - lr: 9.9800e-04
# Epoch 29/200
# 282/282 [==============================] - 9s 33ms/step - loss: 0.0890 - accuracy: 0.9616 - val_loss: 0.8410 - val_accuracy: 0.8084 - lr: 9.9800e-04
# Epoch 30/200
# 282/282 [==============================] - 9s 33ms/step - loss: 0.0715 - accuracy: 0.9736 - val_loss: 0.9240 - val_accuracy: 0.8303 - lr: 9.9800e-04
# Epoch 31/200
# 282/282 [==============================] - 9s 31ms/step - loss: 0.0624 - accuracy: 0.9780 - val_loss: 1.0209 - val_accuracy: 0.8084 - lr: 9.9800e-04
# Epoch 32/200
# 282/282 [==============================] - 10s 35ms/step - loss: 0.0501 - accuracy: 0.9798 - val_loss: 1.0467 - val_accuracy: 0.8204 - lr: 9.9800e-04
# Epoch 33/200
# 282/282 [==============================] - 9s 33ms/step - loss: 0.0567 - accuracy: 0.9762 - val_loss: 1.1885 - val_accuracy: 0.8244 - lr: 9.9700e-04
# Epoch 34/200
# 282/282 [==============================] - 9s 32ms/step - loss: 0.0709 - accuracy: 0.9722 - val_loss: 0.9954 - val_accuracy: 0.8263 - lr: 9.9700e-04
# Epoch 35/200
# 282/282 [==============================] - 10s 35ms/step - loss: 0.0423 - accuracy: 0.9840 - val_loss: 1.0731 - val_accuracy: 0.8204 - lr: 9.9700e-04
# Epoch 36/200
# 282/282 [==============================] - 9s 32ms/step - loss: 0.0476 - accuracy: 0.9805 - val_loss: 1.1644 - val_accuracy: 0.8224 - lr: 9.9700e-04
# Epoch 37/200
# 282/282 [==============================] - 9s 32ms/step - loss: 0.0545 - accuracy: 0.9782 - val_loss: 1.1757 - val_accuracy: 0.8323 - lr: 9.9700e-04
# Epoch 38/200
# 282/282 [==============================] - 9s 33ms/step - loss: 0.0370 - accuracy: 0.9847 - val_loss: 1.3225 - val_accuracy: 0.8463 - lr: 9.9601e-04
# Epoch 39/200
# 282/282 [==============================] - 9s 32ms/step - loss: 0.0670 - accuracy: 0.9747 - val_loss: 0.8620 - val_accuracy: 0.8184 - lr: 9.9601e-04
# Epoch 40/200
# 282/282 [==============================] - 9s 32ms/step - loss: 0.0500 - accuracy: 0.9816 - val_loss: 1.0587 - val_accuracy: 0.8343 - lr: 9.9601e-04
# Epoch 41/200
# 282/282 [==============================] - 9s 32ms/step - loss: 0.0422 - accuracy: 0.9856 - val_loss: 0.9443 - val_accuracy: 0.8244 - lr: 9.9601e-04
# Epoch 42/200
# 282/282 [==============================] - 10s 35ms/step - loss: 0.0365 - accuracy: 0.9862 - val_loss: 1.2011 - val_accuracy: 0.8124 - lr: 9.9601e-04

# %%
# Plot the training histories
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the model
model.save('DenseNet169')
