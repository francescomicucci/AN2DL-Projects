# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Progetto AN2DL/3_KerasApplicationsTesting
# Out:
# Mounted at /gdrive
# /gdrive/.shortcut-targets-by-id/1ygSQdg0_3KzCXK0mWufNykWjfoYjWqKH/Progetto AN2DL/FeatureExtractorTesting

# %% [markdown]
# ### Import libraries

# %%
# Hide warnings
seed  = 42
import os

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold

# %% [markdown]
# ### Load and process the dataset

# %%
# Load data
data = np.load('../clean_data.npz', allow_pickle=True)

# Save labels in a new list (image pixel values are float in [0, 1])
images = data['data']

# Save labels in a new list
labels = data['labels']

# Print data shape
print(images.shape, labels.shape)
# Out:
# (5004, 96, 96, 3) (5004,)

# %%
# Number of images to display
num_img = 100

# Create subplots for displaying images
fig, axes = plt.subplots(10, num_img//10, figsize=(20, 20))
for i in range(num_img):
    ax = axes[i%10, i%num_img//10]
    ax.imshow(np.clip(images[i], 0, 255))  # Display clipped item images
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Convert labels from string to integer
num_labels = []
for label in labels:
  if label == "healthy":
    num_labels.append(0)
  else:
    num_labels.append(1)

# Convert labels in the one-hot encoding format
num_labels = np.array(num_labels)
labels = tfk.utils.to_categorical(num_labels, 2)

# Split data into train and val sets
X_train, X_val, y_train, y_val = train_test_split(
    images,
    labels,
    test_size=0.1,
    stratify=labels
)

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (4503, 96, 96, 3), y_train shape: (4503, 2)
# X_val shape: (501, 96, 96, 3), y_val shape: (501, 2)

# %% [markdown]
# ### ConvNeXtLarge

# %%
# Import Feature Extractor with specified settings
feature_extractor = tfk.applications.ConvNeXtLarge(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    pooling='avg',
    include_preprocessing=True,
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_large_notop.h5
# 785596384/785596384 [==============================] - 10s 0us/step

# %% [markdown]
# ### Model

# %%
# Define network parameters/callbacks
dropout_rate = 1/10
learning_rate = 1e-3

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.999,
    mode='max',
    min_lr=1e-5
)

early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=20,
    restore_best_weights=True
)

# %%
def build_model(feature_extractor, dropout_rate, learning_rate=0.001):
  # Use the supernet as feature extractor, i.e. freeze all its weigths
  feature_extractor.trainable = False

  # Create an input layer with shape (96, 96, 3)
  inputs = tfk.Input(shape=(96, 96, 3), name='Input')

  # Connect FeatureExtractor to the input
  x = feature_extractor(inputs)

  # Hidden layers
  x = tfkl.Dense(units=256, name='HiddenDense1')(x)
  x = tfkl.Activation('relu', name='HiddenActivation1')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)
  x = tfkl.Dense(units=256, name='HiddenDense2')(dropout)
  x = tfkl.Activation('relu', name='HiddenActivation2')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)

  # Add a Dense layer with 2 unit and softmax activation as the classifier
  outputs = tfkl.Dense(2, activation='softmax')(dropout)

  # Create a Model connecting input and output
  model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

  # Compile the model with Categorical Cross-Entropy loss and Adam optimizer
  model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                optimizer=tfk.optimizers.Adam(learning_rate),
                metrics=['accuracy'])

  # Return the model
  return model

# %%
model = build_model(feature_extractor, dropout_rate, learning_rate)
model.summary()

# %%
# Train the model
history = model.fit(
    x = X_train*255,
    y = y_train,
    batch_size = 16,
    epochs = 200,
    validation_data = (X_val*255, y_val),
    callbacks = [early_stopping, lr_scheduler]
).history
# Out:
# Epoch 1/200
# 282/282 [==============================] - 47s 108ms/step - loss: 0.4823 - accuracy: 0.7684 - val_loss: 0.4427 - val_accuracy: 0.7685 - lr: 1.0000e-04
# Epoch 2/200
# 282/282 [==============================] - 19s 66ms/step - loss: 0.3388 - accuracy: 0.8505 - val_loss: 0.3286 - val_accuracy: 0.8703 - lr: 1.0000e-04
# Epoch 3/200
# 282/282 [==============================] - 19s 66ms/step - loss: 0.2868 - accuracy: 0.8781 - val_loss: 0.2988 - val_accuracy: 0.8902 - lr: 1.0000e-04
# Epoch 4/200
# 282/282 [==============================] - 18s 63ms/step - loss: 0.2484 - accuracy: 0.8987 - val_loss: 0.3011 - val_accuracy: 0.8762 - lr: 1.0000e-04
# Epoch 5/200
# 282/282 [==============================] - 18s 65ms/step - loss: 0.2209 - accuracy: 0.9121 - val_loss: 0.2996 - val_accuracy: 0.8942 - lr: 1.0000e-04
# Epoch 6/200
# 282/282 [==============================] - 18s 63ms/step - loss: 0.1882 - accuracy: 0.9289 - val_loss: 0.3045 - val_accuracy: 0.8842 - lr: 1.0000e-04
# Epoch 7/200
# 282/282 [==============================] - 18s 63ms/step - loss: 0.1691 - accuracy: 0.9329 - val_loss: 0.3201 - val_accuracy: 0.8743 - lr: 1.0000e-04
# Epoch 8/200
# 282/282 [==============================] - 18s 65ms/step - loss: 0.1457 - accuracy: 0.9425 - val_loss: 0.2885 - val_accuracy: 0.8902 - lr: 1.0000e-04
# Epoch 9/200
# 282/282 [==============================] - 18s 63ms/step - loss: 0.1352 - accuracy: 0.9511 - val_loss: 0.3114 - val_accuracy: 0.8802 - lr: 1.0000e-04
# Epoch 10/200
# 282/282 [==============================] - 18s 63ms/step - loss: 0.1094 - accuracy: 0.9647 - val_loss: 0.3033 - val_accuracy: 0.8942 - lr: 1.0000e-04
# Epoch 26/200
# 282/282 [==============================] - 18s 64ms/step - loss: 0.0250 - accuracy: 0.9911 - val_loss: 0.4875 - val_accuracy: 0.8782 - lr: 9.9700e-05
# Epoch 27/200
# 282/282 [==============================] - 18s 63ms/step - loss: 0.0222 - accuracy: 0.9931 - val_loss: 0.4692 - val_accuracy: 0.8703 - lr: 9.9700e-05
# Epoch 28/200
# 282/282 [==============================] - 18s 63ms/step - loss: 0.0219 - accuracy: 0.9942 - val_loss: 0.4834 - val_accuracy: 0.8782 - lr: 9.9700e-05
# Epoch 29/200
# 282/282 [==============================] - 18s 64ms/step - loss: 0.0276 - accuracy: 0.9887 - val_loss: 0.4805 - val_accuracy: 0.8942 - lr: 9.9601e-05
# Epoch 30/200
# 282/282 [==============================] - 18s 64ms/step - loss: 0.0203 - accuracy: 0.9944 - val_loss: 0.5132 - val_accuracy: 0.8902 - lr: 9.9601e-05
# Epoch 31/200
# 282/282 [==============================] - 18s 64ms/step - loss: 0.0182 - accuracy: 0.9942 - val_loss: 0.4966 - val_accuracy: 0.8802 - lr: 9.9601e-05
# Epoch 32/200
# 282/282 [==============================] - 18s 63ms/step - loss: 0.0212 - accuracy: 0.9931 - val_loss: 0.5373 - val_accuracy: 0.8922 - lr: 9.9601e-05
# Epoch 33/200
# 282/282 [==============================] - 18s 63ms/step - loss: 0.0110 - accuracy: 0.9967 - val_loss: 0.5409 - val_accuracy: 0.8902 - lr: 9.9601e-05
# Epoch 34/200
# 282/282 [==============================] - 18s 64ms/step - loss: 0.0167 - accuracy: 0.9938 - val_loss: 0.5483 - val_accuracy: 0.8922 - lr: 9.9501e-05
# Epoch 35/200
# 282/282 [==============================] - 18s 63ms/step - loss: 0.0176 - accuracy: 0.9951 - val_loss: 0.5968 - val_accuracy: 0.8723 - lr: 9.9501e-05
# Epoch 36/200
# 282/282 [==============================] - 18s 64ms/step - loss: 0.0199 - accuracy: 0.9936 - val_loss: 0.5697 - val_accuracy: 0.8822 - lr: 9.9501e-05
# Epoch 37/200
# 282/282 [==============================] - 18s 63ms/step - loss: 0.0186 - accuracy: 0.9938 - val_loss: 0.5428 - val_accuracy: 0.8922 - lr: 9.9501e-05
# Epoch 38/200
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0186 - accuracy: 0.9931 - val_loss: 0.6006 - val_accuracy: 0.8942 - lr: 9.9501e-05

# %%
# Plot the training histories
plt.figure(figsize=(15,5))
plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='Model', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the model
model.save('ConvNeXtLarge')
