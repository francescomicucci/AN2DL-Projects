# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Progetto AN2DL/5_ImageAugmentation

# %% [markdown]
# ### Import libraries

# %%
# Hide warnings
import os

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np

import logging

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
from tensorflow.keras.preprocessing.image import ImageDataGenerator
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold
import pickle

# %% [markdown]
# ### Load and process the dataset

# %%
# Load data
data = np.load('../clean_data.npz', allow_pickle=True)

# Save labels in a new list (image pixel values are float in [0, 1])
images = data['data']

# Save labels in a new list
labels = data['labels']

# Print data shape
print(images.shape, labels.shape)
# Out:
# (5004, 96, 96, 3) (5004,)

# %%
# Convert labels from string to integer
num_labels = []
for label in labels:
  if label == "healthy":
    num_labels.append(0)
  else:
    num_labels.append(1)

# Convert labels in the one-hot encoding format
num_labels = np.array(num_labels)
labels = tfk.utils.to_categorical(num_labels, 2)

# Split data into train and val sets
X_train, X_val, y_train, y_val = train_test_split(
    images,
    labels,
    test_size=0.1,
    stratify=labels
)

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (4503, 96, 96, 3), y_train shape: (4503, 2)
# X_val shape: (501, 96, 96, 3), y_val shape: (501, 2)

# %% [markdown]
# ### ConvNeXtLarge

# %%
# Import Feature Extractor with specified settings
feature_extractor = tfk.applications.ConvNeXtLarge(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    pooling='avg',
    include_preprocessing=True,
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_large_notop.h5
# 785596384/785596384 [==============================] - 29s 0us/step

# %% [markdown]
# ### Model

# %%
# Define network parameters/callbacks
dropout_rate = 1/10
learning_rate = 1e-3

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.999,
    mode='max',
    min_lr=1e-5
)

early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=20,
    restore_best_weights=True
)

# %%
def build_model(feature_extractor, dropout_rate, learning_rate=0.001):
  # Use the supernet as feature extractor, i.e. freeze all its weigths
  feature_extractor.trainable = False

  # Create an input layer with shape (96, 96, 3)
  inputs = tfk.Input(shape=(96, 96, 3), name='Input')

  # Connect FeatureExtractor to the input
  x = feature_extractor(inputs)

  # Hidden layers
  x = tfkl.Dense(units=256, name='HiddenDense1')(x)
  x = tfkl.Activation('relu', name='HiddenActivation1')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)
  x = tfkl.Dense(units=256, name='HiddenDense2')(dropout)
  x = tfkl.Activation('relu', name='HiddenActivation2')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)

  # Add a Dense layer with 2 unit and softmax activation as the classifier
  outputs = tfkl.Dense(2, activation='softmax')(dropout)

  # Create a Model connecting input and output
  model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

  # Compile the model with Categorical Cross-Entropy loss and Adam optimizer
  model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                optimizer=tfk.optimizers.Adam(learning_rate),
                metrics=['accuracy'])

  # Return the model
  return model

# %% [markdown]
# ### Flip

# %%
model = build_model(feature_extractor, dropout_rate, learning_rate)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  convnext_large (Functional  (None, 1536)              196230336
#  )
#
#  HiddenDense1 (Dense)        (None, 256)               393472
#
#  HiddenActivation1 (Activat  (None, 256)               0
#  ion)
#
#  dropout (Dropout)           (None, 256)               0
#
#  HiddenDense2 (Dense)        (None, 256)               65792
#
#  HiddenActivation2 (Activat  (None, 256)               0
#  ion)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 2)                 514
#
# =================================================================
# Total params: 196690114 (750.31 MB)
# Trainable params: 459778 (1.75 MB)
# Non-trainable params: 196230336 (748.56 MB)
# _________________________________________________________________

# %%
train_datagen = ImageDataGenerator(
        horizontal_flip = True,
        vertical_flip = True,
        fill_mode='reflect')

train_datagen.fit(X_train*255)

# %%
history_flip = model.fit_generator(
    train_datagen.flow(X_train*255, y_train, batch_size=16),
    epochs=200,
    steps_per_epoch=len(X_train)/16,
    validation_data = (X_val*255, y_val),
    callbacks = [early_stopping, lr_scheduler]
    ).history
# Out:
# Epoch 1/200
# 281/281 [==============================] - 76s 173ms/step - loss: 0.4871 - accuracy: 0.7775 - val_loss: 0.3608 - val_accuracy: 0.8483 - lr: 0.0010
# Epoch 2/200
# 281/281 [==============================] - 37s 131ms/step - loss: 0.3541 - accuracy: 0.8457 - val_loss: 0.3669 - val_accuracy: 0.8523 - lr: 0.0010
# Epoch 3/200
# 281/281 [==============================] - 36s 127ms/step - loss: 0.3176 - accuracy: 0.8685 - val_loss: 0.3788 - val_accuracy: 0.8383 - lr: 0.0010
# Epoch 4/200
# 281/281 [==============================] - 36s 129ms/step - loss: 0.2764 - accuracy: 0.8839 - val_loss: 0.3333 - val_accuracy: 0.8723 - lr: 0.0010
# Epoch 5/200
# 281/281 [==============================] - 36s 130ms/step - loss: 0.2641 - accuracy: 0.8881 - val_loss: 0.2921 - val_accuracy: 0.8902 - lr: 0.0010
# Epoch 6/200
# 281/281 [==============================] - 36s 128ms/step - loss: 0.2420 - accuracy: 0.9018 - val_loss: 0.3074 - val_accuracy: 0.8703 - lr: 0.0010
# Epoch 7/200
# 281/281 [==============================] - 36s 128ms/step - loss: 0.2322 - accuracy: 0.9054 - val_loss: 0.3246 - val_accuracy: 0.8563 - lr: 0.0010
# Epoch 8/200
# 281/281 [==============================] - 36s 127ms/step - loss: 0.2109 - accuracy: 0.9118 - val_loss: 0.2681 - val_accuracy: 0.8862 - lr: 0.0010
# Epoch 9/200
# 281/281 [==============================] - 36s 127ms/step - loss: 0.2163 - accuracy: 0.9118 - val_loss: 0.3087 - val_accuracy: 0.8683 - lr: 0.0010
# Epoch 10/200
# 281/281 [==============================] - 36s 127ms/step - loss: 0.1947 - accuracy: 0.9152 - val_loss: 0.3102 - val_accuracy: 0.8882 - lr: 0.0010
# Epoch 11/200
# 281/281 [==============================] - 36s 127ms/step - loss: 0.1835 - accuracy: 0.9236 - val_loss: 0.3833 - val_accuracy: 0.8583 - lr: 9.9900e-04
# Epoch 12/200
# 281/281 [==============================] - 36s 129ms/step - loss: 0.1690 - accuracy: 0.9316 - val_loss: 0.2550 - val_accuracy: 0.8962 - lr: 9.9900e-04
# Epoch 13/200
# 281/281 [==============================] - 36s 129ms/step - loss: 0.1693 - accuracy: 0.9289 - val_loss: 0.2526 - val_accuracy: 0.9142 - lr: 9.9900e-04
# Epoch 14/200
# 281/281 [==============================] - 36s 129ms/step - loss: 0.1579 - accuracy: 0.9396 - val_loss: 0.2316 - val_accuracy: 0.9261 - lr: 9.9900e-04
# Epoch 15/200
# 281/281 [==============================] - 36s 127ms/step - loss: 0.1419 - accuracy: 0.9458 - val_loss: 0.2530 - val_accuracy: 0.9022 - lr: 9.9900e-04
# Epoch 16/200
# 281/281 [==============================] - 36s 127ms/step - loss: 0.1398 - accuracy: 0.9456 - val_loss: 0.3161 - val_accuracy: 0.8962 - lr: 9.9900e-04
# Epoch 17/200
# 281/281 [==============================] - 36s 127ms/step - loss: 0.1378 - accuracy: 0.9456 - val_loss: 0.2470 - val_accuracy: 0.9142 - lr: 9.9900e-04
# Epoch 18/200
# 281/281 [==============================] - 36s 127ms/step - loss: 0.1307 - accuracy: 0.9498 - val_loss: 0.2844 - val_accuracy: 0.9022 - lr: 9.9900e-04
# Epoch 19/200
# 281/281 [==============================] - 36s 127ms/step - loss: 0.1289 - accuracy: 0.9507 - val_loss: 0.2714 - val_accuracy: 0.8862 - lr: 9.9900e-04
# Epoch 20/200
# 281/281 [==============================] - 36s 127ms/step - loss: 0.1297 - accuracy: 0.9480 - val_loss: 0.2464 - val_accuracy: 0.9102 - lr: 9.9800e-04
# Epoch 21/200
# 281/281 [==============================] - 36s 127ms/step - loss: 0.1198 - accuracy: 0.9558 - val_loss: 0.3553 - val_accuracy: 0.8842 - lr: 9.9800e-04
# Epoch 22/200
# 281/281 [==============================] - 36s 128ms/step - loss: 0.1205 - accuracy: 0.9509 - val_loss: 0.2610 - val_accuracy: 0.9162 - lr: 9.9800e-04
# Epoch 23/200
# 281/281 [==============================] - 36s 127ms/step - loss: 0.1025 - accuracy: 0.9607 - val_loss: 0.2840 - val_accuracy: 0.9102 - lr: 9.9800e-04
# Epoch 24/200
# 281/281 [==============================] - 36s 128ms/step - loss: 0.1013 - accuracy: 0.9598 - val_loss: 0.3717 - val_accuracy: 0.8962 - lr: 9.9800e-04
# Epoch 25/200
# 281/281 [==============================] - 36s 127ms/step - loss: 0.1008 - accuracy: 0.9605 - val_loss: 0.2304 - val_accuracy: 0.9202 - lr: 9.9700e-04
# Epoch 26/200
# 281/281 [==============================] - 36s 128ms/step - loss: 0.1005 - accuracy: 0.9574 - val_loss: 0.2314 - val_accuracy: 0.9222 - lr: 9.9700e-04
# Epoch 27/200
# 281/281 [==============================] - 36s 128ms/step - loss: 0.0944 - accuracy: 0.9625 - val_loss: 0.3210 - val_accuracy: 0.9062 - lr: 9.9700e-04
# Epoch 28/200
# 281/281 [==============================] - 36s 128ms/step - loss: 0.0873 - accuracy: 0.9658 - val_loss: 0.2365 - val_accuracy: 0.9162 - lr: 9.9700e-04
# Epoch 29/200
# 281/281 [==============================] - 36s 128ms/step - loss: 0.0842 - accuracy: 0.9685 - val_loss: 0.2468 - val_accuracy: 0.9122 - lr: 9.9700e-04
# Epoch 30/200
# 281/281 [==============================] - 36s 129ms/step - loss: 0.0996 - accuracy: 0.9634 - val_loss: 0.2238 - val_accuracy: 0.9281 - lr: 9.9601e-04
# Epoch 31/200
# 281/281 [==============================] - 36s 127ms/step - loss: 0.0870 - accuracy: 0.9656 - val_loss: 0.2599 - val_accuracy: 0.9042 - lr: 9.9601e-04
# Epoch 32/200
# 281/281 [==============================] - 36s 127ms/step - loss: 0.0836 - accuracy: 0.9685 - val_loss: 0.2951 - val_accuracy: 0.9102 - lr: 9.9601e-04
# Epoch 33/200
# 281/281 [==============================] - 36s 128ms/step - loss: 0.0942 - accuracy: 0.9638 - val_loss: 0.2361 - val_accuracy: 0.9142 - lr: 9.9601e-04
# Epoch 34/200
# 281/281 [==============================] - 36s 127ms/step - loss: 0.0761 - accuracy: 0.9694 - val_loss: 0.2940 - val_accuracy: 0.9062 - lr: 9.9601e-04
# Epoch 35/200
# 281/281 [==============================] - 36s 127ms/step - loss: 0.0919 - accuracy: 0.9649 - val_loss: 0.2821 - val_accuracy: 0.9122 - lr: 9.9601e-04
# Epoch 36/200
# 281/281 [==============================] - 36s 127ms/step - loss: 0.0683 - accuracy: 0.9731 - val_loss: 0.3361 - val_accuracy: 0.9062 - lr: 9.9501e-04
# Epoch 37/200
# 281/281 [==============================] - 36s 128ms/step - loss: 0.0644 - accuracy: 0.9789 - val_loss: 0.2900 - val_accuracy: 0.9242 - lr: 9.9501e-04
# Epoch 38/200
# 281/281 [==============================] - 36s 127ms/step - loss: 0.0696 - accuracy: 0.9762 - val_loss: 0.4191 - val_accuracy: 0.8743 - lr: 9.9501e-04
# Epoch 39/200
# 281/281 [==============================] - 36s 127ms/step - loss: 0.0687 - accuracy: 0.9731 - val_loss: 0.3349 - val_accuracy: 0.9002 - lr: 9.9501e-04
# Epoch 40/200
# 281/281 [==============================] - 36s 126ms/step - loss: 0.0793 - accuracy: 0.9709 - val_loss: 0.3564 - val_accuracy: 0.8922 - lr: 9.9501e-04
# Epoch 41/200
# 281/281 [==============================] - 36s 126ms/step - loss: 0.0648 - accuracy: 0.9738 - val_loss: 0.3569 - val_accuracy: 0.9082 - lr: 9.9402e-04
# Epoch 42/200
# 281/281 [==============================] - 36s 127ms/step - loss: 0.0717 - accuracy: 0.9729 - val_loss: 0.3181 - val_accuracy: 0.9122 - lr: 9.9402e-04
# Epoch 43/200
# 281/281 [==============================] - 35s 126ms/step - loss: 0.0592 - accuracy: 0.9796 - val_loss: 0.3403 - val_accuracy: 0.9182 - lr: 9.9402e-04
# Epoch 44/200
# 281/281 [==============================] - 36s 126ms/step - loss: 0.0606 - accuracy: 0.9780 - val_loss: 0.2950 - val_accuracy: 0.9202 - lr: 9.9402e-04
# Epoch 45/200
# 281/281 [==============================] - 35s 126ms/step - loss: 0.0549 - accuracy: 0.9782 - val_loss: 0.3732 - val_accuracy: 0.9022 - lr: 9.9402e-04
# Epoch 46/200
# 281/281 [==============================] - 36s 126ms/step - loss: 0.0670 - accuracy: 0.9738 - val_loss: 0.3110 - val_accuracy: 0.9202 - lr: 9.9302e-04
# Epoch 47/200
# 281/281 [==============================] - 36s 126ms/step - loss: 0.0648 - accuracy: 0.9780 - val_loss: 0.2935 - val_accuracy: 0.9202 - lr: 9.9302e-04
# Epoch 48/200
# 281/281 [==============================] - 36s 127ms/step - loss: 0.0537 - accuracy: 0.9802 - val_loss: 0.3889 - val_accuracy: 0.9182 - lr: 9.9302e-04
# Epoch 49/200
# 281/281 [==============================] - 38s 134ms/step - loss: 0.0616 - accuracy: 0.9765 - val_loss: 0.3533 - val_accuracy: 0.9242 - lr: 9.9302e-04
# Epoch 50/200
# 281/281 [==============================] - 37s 130ms/step - loss: 0.0558 - accuracy: 0.9787 - val_loss: 0.3070 - val_accuracy: 0.9222 - lr: 9.9302e-04

# %%
# Save the model
model.save('Augmentation_Flip')
with open('Augmentation_Flip/history.pkl', 'wb') as f:
  pickle.dump(history_flip, f)

# %%
# Plot the training histories

# with open('v1/TestTimeAugmentation/history.pkl', 'rb') as f:
#   history = pickle.load(f)

plt.figure(figsize=(15,5))
# plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
# plt.plot(history['val_loss'], label='Baseline', alpha=.8, color='#ff7f0e')
plt.plot(history_flip['loss'], alpha=.3, color='#4D61E2', linestyle='--')
plt.plot(history_flip['val_loss'], label='Flip', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
# plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
# plt.plot(history['val_accuracy'], label='Baseline', alpha=.8, color='#ff7f0e')
plt.plot(history_flip['accuracy'], alpha=.3, color='#4D61E2', linestyle='--')
plt.plot(history_flip['val_accuracy'], label='Flip', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()
