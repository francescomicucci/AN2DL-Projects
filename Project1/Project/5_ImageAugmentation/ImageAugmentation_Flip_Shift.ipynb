# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Progetto AN2DL/5_ImageAugmentation

# %% [markdown]
# ### Import libraries

# %%
# Hide warnings
import os

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np

import logging

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
from tensorflow.keras.preprocessing.image import ImageDataGenerator
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold
import pickle

# %% [markdown]
# ### Load and process the dataset

# %%
# Load data
data = np.load('../clean_data.npz', allow_pickle=True)

# Save images in a new list (image pixel values are float in [0, 1])
images = data['data']

# Save labels in a new list
labels = data['labels']

# Print data shape
print(images.shape, labels.shape)
# Out:
# (5004, 96, 96, 3) (5004,)

# %%
# Convert labels from string to integer
num_labels = []
for label in labels:
  if label == "healthy":
    num_labels.append(0)
  else:
    num_labels.append(1)

# Convert labels in the one-hot encoding format
num_labels = np.array(num_labels)
labels = tfk.utils.to_categorical(num_labels, 2)

# Split data into train and val sets
X_train, X_val, y_train, y_val = train_test_split(
    images,
    labels,
    test_size=0.1,
    stratify=labels
)

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (4503, 96, 96, 3), y_train shape: (4503, 2)
# X_val shape: (501, 96, 96, 3), y_val shape: (501, 2)

# %% [markdown]
# ### ConvNeXtLarge

# %%
# Import Feature Extractor with specified settings
feature_extractor = tfk.applications.ConvNeXtLarge(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    pooling='avg',
    include_preprocessing=True,
)

# %% [markdown]
# ### Model

# %%
# Define network parameters/callbacks
dropout_rate = 1/10
learning_rate = 1e-3

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.999,
    mode='max',
    min_lr=1e-5
)

early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=30,
    restore_best_weights=True
)

# %%
def build_model(feature_extractor, dropout_rate, learning_rate=0.001):
  # Use the supernet as feature extractor, i.e. freeze all its weigths
  feature_extractor.trainable = False

  # Create an input layer with shape (96, 96, 3)
  inputs = tfk.Input(shape=(96, 96, 3), name='Input')

  # Connect FeatureExtractor to the input
  x = feature_extractor(inputs)

  # Hidden layers
  x = tfkl.Dense(units=256, name='HiddenDense1')(x)
  x = tfkl.Activation('relu', name='HiddenActivation1')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)
  x = tfkl.Dense(units=256, name='HiddenDense2')(dropout)
  x = tfkl.Activation('relu', name='HiddenActivation2')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)

  # Add a Dense layer with 2 unit and softmax activation as the classifier
  outputs = tfkl.Dense(2, activation='softmax')(dropout)

  # Create a Model connecting input and output
  model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

  # Compile the model with Categorical Cross-Entropy loss and Adam optimizer
  model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                optimizer=tfk.optimizers.Adam(learning_rate),
                metrics=['accuracy'])

  # Return the model
  return model

# %% [markdown]
# ### FLIP + SHIFT

# %%
model = build_model(feature_extractor, dropout_rate, learning_rate)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  convnext_large (Functional  (None, 1536)              196230336
#  )
#
#  HiddenDense1 (Dense)        (None, 256)               393472
#
#  HiddenActivation1 (Activat  (None, 256)               0
#  ion)
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  HiddenDense2 (Dense)        (None, 256)               65792
#
#  HiddenActivation2 (Activat  (None, 256)               0
#  ion)
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 196690114 (750.31 MB)
# Trainable params: 459778 (1.75 MB)
# Non-trainable params: 196230336 (748.56 MB)
# _________________________________________________________________

# %%
train_datagen = ImageDataGenerator(
        horizontal_flip=True,
        vertical_flip = True,
        width_shift_range = 0.1,
        height_shift_range = 0.1,
        fill_mode='reflect')

# %%
history_flip_shift = model.fit_generator(train_datagen.flow(X_train*255, y_train,
                              batch_size=16),
                              epochs=200,
                              steps_per_epoch=len(X_train)/16,
                              validation_data = (X_val*255, y_val),
                              callbacks = [early_stopping, lr_scheduler]
                              ).history
# Out:
# Epoch 1/200
# 281/281 [==============================] - 119s 212ms/step - loss: 0.5021 - accuracy: 0.7597 - val_loss: 0.3516 - val_accuracy: 0.8483 - lr: 0.0010
# Epoch 2/200
# 281/281 [==============================] - 43s 154ms/step - loss: 0.3877 - accuracy: 0.8237 - val_loss: 0.3528 - val_accuracy: 0.8643 - lr: 0.0010
# Epoch 3/200
# 281/281 [==============================] - 45s 160ms/step - loss: 0.3465 - accuracy: 0.8434 - val_loss: 0.2959 - val_accuracy: 0.8902 - lr: 0.0010
# Epoch 4/200
# 281/281 [==============================] - 43s 153ms/step - loss: 0.3230 - accuracy: 0.8590 - val_loss: 0.3013 - val_accuracy: 0.8643 - lr: 0.0010
# Epoch 5/200
# 281/281 [==============================] - 43s 153ms/step - loss: 0.2968 - accuracy: 0.8776 - val_loss: 0.2735 - val_accuracy: 0.8743 - lr: 0.0010
# Epoch 6/200
# 281/281 [==============================] - 42s 151ms/step - loss: 0.2740 - accuracy: 0.8856 - val_loss: 0.2748 - val_accuracy: 0.8822 - lr: 0.0010
# Epoch 7/200
# 281/281 [==============================] - 45s 159ms/step - loss: 0.2711 - accuracy: 0.8830 - val_loss: 0.3267 - val_accuracy: 0.8842 - lr: 0.0010
# Epoch 8/200
# 281/281 [==============================] - 43s 153ms/step - loss: 0.2634 - accuracy: 0.8894 - val_loss: 0.3126 - val_accuracy: 0.8862 - lr: 0.0010
# Epoch 9/200
# 281/281 [==============================] - 43s 151ms/step - loss: 0.2486 - accuracy: 0.8952 - val_loss: 0.2715 - val_accuracy: 0.8942 - lr: 9.9900e-04
# Epoch 40/200
# 281/281 [==============================] - 43s 151ms/step - loss: 0.1379 - accuracy: 0.9458 - val_loss: 0.2969 - val_accuracy: 0.8942 - lr: 9.9601e-04
# Epoch 41/200
# 281/281 [==============================] - 44s 155ms/step - loss: 0.1392 - accuracy: 0.9400 - val_loss: 0.2715 - val_accuracy: 0.9122 - lr: 9.9501e-04
# Epoch 42/200
# 281/281 [==============================] - 42s 150ms/step - loss: 0.1287 - accuracy: 0.9483 - val_loss: 0.3067 - val_accuracy: 0.9142 - lr: 9.9501e-04
# Epoch 43/200
# 281/281 [==============================] - 43s 152ms/step - loss: 0.1392 - accuracy: 0.9485 - val_loss: 0.3457 - val_accuracy: 0.9022 - lr: 9.9501e-04
# Epoch 44/200
# 281/281 [==============================] - 43s 154ms/step - loss: 0.1327 - accuracy: 0.9463 - val_loss: 0.2901 - val_accuracy: 0.9162 - lr: 9.9501e-04
# Epoch 45/200
# 281/281 [==============================] - 43s 154ms/step - loss: 0.1259 - accuracy: 0.9507 - val_loss: 0.2519 - val_accuracy: 0.9162 - lr: 9.9501e-04
# Epoch 46/200
# 281/281 [==============================] - 45s 160ms/step - loss: 0.1256 - accuracy: 0.9496 - val_loss: 0.3049 - val_accuracy: 0.8922 - lr: 9.9402e-04
# Epoch 47/200
# 281/281 [==============================] - 41s 146ms/step - loss: 0.1237 - accuracy: 0.9507 - val_loss: 0.2831 - val_accuracy: 0.9022 - lr: 9.9402e-04
# Epoch 48/200
# 281/281 [==============================] - 42s 148ms/step - loss: 0.1259 - accuracy: 0.9478 - val_loss: 0.2668 - val_accuracy: 0.9182 - lr: 9.9402e-04
# Epoch 49/200
# 281/281 [==============================] - 43s 152ms/step - loss: 0.1264 - accuracy: 0.9487 - val_loss: 0.2729 - val_accuracy: 0.9002 - lr: 9.9402e-04
# Epoch 50/200
# 281/281 [==============================] - 45s 160ms/step - loss: 0.1320 - accuracy: 0.9478 - val_loss: 0.2423 - val_accuracy: 0.9082 - lr: 9.9402e-04

# %%
# Plot the training histories
plt.figure(figsize=(15,5))
plt.plot(history_flip_shift['loss'], alpha=.3, color='#4D61E2', linestyle='--')
plt.plot(history_flip_shift['val_loss'], label='Filter', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history_flip_shift['accuracy'], alpha=.3, color='#4D61E2', linestyle='--')
plt.plot(history_flip_shift['val_accuracy'], label='Filter', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the model
model.save('Augmentation_Flip_Shift')
with open('Augmentation_Flip_Shift/history.pkl', 'wb') as f:
  pickle.dump(history_flip_shift, f)
