# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Progetto AN2DL/5_ImageAugmentation

# %% [markdown]
# ### Import libraries

# %%
# Hide warnings
import os

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np

import logging

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
from tensorflow.keras.preprocessing.image import ImageDataGenerator
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold
import pickle
from tqdm import tqdm

# %% [markdown]
# ### Load and process the dataset

# %%
# Load data
data = np.load('../clean_data.npz', allow_pickle=True)

# Save labels in a new list (image pixel values are float in [0, 1])
images = data['data']

# Save labels in a new list
labels = data['labels']

# Print data shape
print(images.shape, labels.shape)
# Out:
# (5004, 96, 96, 3) (5004,)

# %%
# Convert labels from string to integer
num_labels = []
for label in labels:
  if label == "healthy":
    num_labels.append(0)
  else:
    num_labels.append(1)

# Convert labels in the one-hot encoding format
num_labels = np.array(num_labels)
labels = tfk.utils.to_categorical(num_labels, 2)

# Split data into train and val sets
X_train, X_val, y_train, y_val = train_test_split(
    images,
    labels,
    test_size=0.1,
    stratify=labels
)

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (4503, 96, 96, 3), y_train shape: (4503, 2)
# X_val shape: (501, 96, 96, 3), y_val shape: (501, 2)

# %% [markdown]
# ### ConvNeXtLarge

# %%
# Import Feature Extractor with specified settings
feature_extractor = tfk.applications.ConvNeXtLarge(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    pooling='avg',
    include_preprocessing=True,
)

# %% [markdown]
# ### Model

# %%
# Define network parameters/callbacks
dropout_rate = 1/10
learning_rate = 1e-3

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.999,
    mode='max',
    min_lr=1e-5
)

early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=20,
    restore_best_weights=True
)

# %%
def build_model(feature_extractor, dropout_rate, learning_rate=0.001):
  # Use the supernet as feature extractor, i.e. freeze all its weigths
  feature_extractor.trainable = False

  # Create an input layer with shape (96, 96, 3)
  inputs = tfk.Input(shape=(96, 96, 3), name='Input')

  # Connect FeatureExtractor to the input
  x = feature_extractor(inputs)

  # Hidden layers
  x = tfkl.Dense(units=256, name='HiddenDense1')(x)
  x = tfkl.Activation('relu', name='HiddenActivation1')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)
  x = tfkl.Dense(units=256, name='HiddenDense2')(dropout)
  x = tfkl.Activation('relu', name='HiddenActivation2')(x)
  dropout = tfkl.Dropout(dropout_rate)(x)

  # Add a Dense layer with 2 unit and softmax activation as the classifier
  outputs = tfkl.Dense(2, activation='softmax')(dropout)

  # Create a Model connecting input and output
  model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

  # Compile the model with Categorical Cross-Entropy loss and Adam optimizer
  model.compile(loss=tfk.losses.CategoricalCrossentropy(),
                optimizer=tfk.optimizers.Adam(learning_rate),
                metrics=['accuracy'])

  # Return the model
  return model

# %% [markdown]
# ### Rotation

# %%
model = build_model(feature_extractor, dropout_rate, learning_rate)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  convnext_large (Functional  (None, 1536)              196230336
#  )
#
#  HiddenDense1 (Dense)        (None, 256)               393472
#
#  HiddenActivation1 (Activat  (None, 256)               0
#  ion)
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  HiddenDense2 (Dense)        (None, 256)               65792
#
#  HiddenActivation2 (Activat  (None, 256)               0
#  ion)
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 196690114 (750.31 MB)
# Trainable params: 459778 (1.75 MB)
# Non-trainable params: 196230336 (748.56 MB)
# _________________________________________________________________

# %%
train_datagen = ImageDataGenerator(
        rotation_range=20.,
        fill_mode='reflect')

train_datagen.fit(X_train*255)

# %%
history_rotation = model.fit_generator(
    train_datagen.flow(X_train*255, y_train, batch_size=16),
    epochs=200,
    steps_per_epoch=len(X_train)/16,
    validation_data = (X_val*255, y_val),
    callbacks = [early_stopping, lr_scheduler]
    ).history
# Out:
# Epoch 1/200
# 281/281 [==============================] - 63s 169ms/step - loss: 0.4871 - accuracy: 0.7717 - val_loss: 0.4888 - val_accuracy: 0.7625 - lr: 0.0010
# Epoch 2/200
# 281/281 [==============================] - 43s 152ms/step - loss: 0.3620 - accuracy: 0.8359 - val_loss: 0.3364 - val_accuracy: 0.8543 - lr: 0.0010
# Epoch 3/200
# 281/281 [==============================] - 42s 149ms/step - loss: 0.3117 - accuracy: 0.8661 - val_loss: 0.3064 - val_accuracy: 0.8643 - lr: 0.0010
# Epoch 4/200
# 281/281 [==============================] - 44s 155ms/step - loss: 0.2948 - accuracy: 0.8694 - val_loss: 0.3115 - val_accuracy: 0.8643 - lr: 0.0010
# Epoch 5/200
# 281/281 [==============================] - 42s 149ms/step - loss: 0.2726 - accuracy: 0.8805 - val_loss: 0.3175 - val_accuracy: 0.8703 - lr: 0.0010
# Epoch 6/200
# 281/281 [==============================] - 44s 158ms/step - loss: 0.2485 - accuracy: 0.8963 - val_loss: 0.2932 - val_accuracy: 0.8782 - lr: 0.0010
# Epoch 7/200
# 281/281 [==============================] - 42s 149ms/step - loss: 0.2378 - accuracy: 0.8978 - val_loss: 0.3126 - val_accuracy: 0.8762 - lr: 0.0010
# Epoch 8/200
# 281/281 [==============================] - 44s 155ms/step - loss: 0.2263 - accuracy: 0.9018 - val_loss: 0.2909 - val_accuracy: 0.8902 - lr: 0.0010
# Epoch 9/200
# 281/281 [==============================] - 43s 153ms/step - loss: 0.2071 - accuracy: 0.9127 - val_loss: 0.3609 - val_accuracy: 0.8443 - lr: 0.0010
# Epoch 10/200
# 281/281 [==============================] - 42s 149ms/step - loss: 0.1976 - accuracy: 0.9183 - val_loss: 0.2670 - val_accuracy: 0.8882 - lr: 0.0010
# 281/281 [==============================] - 44s 157ms/step - loss: 0.1168 - accuracy: 0.9534 - val_loss: 0.2862 - val_accuracy: 0.8882 - lr: 9.9700e-04
# Epoch 27/200
# 281/281 [==============================] - 42s 150ms/step - loss: 0.1144 - accuracy: 0.9534 - val_loss: 0.3180 - val_accuracy: 0.8982 - lr: 9.9700e-04
# Epoch 28/200
# 281/281 [==============================] - 45s 158ms/step - loss: 0.1195 - accuracy: 0.9543 - val_loss: 0.3084 - val_accuracy: 0.9002 - lr: 9.9700e-04
# Epoch 29/200
# 281/281 [==============================] - 42s 150ms/step - loss: 0.1065 - accuracy: 0.9591 - val_loss: 0.3159 - val_accuracy: 0.8902 - lr: 9.9700e-04
# Epoch 30/200
# 281/281 [==============================] - 42s 150ms/step - loss: 0.1107 - accuracy: 0.9567 - val_loss: 0.3138 - val_accuracy: 0.8922 - lr: 9.9700e-04
# Epoch 31/200
# 281/281 [==============================] - 43s 154ms/step - loss: 0.1001 - accuracy: 0.9591 - val_loss: 0.3535 - val_accuracy: 0.8822 - lr: 9.9601e-04
# Epoch 32/200
# 281/281 [==============================] - 43s 151ms/step - loss: 0.1052 - accuracy: 0.9611 - val_loss: 0.3386 - val_accuracy: 0.8902 - lr: 9.9601e-04
# Epoch 33/200
# 281/281 [==============================] - 43s 154ms/step - loss: 0.1004 - accuracy: 0.9629 - val_loss: 0.3919 - val_accuracy: 0.8922 - lr: 9.9601e-04
# Epoch 34/200
# 281/281 [==============================] - 44s 155ms/step - loss: 0.1055 - accuracy: 0.9587 - val_loss: 0.2814 - val_accuracy: 0.8962 - lr: 9.9601e-04
# Epoch 35/200
# 281/281 [==============================] - 47s 167ms/step - loss: 0.1043 - accuracy: 0.9594 - val_loss: 0.3466 - val_accuracy: 0.8862 - lr: 9.9601e-04

# %%
# Save the model
model.save('Augmentation_Rotation')
with open('Augmentation_Rotation/history.pkl', 'wb') as f:
  pickle.dump(history_rotation, f)

# %%
# Plot the training histories

# with open('v1/TestTimeAugmentation/history.pkl', 'rb') as f:
#   history = pickle.load(f)

plt.figure(figsize=(15,5))
# plt.plot(history['loss'], alpha=.3, color='#ff7f0e', linestyle='--')
# plt.plot(history['val_loss'], label='Baseline', alpha=.8, color='#ff7f0e')
plt.plot(history_rotation['loss'], alpha=.3, color='#9467BD', linestyle='--')
plt.plot(history_rotation['val_loss'], label='Rotation', alpha=.8, color='#9467BD')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
# plt.plot(history['accuracy'], alpha=.3, color='#ff7f0e', linestyle='--')
# plt.plot(history['val_accuracy'], label='Baseline', alpha=.8, color='#ff7f0e')
plt.plot(history_rotation['accuracy'], alpha=.3, color='#9467BD', linestyle='--')
plt.plot(history_rotation['val_accuracy'], label='Rotation', alpha=.8, color='#9467BD')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()
